# %% [markdown]
# # FIT3182 - Big data management and processing
#
# Name: Cheong Karr Kei
#
# Student ID: 30091497
#
# Email: kche0070@student.monash.edu
#
#
# # Assignment Part A #
#
# **Task 1. MongoDB Data Model**
#
#
# Based on the two data sets provided (`hotspot_historic.csv` and `climate_historic.csv`), a suitable data model to support the efficient querying of the two data sets would be a `One-to-Many Relationship Model` by using `Document References`.
#
# According to the specifications, climate data is recorded on a daily basis whereas fire data is recorded based on the occurrence of a fire on a particular day. This means that for one climate data, there can be zero or many fire data, thus the one-to-many relationship.
#
# Let us look at an example of this model using the two data sets provided.

# %%
import pymongo
from pymongo import MongoClient

# Connect on the default host and port
client = MongoClient () 

#Create/get database 
db = client.taskA_db

# %% [markdown]
# To create this example, we will look at the entries on `27th December 2018` in both datasets. In `climate_historic.csv`, there is only one entry where:
# - station: 948702
# - date: 27/12/18
# - air_temperature_celcius: 28
# - relative_humidity: 58.3
# - windspeed_knots: 9.3
# - max_wind_speed: 15.9
# - precipitation: 0.00I
# - GHI_w/m2: 223
#
# Let us create a new document, note that we change the date to 27/12/2018 format to match with the dates in `hotspot_historic.csv` for demonstration purposes

# %%
#Create/get collection for climates
climates = db.climates
#clear collection
climates.drop()

# %%
newClimate = {
    "station": 948702,
    "date": "27/12/2018",
    "air_temperature_celcius": 28,
    "relative_humidity": 58.3,
    "windspeed_knots": 9.3,
    "max_wind_speed": 15.9,
    "precipitation": "0.00I",
    "GHI_w/m2": 223
    }

# %% [markdown]
# Now, insert this document into our collection

# %%
result = climates.insert_one(newClimate)
print(result.inserted_id)
# Out:
# 60af1c449343690fa94506b3

# %% [markdown]
# Let us look at the document that we have just inserted

# %%
from pprint import pprint

cursor = climates.find({})
for document in cursor: 
    pprint(document)
# Out:
# {'GHI_w/m2': 223,
#  '_id': ObjectId('60af1c449343690fa94506b3'),
#  'air_temperature_celcius': 28,
#  'date': '27/12/2018',
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.3,
#  'station': 948702,
#  'windspeed_knots': 9.3}

# %% [markdown]
# There are four entries on `27th December 2018` in `hotspot_historic.csv`:
#
# **Entry 1:**
# - latitude: -37.966
# - longitude: 145.051
# - datetime: 2018-12-27T04:16:51
# - confidence: 78
# - date: 27/12/2018
# - surface_temperature_celcius: 68
#
# **Entry 2:**
# - latitude: -35.541
# - longitude: 143.311
# - datetime: 2018-12-27T00:02:15
# - confidence: 82
# - date: 27/12/2018
# - surface_temperature_celcius: 63
#
# **Entry 3:**
# - latitude: -35.554
# - longitude: 143.307
# - datetime: 2018-12-27T00:02:15
# - confidence: 67
# - date: 27/12/2018
# - surface_temperature_celcius: 53
#
# **Entry 4:**
# - latitude: -35.543
# - longitude: 143.316
# - datetime: 2018-12-27T00:02:14
# - confidence: 86
# - date: 27/12/2018
# - surface_temperature_celcius: 67
#
# Let us create the new documents for these entries so that we can add them to our database.

# %%
#Create/get collection for fires
fires = db.fires
#Clear collection 
fires.drop()

# %%
newFires = [
    {
    
        "latitude": -37.966,
        "longitude": 145.051,
        "datetime": "2018-12-27T04:16:51",
        "confidence": 78,
        "date": "27/12/2018",
        "surface_temperature_celcius": 68

    },
    {
    
        "latitude": -35.541,
        "longitude": 143.311,
        "datetime": "2018-12-27T00:02:15",
        "confidence": 82,
        "date": "27/12/2018",
        "surface_temperature_celcius": 63

    },
    {
    
        "latitude": -35.554,
        "longitude": 143.307,
        "datetime": "2018-12-27T00:02:15",
        "confidence": 67,
        "date": "27/12/2018",
        "surface_temperature_celcius": 53

    },
    {
    
    "latitude": -35.543,
    "longitude": 143.316,
    "datetime": "2018-12-27T00:02:14",
    "confidence": 86,
    "date": "27/12/2018",
    "surface_temperature_celcius": 67

    }
    
]
result = fires.insert_many(newFires)

result.inserted_ids
# Out:
# [ObjectId('60af1c4b9343690fa94506b4'),
#  ObjectId('60af1c4b9343690fa94506b5'),
#  ObjectId('60af1c4b9343690fa94506b6'),
#  ObjectId('60af1c4b9343690fa94506b7')]

# %% [markdown]
# Now look at the documents in fires collection

# %%
from pprint import pprint

cursor = fires.find({})
for document in cursor: 
    pprint(document)
# Out:
# {'_id': ObjectId('60af1c4b9343690fa94506b4'),
#  'confidence': 78,
#  'date': '27/12/2018',
#  'datetime': '2018-12-27T04:16:51',
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c4b9343690fa94506b5'),
#  'confidence': 82,
#  'date': '27/12/2018',
#  'datetime': '2018-12-27T00:02:15',
#  'latitude': -35.541,
#  'longitude': 143.311,
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('60af1c4b9343690fa94506b6'),
#  'confidence': 67,
#  'date': '27/12/2018',
#  'datetime': '2018-12-27T00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c4b9343690fa94506b7'),
#  'confidence': 86,
#  'date': '27/12/2018',
#  'datetime': '2018-12-27T00:02:14',
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}

# %% [markdown]
# Now, retrieve the unique ID's of the document in `fires` on the date that we want to reference in each corresponding `climates` entry and add them into an array

# %%
results = fires.find({"date":"27/12/2018"} , {"id_":1})

fires_id  = []
for result in results:
    fires_id.append(result["_id"])
    
print(fires_id)
# Out:
# [ObjectId('60af1c4b9343690fa94506b4'), ObjectId('60af1c4b9343690fa94506b5'), ObjectId('60af1c4b9343690fa94506b6'), ObjectId('60af1c4b9343690fa94506b7')]

# %% [markdown]
# We can now add the field `fires` to refer to the corresponding `fires` entries to each `climates` document.

# %%
result = climates.update_many({"date":"27/12/2018"},
    { 
    "$set": {
        "fires": fires_id} 
    })

# %% [markdown]
# Now we can check the `climates` collection once again to see the added field.

# %%
cursor = climates.find({})
for document in cursor: 
    pprint(document)
# Out:
# {'GHI_w/m2': 223,
#  '_id': ObjectId('60af1c449343690fa94506b3'),
#  'air_temperature_celcius': 28,
#  'date': '27/12/2018',
#  'fires': [ObjectId('60af1c4b9343690fa94506b4'),
#            ObjectId('60af1c4b9343690fa94506b5'),
#            ObjectId('60af1c4b9343690fa94506b6'),
#            ObjectId('60af1c4b9343690fa94506b7')],
#  'max_wind_speed': 15.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 58.3,
#  'station': 948702,
#  'windspeed_knots': 9.3}

# %% [markdown]
# We have now successfully stored the `fires` references inside the `climates` documents!
#
# To understand why I have chosen this data model design, we first have to look at the two ways we can model `one-to-many` relationships:
# - Embedding Documents
# - Referencing Documents
#
# **1. Embedding Documents**
#
# If we were to choose this data model design, then we have to embed the  `fires` documents inside each corresponding `climates` document. This is not ideal because we can run out of memory.
#
# **2. Referencing Documents**
#
# Thus, to avoid this risk of running out of memory, we use references which allows us to keep our `climates` data in a separate collection from the `fires` collection. Since we now have two separate colections for `climates` and `fires`, not only do we have more memory for each collection but we can also access each collection independently. Now, we have two ways of referencing the data:
#
# - Having `one` refence to the corresponding `climates` document in each `fires`document.
#     * This is not ideal because there may be days where no fires were reported whereas climates are recorded on a daily basis so we risk missing out some climates data.
#
# - Keeping an `array` of references to the corresponding `fires` document in each `climates` document.
#     * This is better because we just just access the corresponding `fires` documents (if any) through each `climates` document.
#
# This explains the justification behind choosing this data model. We will now move on to Task 2.

# %% [markdown]
# **Task 2. Querying MongoDB using PyMongo**
#
# Now that we understand the data model, we will move on to creating the actual database for part A.
#
# **Load climate data to our database**

# %%
import pymongo
from pymongo import MongoClient

# Connect on the default host and port
client = MongoClient () 
#Create/get database 
db = client.fit3182_assignment_db
#Create/get collection for climate data
climates = db.climate_historic
#clear collection
climates.drop()

# %%
#import necessary modules
import csv
import datetime as dt

#open csv file containing climate data (https://stackoverflow.com/questions/17262256/how-to-read-one-single-line-of-csv-data-in-python)

header = None
with open('climate_historic.csv', newline='') as f:
    reader = csv.reader(f)
    #get the header (first row)
    header = next(reader)  
    
    #iterate row 2 onwards
    for row in reader:
        #we want to use the same format for date as in the fires data
        current_date = row[1]
        #initialise string for new date
        new_date = ""

        #reformat date
        for i in range (len(current_date)-2):
            new_date += current_date[i]

        new_date += "20"

        new_date += current_date[len(current_date)-2]
        new_date += current_date[len(current_date)-1]

        new_date = dt.datetime.strptime(new_date, "%d/%m/%Y").strftime("%d/%m/%Y")
        
        #create new document
        newClimate = {
                        #station
                        header[0] : int(row[0]),    
                        #date
                        header[1]: new_date,   
                        #air_temperature_celcius
                        header[2]: int(row[2]),
                        #relative_humidity
                        header[3]: float(row[3]),
                        #windspeed_knots
                        header[4]: float(row[4]),
                        #max_wind_speed
                        header[5]: float(row[5]),
                        #precipitation
                        header[6]: str(row[6]),
                        #GHI_w/m2
                        header[7]: int(row[7])
                      } 
        
        #insert document to climates colllection
        result = climates.insert_one(newClimate)

# %% [markdown]
# Now let us look at the inserted documents in `climates`

# %%
from pprint import pprint

cursor = climates.find({})
for document in cursor: 
    pprint(document)
# Out:
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60af1c5e9343690fa94506b9'),
#  'air_temperature_celcius': 19,
#  'date': '31/12/2017',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.8,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('60af1c5e9343690fa94506ba'),
#  'air_temperature_celcius': 15,
#  'date': '02/01/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 50.7,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('60af1c5e9343690fa94506bb'),
#  'air_temperature_celcius': 16,
#  'date': '03/01/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 186,
#  '_id': ObjectId('60af1c5e9343690fa94506bc'),
#  'air_temperature_celcius': 24,
#  'date': '04/01/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 61.6,
#  'station': 948700,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('60af1c5e9343690fa94506bd'),
#  'air_temperature_celcius': 24,
#  'date': '05/01/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.3,
#  'station': 948700,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('60af1c5e9343690fa94506be'),
#  'air_temperature_celcius': 26,
#  'date': '06/01/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.8,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('60af1c5e9343690fa94506bf'),
#  'air_temperature_celcius': 32,
#  'date': '07/01/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 160,
#  '_id': ObjectId('60af1c5e9343690fa94506c0'),
#  'air_temperature_celcius': 20,
#  'date': '08/01/2018',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 57.7,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60af1c5e9343690fa94506c1'),
#  'air_temperature_celcius': 19,
#  'date': '09/01/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('60af1c5e9343690fa94506c2'),
#  'air_temperature_celcius': 20,
#  'date': '10/01/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa94506c3'),
#  'air_temperature_celcius': 18,
#  'date': '11/01/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.3,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 179,
#  '_id': ObjectId('60af1c5e9343690fa94506c4'),
#  'air_temperature_celcius': 22,
#  'date': '12/01/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 157,
#  '_id': ObjectId('60af1c5e9343690fa94506c5'),
#  'air_temperature_celcius': 19,
#  'date': '13/01/2018',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60af1c5e9343690fa94506c6'),
#  'air_temperature_celcius': 17,
#  'date': '14/01/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.4,
#  'station': 948700,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('60af1c5e9343690fa94506c7'),
#  'air_temperature_celcius': 16,
#  'date': '15/01/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 50.8,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('60af1c5e9343690fa94506c8'),
#  'air_temperature_celcius': 24,
#  'date': '16/01/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.4,
#  'station': 948700,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 200,
#  '_id': ObjectId('60af1c5e9343690fa94506c9'),
#  'air_temperature_celcius': 24,
#  'date': '17/01/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.4,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60af1c5e9343690fa94506ca'),
#  'air_temperature_celcius': 16,
#  'date': '18/01/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 46.7,
#  'station': 948700,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('60af1c5e9343690fa94506cb'),
#  'air_temperature_celcius': 19,
#  'date': '19/01/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.98G',
#  'relative_humidity': 57.2,
#  'station': 948700,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('60af1c5e9343690fa94506cc'),
#  'air_temperature_celcius': 16,
#  'date': '20/01/2018',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.03G',
#  'relative_humidity': 50.9,
#  'station': 948700,
#  'windspeed_knots': 12.9}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa94506cd'),
#  'air_temperature_celcius': 17,
#  'date': '21/01/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 52.5,
#  'station': 948700,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 182,
#  '_id': ObjectId('60af1c5e9343690fa94506ce'),
#  'air_temperature_celcius': 23,
#  'date': '22/01/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 59.0,
#  'station': 948700,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 199,
#  '_id': ObjectId('60af1c5e9343690fa94506cf'),
#  'air_temperature_celcius': 25,
#  'date': '23/01/2018',
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 58.3,
#  'station': 948700,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('60af1c5e9343690fa94506d0'),
#  'air_temperature_celcius': 16,
#  'date': '24/01/2018',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 48.2,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60af1c5e9343690fa94506d1'),
#  'air_temperature_celcius': 17,
#  'date': '25/01/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.8,
#  'station': 948700,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa94506d2'),
#  'air_temperature_celcius': 18,
#  'date': '26/01/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.5,
#  'station': 948700,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('60af1c5e9343690fa94506d3'),
#  'air_temperature_celcius': 19,
#  'date': '27/01/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00A',
#  'relative_humidity': 56.1,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60af1c5e9343690fa94506d4'),
#  'air_temperature_celcius': 18,
#  'date': '28/01/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('60af1c5e9343690fa94506d5'),
#  'air_temperature_celcius': 22,
#  'date': '29/01/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.0,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 163,
#  '_id': ObjectId('60af1c5e9343690fa94506d6'),
#  'air_temperature_celcius': 20,
#  'date': '30/01/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 55.8,
#  'station': 948700,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('60af1c5e9343690fa94506d7'),
#  'air_temperature_celcius': 16,
#  'date': '31/01/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.4,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 138,
#  '_id': ObjectId('60af1c5e9343690fa94506d8'),
#  'air_temperature_celcius': 16,
#  'date': '01/02/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 48.9,
#  'station': 948700,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa94506d9'),
#  'air_temperature_celcius': 18,
#  'date': '02/02/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.0,
#  'station': 948700,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60af1c5e9343690fa94506da'),
#  'air_temperature_celcius': 18,
#  'date': '03/02/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.4,
#  'station': 948700,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 216,
#  '_id': ObjectId('60af1c5e9343690fa94506db'),
#  'air_temperature_celcius': 26,
#  'date': '04/02/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.7,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('60af1c5e9343690fa94506dc'),
#  'air_temperature_celcius': 21,
#  'date': '05/02/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 1.26G',
#  'relative_humidity': 64.5,
#  'station': 948700,
#  'windspeed_knots': 10.6}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('60af1c5e9343690fa94506dd'),
#  'air_temperature_celcius': 16,
#  'date': '06/02/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.1,
#  'station': 948700,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('60af1c5e9343690fa94506de'),
#  'air_temperature_celcius': 20,
#  'date': '07/02/2018',
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 57.4,
#  'station': 948700,
#  'windspeed_knots': 10.9}
# {'GHI_w/m2': 239,
#  '_id': ObjectId('60af1c5e9343690fa94506df'),
#  'air_temperature_celcius': 31,
#  'date': '08/02/2018',
#  'max_wind_speed': 23.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 61.9,
#  'station': 948700,
#  'windspeed_knots': 14.1}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('60af1c5e9343690fa94506e0'),
#  'air_temperature_celcius': 22,
#  'date': '09/02/2018',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.7,
#  'station': 948700,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 164,
#  '_id': ObjectId('60af1c5e9343690fa94506e1'),
#  'air_temperature_celcius': 21,
#  'date': '10/02/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.4,
#  'station': 948700,
#  'windspeed_knots': 6.8}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('60af1c5e9343690fa94506e2'),
#  'air_temperature_celcius': 19,
#  'date': '11/02/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 53.8,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('60af1c5e9343690fa94506e3'),
#  'air_temperature_celcius': 16,
#  'date': '12/02/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.3,
#  'station': 948700,
#  'windspeed_knots': 14.4}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('60af1c5e9343690fa94506e4'),
#  'air_temperature_celcius': 16,
#  'date': '13/02/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.16G',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 12.1}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa94506e5'),
#  'air_temperature_celcius': 14,
#  'date': '14/02/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.5,
#  'station': 948700,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 183,
#  '_id': ObjectId('60af1c5e9343690fa94506e6'),
#  'air_temperature_celcius': 22,
#  'date': '15/02/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.4,
#  'station': 948700,
#  'windspeed_knots': 10.9}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa94506e7'),
#  'air_temperature_celcius': 18,
#  'date': '16/02/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('60af1c5e9343690fa94506e8'),
#  'air_temperature_celcius': 18,
#  'date': '17/02/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 49.4,
#  'station': 948700,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 134,
#  '_id': ObjectId('60af1c5e9343690fa94506e9'),
#  'air_temperature_celcius': 15,
#  'date': '18/02/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 44.6,
#  'station': 948700,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 113,
#  '_id': ObjectId('60af1c5e9343690fa94506ea'),
#  'air_temperature_celcius': 13,
#  'date': '19/02/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.71G',
#  'relative_humidity': 48.5,
#  'station': 948700,
#  'windspeed_knots': 10.7}
# {'GHI_w/m2': 130,
#  '_id': ObjectId('60af1c5e9343690fa94506eb'),
#  'air_temperature_celcius': 15,
#  'date': '20/02/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 49.1,
#  'station': 948701,
#  'windspeed_knots': 9.6}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('60af1c5e9343690fa94506ec'),
#  'air_temperature_celcius': 16,
#  'date': '21/02/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 51.0,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('60af1c5e9343690fa94506ed'),
#  'air_temperature_celcius': 23,
#  'date': '22/02/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 49.6,
#  'station': 948701,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('60af1c5e9343690fa94506ee'),
#  'air_temperature_celcius': 18,
#  'date': '23/02/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 55.5,
#  'station': 948701,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('60af1c5e9343690fa94506ef'),
#  'air_temperature_celcius': 16,
#  'date': '24/02/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 48.3,
#  'station': 948701,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa94506f0'),
#  'air_temperature_celcius': 17,
#  'date': '25/02/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 52.6,
#  'station': 948701,
#  'windspeed_knots': 10.3}
# {'GHI_w/m2': 173,
#  '_id': ObjectId('60af1c5e9343690fa94506f1'),
#  'air_temperature_celcius': 21,
#  'date': '26/02/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('60af1c5e9343690fa94506f2'),
#  'air_temperature_celcius': 24,
#  'date': '27/02/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 190,
#  '_id': ObjectId('60af1c5e9343690fa94506f3'),
#  'air_temperature_celcius': 23,
#  'date': '28/02/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.1,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('60af1c5e9343690fa94506f4'),
#  'air_temperature_celcius': 21,
#  'date': '01/03/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 57.3,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('60af1c5e9343690fa94506f5'),
#  'air_temperature_celcius': 20,
#  'date': '02/03/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('60af1c5e9343690fa94506f6'),
#  'air_temperature_celcius': 21,
#  'date': '03/03/2018',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 59.5,
#  'station': 948701,
#  'windspeed_knots': 12.4}
# {'GHI_w/m2': 170,
#  '_id': ObjectId('60af1c5e9343690fa94506f7'),
#  'air_temperature_celcius': 22,
#  'date': '04/03/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.0,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60af1c5e9343690fa94506f8'),
#  'air_temperature_celcius': 20,
#  'date': '05/03/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.8,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('60af1c5e9343690fa94506f9'),
#  'air_temperature_celcius': 20,
#  'date': '06/03/2018',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.9,
#  'station': 948701,
#  'windspeed_knots': 17.0}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('60af1c5e9343690fa94506fa'),
#  'air_temperature_celcius': 19,
#  'date': '07/03/2018',
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.5,
#  'station': 948701,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 177,
#  '_id': ObjectId('60af1c5e9343690fa94506fb'),
#  'air_temperature_celcius': 21,
#  'date': '08/03/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.7,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 192,
#  '_id': ObjectId('60af1c5e9343690fa94506fc'),
#  'air_temperature_celcius': 23,
#  'date': '09/03/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60af1c5e9343690fa94506fd'),
#  'air_temperature_celcius': 19,
#  'date': '10/03/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.2,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('60af1c5e9343690fa94506fe'),
#  'air_temperature_celcius': 20,
#  'date': '11/03/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 59.7,
#  'station': 948701,
#  'windspeed_knots': 8.6}
# {'GHI_w/m2': 168,
#  '_id': ObjectId('60af1c5e9343690fa94506ff'),
#  'air_temperature_celcius': 21,
#  'date': '12/03/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 58.1,
#  'station': 948701,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60af1c5e9343690fa9450700'),
#  'air_temperature_celcius': 20,
#  'date': '13/03/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.2,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 199,
#  '_id': ObjectId('60af1c5e9343690fa9450701'),
#  'air_temperature_celcius': 25,
#  'date': '14/03/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.3,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('60af1c5e9343690fa9450702'),
#  'air_temperature_celcius': 28,
#  'date': '15/03/2018',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa9450703'),
#  'air_temperature_celcius': 18,
#  'date': '16/03/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 53.3,
#  'station': 948701,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('60af1c5e9343690fa9450704'),
#  'air_temperature_celcius': 18,
#  'date': '17/03/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.1,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('60af1c5e9343690fa9450705'),
#  'air_temperature_celcius': 21,
#  'date': '18/03/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'date': '19/03/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 174,
#  '_id': ObjectId('60af1c5e9343690fa9450707'),
#  'air_temperature_celcius': 23,
#  'date': '20/03/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 63.8,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('60af1c5e9343690fa9450708'),
#  'air_temperature_celcius': 20,
#  'date': '21/03/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.63G',
#  'relative_humidity': 67.4,
#  'station': 948701,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60af1c5e9343690fa9450709'),
#  'air_temperature_celcius': 18,
#  'date': '22/03/2018',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 57.5,
#  'station': 948701,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('60af1c5e9343690fa945070a'),
#  'air_temperature_celcius': 18,
#  'date': '23/03/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60af1c5e9343690fa945070b'),
#  'air_temperature_celcius': 20,
#  'date': '24/03/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 178,
#  '_id': ObjectId('60af1c5e9343690fa945070c'),
#  'air_temperature_celcius': 23,
#  'date': '25/03/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 61.9,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'date': '26/03/2018',
#  'max_wind_speed': 26.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 142,
#  '_id': ObjectId('60af1c5e9343690fa945070e'),
#  'air_temperature_celcius': 17,
#  'date': '27/03/2018',
#  'max_wind_speed': 25.1,
#  'precipitation ': ' 0.16G',
#  'relative_humidity': 53.4,
#  'station': 948701,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'date': '28/03/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.6,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 146,
#  '_id': ObjectId('60af1c5e9343690fa9450710'),
#  'air_temperature_celcius': 17,
#  'date': '29/03/2018',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 114,
#  '_id': ObjectId('60af1c5e9343690fa9450711'),
#  'air_temperature_celcius': 13,
#  'date': '30/03/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 47.0,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60af1c5e9343690fa9450712'),
#  'air_temperature_celcius': 14,
#  'date': '31/03/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60af1c5e9343690fa9450713'),
#  'air_temperature_celcius': 14,
#  'date': '01/04/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 109,
#  '_id': ObjectId('60af1c5e9343690fa9450714'),
#  'air_temperature_celcius': 12,
#  'date': '02/04/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.4,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'date': '03/04/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'date': '04/04/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'date': '05/04/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 171,
#  '_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'date': '06/04/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('60af1c5e9343690fa9450719'),
#  'air_temperature_celcius': 21,
#  'date': '07/04/2018',
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.0,
#  'station': 948701,
#  'windspeed_knots': 13.2}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60af1c5e9343690fa945071a'),
#  'air_temperature_celcius': 19,
#  'date': '08/04/2018',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.47G',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 12.5}
# {'GHI_w/m2': 96,
#  '_id': ObjectId('60af1c5e9343690fa945071b'),
#  'air_temperature_celcius': 11,
#  'date': '09/04/2018',
#  'max_wind_speed': 22.9,
#  'precipitation ': ' 0.59G',
#  'relative_humidity': 48.2,
#  'station': 948701,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 120,
#  '_id': ObjectId('60af1c5e9343690fa945071c'),
#  'air_temperature_celcius': 14,
#  'date': '10/04/2018',
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 50.4,
#  'station': 948701,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 118,
#  '_id': ObjectId('60af1c5e9343690fa945071d'),
#  'air_temperature_celcius': 14,
#  'date': '11/04/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 52.5,
#  'station': 948701,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 118,
#  '_id': ObjectId('60af1c5e9343690fa945071e'),
#  'air_temperature_celcius': 14,
#  'date': '12/04/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.4,
#  'station': 948701,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 132,
#  '_id': ObjectId('60af1c5e9343690fa945071f'),
#  'air_temperature_celcius': 16,
#  'date': '13/04/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 113,
#  '_id': ObjectId('60af1c5e9343690fa9450720'),
#  'air_temperature_celcius': 13,
#  'date': '14/04/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 48.5,
#  'station': 948701,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 108,
#  '_id': ObjectId('60af1c5e9343690fa9450721'),
#  'air_temperature_celcius': 12,
#  'date': '15/04/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 44.0,
#  'station': 948701,
#  'windspeed_knots': 4.7}
# {'GHI_w/m2': 129,
#  '_id': ObjectId('60af1c5e9343690fa9450722'),
#  'air_temperature_celcius': 15,
#  'date': '16/04/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 49.3,
#  'station': 948701,
#  'windspeed_knots': 3.6}
# {'GHI_w/m2': 110,
#  '_id': ObjectId('60af1c5e9343690fa9450723'),
#  'air_temperature_celcius': 13,
#  'date': '17/04/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.4,
#  'station': 948701,
#  'windspeed_knots': 4.6}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa9450724'),
#  'air_temperature_celcius': 15,
#  'date': '18/04/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 184,
#  '_id': ObjectId('60af1c5e9343690fa9450725'),
#  'air_temperature_celcius': 22,
#  'date': '19/04/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('60af1c5e9343690fa9450726'),
#  'air_temperature_celcius': 20,
#  'date': '20/04/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('60af1c5e9343690fa9450727'),
#  'air_temperature_celcius': 17,
#  'date': '21/04/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 58.1,
#  'station': 948701,
#  'windspeed_knots': 11.7}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa9450728'),
#  'air_temperature_celcius': 18,
#  'date': '22/04/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 58.9,
#  'station': 948701,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 134,
#  '_id': ObjectId('60af1c5e9343690fa9450729'),
#  'air_temperature_celcius': 17,
#  'date': '23/04/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 59.3,
#  'station': 948701,
#  'windspeed_knots': 4.2}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60af1c5e9343690fa945072a'),
#  'air_temperature_celcius': 19,
#  'date': '24/04/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.83G',
#  'relative_humidity': 60.5,
#  'station': 948701,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 117,
#  '_id': ObjectId('60af1c5e9343690fa945072b'),
#  'air_temperature_celcius': 14,
#  'date': '25/04/2018',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.98G',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('60af1c5e9343690fa945072c'),
#  'air_temperature_celcius': 11,
#  'date': '26/04/2018',
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 104,
#  '_id': ObjectId('60af1c5e9343690fa945072d'),
#  'air_temperature_celcius': 12,
#  'date': '27/04/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.03G',
#  'relative_humidity': 48.2,
#  'station': 948701,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 132,
#  '_id': ObjectId('60af1c5e9343690fa945072e'),
#  'air_temperature_celcius': 16,
#  'date': '28/04/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 54.8,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 127,
#  '_id': ObjectId('60af1c5e9343690fa945072f'),
#  'air_temperature_celcius': 15,
#  'date': '29/04/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 51.9,
#  'station': 948701,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('60af1c5e9343690fa9450730'),
#  'air_temperature_celcius': 15,
#  'date': '30/04/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.6,
#  'station': 948701,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 121,
#  '_id': ObjectId('60af1c5e9343690fa9450731'),
#  'air_temperature_celcius': 14,
#  'date': '01/05/2018',
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 49.2,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 91,
#  '_id': ObjectId('60af1c5e9343690fa9450732'),
#  'air_temperature_celcius': 10,
#  'date': '02/05/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 42.6,
#  'station': 948701,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 91,
#  '_id': ObjectId('60af1c5e9343690fa9450733'),
#  'air_temperature_celcius': 10,
#  'date': '03/05/2018',
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 43.1,
#  'station': 948701,
#  'windspeed_knots': 4.7}
# {'GHI_w/m2': 91,
#  '_id': ObjectId('60af1c5e9343690fa9450734'),
#  'air_temperature_celcius': 10,
#  'date': '04/05/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.3,
#  'station': 948701,
#  'windspeed_knots': 2.6}
# {'GHI_w/m2': 123,
#  '_id': ObjectId('60af1c5e9343690fa9450735'),
#  'air_temperature_celcius': 14,
#  'date': '05/05/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.4,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 107,
#  '_id': ObjectId('60af1c5e9343690fa9450736'),
#  'air_temperature_celcius': 12,
#  'date': '06/05/2018',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.16G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 107,
#  '_id': ObjectId('60af1c5e9343690fa9450737'),
#  'air_temperature_celcius': 12,
#  'date': '07/05/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.16G',
#  'relative_humidity': 45.0,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 103,
#  '_id': ObjectId('60af1c5e9343690fa9450738'),
#  'air_temperature_celcius': 12,
#  'date': '08/05/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 104,
#  '_id': ObjectId('60af1c5e9343690fa9450739'),
#  'air_temperature_celcius': 12,
#  'date': '09/05/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 49.0,
#  'station': 948701,
#  'windspeed_knots': 4.6}
# {'GHI_w/m2': 89,
#  '_id': ObjectId('60af1c5e9343690fa945073a'),
#  'air_temperature_celcius': 10,
#  'date': '10/05/2018',
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
# {'GHI_w/m2': 80,
#  '_id': ObjectId('60af1c5e9343690fa945073b'),
#  'air_temperature_celcius': 9,
#  'date': '11/05/2018',
#  'max_wind_speed': 6.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.3,
#  'station': 948701,
#  'windspeed_knots': 2.5}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa945073c'),
#  'air_temperature_celcius': 14,
#  'date': '12/05/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.9,
#  'station': 948701,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 81,
#  '_id': ObjectId('60af1c5e9343690fa945073d'),
#  'air_temperature_celcius': 9,
#  'date': '13/05/2018',
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.0,
#  'station': 948701,
#  'windspeed_knots': 2.8}
# {'GHI_w/m2': 88,
#  '_id': ObjectId('60af1c5e9343690fa945073e'),
#  'air_temperature_celcius': 10,
#  'date': '14/05/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 46.8,
#  'station': 948701,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 88,
#  '_id': ObjectId('60af1c5e9343690fa945073f'),
#  'air_temperature_celcius': 10,
#  'date': '15/05/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.0,
#  'station': 948701,
#  'windspeed_knots': 5.2}
# {'GHI_w/m2': 104,
#  '_id': ObjectId('60af1c5e9343690fa9450740'),
#  'air_temperature_celcius': 12,
#  'date': '16/05/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 48.8,
#  'station': 948701,
#  'windspeed_knots': 4.2}
# {'GHI_w/m2': 112,
#  '_id': ObjectId('60af1c5e9343690fa9450741'),
#  'air_temperature_celcius': 13,
#  'date': '17/05/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 49.4,
#  'station': 948701,
#  'windspeed_knots': 3.8}
# {'GHI_w/m2': 120,
#  '_id': ObjectId('60af1c5e9343690fa9450742'),
#  'air_temperature_celcius': 14,
#  'date': '18/05/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 6.8}
# {'GHI_w/m2': 101,
#  '_id': ObjectId('60af1c5e9343690fa9450743'),
#  'air_temperature_celcius': 12,
#  'date': '19/05/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.05G',
#  'relative_humidity': 51.6,
#  'station': 948701,
#  'windspeed_knots': 3.4}
# {'GHI_w/m2': 120,
#  '_id': ObjectId('60af1c5e9343690fa9450744'),
#  'air_temperature_celcius': 14,
#  'date': '20/05/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.1,
#  'station': 948701,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 119,
#  '_id': ObjectId('60af1c5e9343690fa9450745'),
#  'air_temperature_celcius': 14,
#  'date': '21/05/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.0,
#  'station': 948701,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('60af1c5e9343690fa9450746'),
#  'air_temperature_celcius': 17,
#  'date': '22/05/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 48.7,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 129,
#  '_id': ObjectId('60af1c5e9343690fa9450747'),
#  'air_temperature_celcius': 15,
#  'date': '23/05/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa9450748'),
#  'air_temperature_celcius': 14,
#  'date': '24/05/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.4,
#  'station': 948701,
#  'windspeed_knots': 7.5}
# {'GHI_w/m2': 119,
#  '_id': ObjectId('60af1c5e9343690fa9450749'),
#  'air_temperature_celcius': 14,
#  'date': '25/05/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 50.7,
#  'station': 948701,
#  'windspeed_knots': 8.6}
# {'GHI_w/m2': 113,
#  '_id': ObjectId('60af1c5e9343690fa945074a'),
#  'air_temperature_celcius': 13,
#  'date': '26/05/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.5,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa945074b'),
#  'air_temperature_celcius': 14,
#  'date': '27/05/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.35G',
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('60af1c5e9343690fa945074c'),
#  'air_temperature_celcius': 9,
#  'date': '28/05/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 41.2,
#  'station': 948701,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 109,
#  '_id': ObjectId('60af1c5e9343690fa945074d'),
#  'air_temperature_celcius': 12,
#  'date': '29/05/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 42.8,
#  'station': 948701,
#  'windspeed_knots': 12.1}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('60af1c5e9343690fa945074e'),
#  'air_temperature_celcius': 8,
#  'date': '30/05/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 99,
#  '_id': ObjectId('60af1c5e9343690fa945074f'),
#  'air_temperature_celcius': 11,
#  'date': '31/05/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 43.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 100,
#  '_id': ObjectId('60af1c5e9343690fa9450750'),
#  'air_temperature_celcius': 11,
#  'date': '01/06/2018',
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 43.2,
#  'station': 948701,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('60af1c5e9343690fa9450751'),
#  'air_temperature_celcius': 12,
#  'date': '02/06/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.0,
#  'station': 948701,
#  'windspeed_knots': 4.8}
# {'GHI_w/m2': 72,
#  '_id': ObjectId('60af1c5e9343690fa9450752'),
#  'air_temperature_celcius': 8,
#  'date': '03/06/2018',
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.3,
#  'station': 948701,
#  'windspeed_knots': 3.9}
# {'GHI_w/m2': 82,
#  '_id': ObjectId('60af1c5e9343690fa9450753'),
#  'air_temperature_celcius': 9,
#  'date': '04/06/2018',
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('60af1c5e9343690fa9450754'),
#  'air_temperature_celcius': 12,
#  'date': '05/06/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 47.6,
#  'station': 948701,
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('60af1c5e9343690fa9450755'),
#  'air_temperature_celcius': 9,
#  'date': '06/06/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 74,
#  '_id': ObjectId('60af1c5e9343690fa9450756'),
#  'air_temperature_celcius': 8,
#  'date': '07/06/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 88,
#  '_id': ObjectId('60af1c5e9343690fa9450757'),
#  'air_temperature_celcius': 10,
#  'date': '08/06/2018',
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 46.3,
#  'station': 948701,
#  'windspeed_knots': 4.6}
# {'GHI_w/m2': 88,
#  '_id': ObjectId('60af1c5e9343690fa9450758'),
#  'air_temperature_celcius': 10,
#  'date': '09/06/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 47.1,
#  'station': 948701,
#  'windspeed_knots': 4.6}
# {'GHI_w/m2': 72,
#  '_id': ObjectId('60af1c5e9343690fa9450759'),
#  'air_temperature_celcius': 8,
#  'date': '10/06/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 44.5,
#  'station': 948701,
#  'windspeed_knots': 4.7}
# {'GHI_w/m2': 89,
#  '_id': ObjectId('60af1c5e9343690fa945075a'),
#  'air_temperature_celcius': 10,
#  'date': '11/06/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 44.9,
#  'station': 948701,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 103,
#  '_id': ObjectId('60af1c5e9343690fa945075b'),
#  'air_temperature_celcius': 12,
#  'date': '12/06/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 49.4,
#  'station': 948701,
#  'windspeed_knots': 4.4}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('60af1c5e9343690fa945075c'),
#  'air_temperature_celcius': 8,
#  'date': '13/06/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.1,
#  'station': 948701,
#  'windspeed_knots': 3.4}
# {'GHI_w/m2': 97,
#  '_id': ObjectId('60af1c5e9343690fa945075d'),
#  'air_temperature_celcius': 11,
#  'date': '14/06/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 46.4,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('60af1c5e9343690fa945075e'),
#  'air_temperature_celcius': 11,
#  'date': '15/06/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00A',
#  'relative_humidity': 45.4,
#  'station': 948701,
#  'windspeed_knots': 5.2}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('60af1c5e9343690fa945075f'),
#  'air_temperature_celcius': 8,
#  'date': '16/06/2018',
#  'max_wind_speed': 6.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 42.6,
#  'station': 948701,
#  'windspeed_knots': 2.0}
# {'GHI_w/m2': 89,
#  '_id': ObjectId('60af1c5e9343690fa9450760'),
#  'air_temperature_celcius': 10,
#  'date': '17/06/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 45.6,
#  'station': 948701,
#  'windspeed_knots': 4.5}
# {'GHI_w/m2': 87,
#  '_id': ObjectId('60af1c5e9343690fa9450761'),
#  'air_temperature_celcius': 10,
#  'date': '18/06/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.9,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('60af1c5e9343690fa9450762'),
#  'air_temperature_celcius': 11,
#  'date': '19/06/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 5.6}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('60af1c5e9343690fa9450763'),
#  'air_temperature_celcius': 11,
#  'date': '20/06/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 45.3,
#  'station': 948701,
#  'windspeed_knots': 10.6}
# {'GHI_w/m2': 89,
#  '_id': ObjectId('60af1c5e9343690fa9450764'),
#  'air_temperature_celcius': 10,
#  'date': '21/06/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.9,
#  'station': 948701,
#  'windspeed_knots': 3.2}
# {'GHI_w/m2': 92,
#  '_id': ObjectId('60af1c5e9343690fa9450765'),
#  'air_temperature_celcius': 10,
#  'date': '22/06/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 41.4,
#  'station': 948701,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 99,
#  '_id': ObjectId('60af1c5e9343690fa9450766'),
#  'air_temperature_celcius': 11,
#  'date': '23/06/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 43.9,
#  'station': 948701,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 94,
#  '_id': ObjectId('60af1c5e9343690fa9450767'),
#  'air_temperature_celcius': 10,
#  'date': '24/06/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 37.9,
#  'station': 948701,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 99,
#  '_id': ObjectId('60af1c5e9343690fa9450768'),
#  'air_temperature_celcius': 11,
#  'date': '25/06/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 44.2,
#  'station': 948701,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 89,
#  '_id': ObjectId('60af1c5e9343690fa9450769'),
#  'air_temperature_celcius': 10,
#  'date': '26/06/2018',
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 3.6}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('60af1c5e9343690fa945076a'),
#  'air_temperature_celcius': 9,
#  'date': '27/06/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 41.0,
#  'station': 948701,
#  'windspeed_knots': 8.2}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('60af1c5e9343690fa945076b'),
#  'air_temperature_celcius': 10,
#  'date': '28/06/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.7,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 91,
#  '_id': ObjectId('60af1c5e9343690fa945076c'),
#  'air_temperature_celcius': 10,
#  'date': '29/06/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.13B',
#  'relative_humidity': 42.1,
#  'station': 948701,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 48,
#  '_id': ObjectId('60af1c5e9343690fa945076d'),
#  'air_temperature_celcius': 5,
#  'date': '30/06/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00A',
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
# {'GHI_w/m2': 49,
#  '_id': ObjectId('60af1c5e9343690fa945076e'),
#  'air_temperature_celcius': 5,
#  'date': '01/07/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 60,
#  '_id': ObjectId('60af1c5e9343690fa945076f'),
#  'air_temperature_celcius': 6,
#  'date': '02/07/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('60af1c5e9343690fa9450770'),
#  'air_temperature_celcius': 11,
#  'date': '03/07/2018',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('60af1c5e9343690fa9450771'),
#  'air_temperature_celcius': 12,
#  'date': '04/07/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 82,
#  '_id': ObjectId('60af1c5e9343690fa9450772'),
#  'air_temperature_celcius': 9,
#  'date': '05/07/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 42.4,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 84,
#  '_id': ObjectId('60af1c5e9343690fa9450773'),
#  'air_temperature_celcius': 9,
#  'date': '06/07/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 40.1,
#  'station': 948701,
#  'windspeed_knots': 7.5}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('60af1c5e9343690fa9450774'),
#  'air_temperature_celcius': 9,
#  'date': '07/07/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 41.2,
#  'station': 948701,
#  'windspeed_knots': 9.8}
# {'GHI_w/m2': 82,
#  '_id': ObjectId('60af1c5e9343690fa9450775'),
#  'air_temperature_celcius': 9,
#  'date': '08/07/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 42.8,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 93,
#  '_id': ObjectId('60af1c5e9343690fa9450776'),
#  'air_temperature_celcius': 10,
#  'date': '09/07/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 39.4,
#  'station': 948701,
#  'windspeed_knots': 9.6}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('60af1c5e9343690fa9450777'),
#  'air_temperature_celcius': 10,
#  'date': '10/07/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 44.4,
#  'station': 948701,
#  'windspeed_knots': 5.6}
# {'GHI_w/m2': 56,
#  '_id': ObjectId('60af1c5e9343690fa9450778'),
#  'air_temperature_celcius': 6,
#  'date': '11/07/2018',
#  'max_wind_speed': 5.1,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 84,
#  '_id': ObjectId('60af1c5e9343690fa9450779'),
#  'air_temperature_celcius': 9,
#  'date': '12/07/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 5.6}
# {'GHI_w/m2': 111,
#  '_id': ObjectId('60af1c5e9343690fa945077a'),
#  'air_temperature_celcius': 12,
#  'date': '13/07/2018',
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 16.7}
# {'GHI_w/m2': 84,
#  '_id': ObjectId('60af1c5e9343690fa945077b'),
#  'air_temperature_celcius': 9,
#  'date': '14/07/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 40.0,
#  'station': 948701,
#  'windspeed_knots': 8.6}
# {'GHI_w/m2': 57,
#  '_id': ObjectId('60af1c5e9343690fa945077c'),
#  'air_temperature_celcius': 6,
# ...
#  '_id': ObjectId('60af1c5e9343690fa94507e6'),
#  'air_temperature_celcius': 17,
#  'date': '29/10/2018',
#  'max_wind_speed': 27.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 100,
#  '_id': ObjectId('60af1c5e9343690fa94507e7'),
#  'air_temperature_celcius': 11,
#  'date': '30/10/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 114,
#  '_id': ObjectId('60af1c5e9343690fa94507e8'),
#  'air_temperature_celcius': 13,
#  'date': '31/10/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 47.1,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 111,
#  '_id': ObjectId('60af1c5e9343690fa94507e9'),
#  'air_temperature_celcius': 13,
#  'date': '01/11/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 50.1,
#  'station': 948702,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 108,
#  '_id': ObjectId('60af1c5e9343690fa94507ea'),
#  'air_temperature_celcius': 12,
#  'date': '02/11/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.16G',
#  'relative_humidity': 43.8,
#  'station': 948702,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('60af1c5e9343690fa94507eb'),
#  'air_temperature_celcius': 11,
#  'date': '03/11/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 40.4,
#  'station': 948702,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 101,
#  '_id': ObjectId('60af1c5e9343690fa94507ec'),
#  'air_temperature_celcius': 11,
#  'date': '04/11/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.03G',
#  'relative_humidity': 41.4,
#  'station': 948702,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 118,
#  '_id': ObjectId('60af1c5e9343690fa94507ed'),
#  'air_temperature_celcius': 13,
#  'date': '05/11/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 43.3,
#  'station': 948702,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 117,
#  '_id': ObjectId('60af1c5e9343690fa94507ee'),
#  'air_temperature_celcius': 13,
#  'date': '06/11/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 44.1,
#  'station': 948702,
#  'windspeed_knots': 12.9}
# {'GHI_w/m2': 109,
#  '_id': ObjectId('60af1c5e9343690fa94507ef'),
#  'air_temperature_celcius': 12,
#  'date': '07/11/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 42.7,
#  'station': 948702,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 106,
#  '_id': ObjectId('60af1c5e9343690fa94507f0'),
#  'air_temperature_celcius': 12,
#  'date': '08/11/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 46.6,
#  'station': 948702,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 119,
#  '_id': ObjectId('60af1c5e9343690fa94507f1'),
#  'air_temperature_celcius': 14,
#  'date': '09/11/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 50.9,
#  'station': 948702,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60af1c5e9343690fa94507f2'),
#  'air_temperature_celcius': 18,
#  'date': '10/11/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.8,
#  'station': 948702,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('60af1c5e9343690fa94507f3'),
#  'air_temperature_celcius': 18,
#  'date': '11/11/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.6,
#  'station': 948702,
#  'windspeed_knots': 8.2}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60af1c5e9343690fa94507f4'),
#  'air_temperature_celcius': 18,
#  'date': '12/11/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.8,
#  'station': 948702,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60af1c5e9343690fa94507f5'),
#  'air_temperature_celcius': 24,
#  'date': '13/11/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.9,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 243,
#  '_id': ObjectId('60af1c5e9343690fa94507f6'),
#  'air_temperature_celcius': 28,
#  'date': '14/11/2018',
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 48.3,
#  'station': 948702,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('60af1c5e9343690fa94507f7'),
#  'air_temperature_celcius': 21,
#  'date': '15/11/2018',
#  'max_wind_speed': 22.9,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 58.8,
#  'station': 948702,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60af1c5e9343690fa94507f8'),
#  'air_temperature_celcius': 18,
#  'date': '16/11/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151,
#  '_id': ObjectId('60af1c5e9343690fa94507f9'),
#  'air_temperature_celcius': 19,
#  'date': '17/11/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60af1c5e9343690fa94507fa'),
#  'air_temperature_celcius': 20,
#  'date': '18/11/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 58.4,
#  'station': 948702,
#  'windspeed_knots': 4.7}
# {'GHI_w/m2': 178,
#  '_id': ObjectId('60af1c5e9343690fa94507fb'),
#  'air_temperature_celcius': 22,
#  'date': '19/11/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 57.0,
#  'station': 948702,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('60af1c5e9343690fa94507fc'),
#  'air_temperature_celcius': 24,
#  'date': '20/11/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.5,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('60af1c5e9343690fa94507fd'),
#  'air_temperature_celcius': 24,
#  'date': '21/11/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.8,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('60af1c5e9343690fa94507fe'),
#  'air_temperature_celcius': 23,
#  'date': '22/11/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 49.6,
#  'station': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('60af1c5e9343690fa94507ff'),
#  'air_temperature_celcius': 24,
#  'date': '23/11/2018',
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.8,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 183,
#  '_id': ObjectId('60af1c5e9343690fa9450800'),
#  'air_temperature_celcius': 23,
#  'date': '24/11/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 58.8,
#  'station': 948702,
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 188,
#  '_id': ObjectId('60af1c5e9343690fa9450801'),
#  'air_temperature_celcius': 24,
#  'date': '25/11/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 60.1,
#  'station': 948702,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 156,
#  '_id': ObjectId('60af1c5e9343690fa9450802'),
#  'air_temperature_celcius': 20,
#  'date': '26/11/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 60.8,
#  'station': 948702,
#  'windspeed_knots': 10.4}
# {'GHI_w/m2': 142,
#  '_id': ObjectId('60af1c5e9343690fa9450803'),
#  'air_temperature_celcius': 17,
#  'date': '27/11/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 52.7,
#  'station': 948702,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 183,
#  '_id': ObjectId('60af1c5e9343690fa9450804'),
#  'air_temperature_celcius': 23,
#  'date': '28/11/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.8,
#  'station': 948702,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('60af1c5e9343690fa9450805'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 135,
#  '_id': ObjectId('60af1c5e9343690fa9450807'),
#  'air_temperature_celcius': 17,
#  'date': '01/12/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.75G',
#  'relative_humidity': 59.0,
#  'station': 948702,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa9450808'),
#  'air_temperature_celcius': 15,
#  'date': '02/12/2018',
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 1.77G',
#  'relative_humidity': 56.2,
#  'station': 948702,
#  'windspeed_knots': 16.9}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa9450809'),
#  'air_temperature_celcius': 14,
#  'date': '03/12/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.03G',
#  'relative_humidity': 48.2,
#  'station': 948702,
#  'windspeed_knots': 12.5}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa945080a'),
#  'air_temperature_celcius': 14,
#  'date': '04/12/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.2,
#  'station': 948702,
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 142,
#  '_id': ObjectId('60af1c5e9343690fa945080b'),
#  'air_temperature_celcius': 17,
#  'date': '05/12/2018',
#  'max_wind_speed': 22.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.0,
#  'station': 948702,
#  'windspeed_knots': 14.6}
# {'GHI_w/m2': 135,
#  '_id': ObjectId('60af1c5e9343690fa945080c'),
#  'air_temperature_celcius': 16,
#  'date': '06/12/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.7,
#  'station': 948702,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('60af1c5e9343690fa945080d'),
#  'air_temperature_celcius': 15,
#  'date': '07/12/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 1.26G',
#  'relative_humidity': 51.0,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60af1c5e9343690fa945080e'),
#  'air_temperature_celcius': 15,
#  'date': '08/12/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.1,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60af1c5e9343690fa945080f'),
#  'air_temperature_celcius': 17,
#  'date': '09/12/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.6,
#  'station': 948702,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60af1c5e9343690fa9450810'),
#  'air_temperature_celcius': 17,
#  'date': '10/12/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.5,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa9450811'),
#  'air_temperature_celcius': 17,
#  'date': '11/12/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 156,
#  '_id': ObjectId('60af1c5e9343690fa9450812'),
#  'air_temperature_celcius': 19,
#  'date': '12/12/2018',
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 240,
#  '_id': ObjectId('60af1c5e9343690fa9450813'),
#  'air_temperature_celcius': 28,
#  'date': '13/12/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 49.9,
#  'station': 948702,
#  'windspeed_knots': 11.0}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa9450814'),
#  'air_temperature_celcius': 17,
#  'date': '14/12/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.5,
#  'station': 948702,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('60af1c5e9343690fa9450815'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('60af1c5e9343690fa9450817'),
#  'air_temperature_celcius': 21,
#  'date': '17/12/2018',
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 195,
#  '_id': ObjectId('60af1c5e9343690fa9450818'),
#  'air_temperature_celcius': 25,
#  'date': '18/12/2018',
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.9,
#  'station': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('60af1c5e9343690fa9450819'),
#  'air_temperature_celcius': 21,
#  'date': '19/12/2018',
#  'max_wind_speed': 22.9,
#  'precipitation ': ' 0.67G',
#  'relative_humidity': 57.4,
#  'station': 948702,
#  'windspeed_knots': 10.7}
# {'GHI_w/m2': 144,
#  '_id': ObjectId('60af1c5e9343690fa945081a'),
#  'air_temperature_celcius': 17,
#  'date': '20/12/2018',
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 51.2,
#  'station': 948702,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa945081b'),
#  'air_temperature_celcius': 17,
#  'date': '21/12/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.5,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('60af1c5e9343690fa945081c'),
#  'air_temperature_celcius': 19,
#  'date': '22/12/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.8,
#  'station': 948702,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('60af1c5e9343690fa945081d'),
#  'air_temperature_celcius': 19,
#  'date': '23/12/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.9,
#  'station': 948702,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60af1c5e9343690fa945081e'),
#  'air_temperature_celcius': 16,
#  'date': '24/12/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.0,
#  'station': 948702,
#  'windspeed_knots': 12.0}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60af1c5e9343690fa945081f'),
#  'air_temperature_celcius': 17,
#  'date': '25/12/2018',
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 50.4,
#  'station': 948702,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('60af1c5e9343690fa9450820'),
#  'air_temperature_celcius': 22,
#  'date': '26/12/2018',
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.5,
#  'station': 948702,
#  'windspeed_knots': 10.3}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('60af1c5e9343690fa9450821'),
#  'air_temperature_celcius': 28,
#  'date': '27/12/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.3,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 163,
#  '_id': ObjectId('60af1c5e9343690fa9450822'),
#  'air_temperature_celcius': 21,
#  'date': '28/12/2018',
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 61.1,
#  'station': 948702,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa9450823'),
#  'air_temperature_celcius': 19,
#  'date': '29/12/2018',
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.63G',
#  'relative_humidity': 59.7,
#  'station': 948702,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 135,
#  '_id': ObjectId('60af1c5e9343690fa9450824'),
#  'air_temperature_celcius': 16,
#  'date': '30/12/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 51.5,
#  'station': 948702,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa9450825'),
#  'air_temperature_celcius': 18,
#  'date': '31/12/2018',
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 53.6,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60af1c5e9343690fa9450826'),
#  'air_temperature_celcius': 19,
#  'date': '01/01/2018',
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.9,
#  'station': 948702,
#  'windspeed_knots': 8.1}

# %% [markdown]
# **Load fire data to our database**

# %%
#create collection for fire data
fires = db.fire_historic
#clear collection
fires.drop()

# %%
#import necessary modules
import csv
import datetime as dt

#open csv file containing climate data (https://stackoverflow.com/questions/17262256/how-to-read-one-single-line-of-csv-data-in-python)

header = None
with open('hotspot_historic.csv', newline='') as f:
    reader = csv.reader(f)
    #get the header (first row)
    header = next(reader)  
    
    #iterate row 2 onwards
    for row in reader:
        
        #we want the format of the date to be the same for both collections
        current_date = row[4]
        new_date = dt.datetime.strptime(current_date, "%d/%m/%Y").strftime("%d/%m/%Y")
            
        #create new document
        newFire = {
                        #latitude
                        header[0] : float(row[0]),    
                        #longitude
                        header[1]: float(row[1]),   
                        #datetime
                        header[2]: str(row[2]),
                        #confidence
                        header[3]: int(row[3]),
                        #date
                        header[4]: new_date,
                        #surface_temperature_celcius
                        header[5]: int(row[5]),
                        
                      } 
        
        #insert document to fires colllection
        result = fires.insert_one(newFire)

# %% [markdown]
# Now let us look at the inserted documents in `fires`

# %%
cursor = fires.find({})
for document in cursor: 
    pprint(document)
# Out:
# {'_id': ObjectId('60af1c679343690fa9450827'),
#  'confidence': 78,
#  'date': '27/12/2018',
#  'datetime': '2018-12-27T04:16:51',
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c679343690fa9450828'),
#  'confidence': 82,
#  'date': '27/12/2018',
#  'datetime': '2018-12-27T00:02:15',
#  'latitude': -35.541,
#  'longitude': 143.311,
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('60af1c679343690fa9450829'),
#  'confidence': 67,
#  'date': '27/12/2018',
#  'datetime': '2018-12-27T00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c679343690fa945082a'),
#  'confidence': 86,
#  'date': '27/12/2018',
#  'datetime': '2018-12-27T00:02:14',
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c679343690fa945082b'),
#  'confidence': 80,
#  'date': '25/12/2018',
#  'datetime': '2018-12-25T04:29:08',
#  'latitude': -37.708,
#  'longitude': 145.1,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c679343690fa945082c'),
#  'confidence': 65,
#  'date': '24/12/2018',
#  'datetime': '2018-12-24T13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('60af1c679343690fa945082d'),
#  'confidence': 72,
#  'date': '21/12/2018',
#  'datetime': '2018-12-21T04:53:29',
#  'latitude': -38.075,
#  'longitude': 143.76,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c679343690fa945082e'),
#  'confidence': 94,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T15:38:39',
#  'latitude': -37.636,
#  'longitude': 149.33,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c679343690fa945082f'),
#  'confidence': 69,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('60af1c679343690fa9450830'),
#  'confidence': 62,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c679343690fa9450831'),
#  'confidence': 93,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T04:35:13',
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c679343690fa9450832'),
#  'confidence': 84,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T04:34:58',
#  'latitude': -37.608,
#  'longitude': 149.328,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c679343690fa9450833'),
#  'confidence': 95,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T04:34:58',
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c679343690fa9450834'),
#  'confidence': 59,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c679343690fa9450835'),
#  'confidence': 90,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T04:34:57',
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c679343690fa9450836'),
#  'confidence': 75,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T04:34:57',
#  'latitude': -37.661,
#  'longitude': 149.327,
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('60af1c679343690fa9450837'),
#  'confidence': 79,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T04:34:57',
#  'latitude': -37.649,
#  'longitude': 149.322,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c679343690fa9450838'),
#  'confidence': 93,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T00:21:12',
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c679343690fa9450839'),
#  'confidence': 60,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c679343690fa945083a'),
#  'confidence': 82,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T00:21:11',
#  'latitude': -38.048,
#  'longitude': 144.213,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c679343690fa945083b'),
#  'confidence': 82,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T00:20:53',
#  'latitude': -37.651,
#  'longitude': 149.345,
#  'surface_temperature_celcius': 64}
# {'_id': ObjectId('60af1c679343690fa945083c'),
#  'confidence': 53,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('60af1c679343690fa945083d'),
#  'confidence': 92,
#  'date': '15/12/2018',
#  'datetime': '2018-12-15T13:17:17',
#  'latitude': -37.627,
#  'longitude': 149.33,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c679343690fa945083e'),
#  'confidence': 78,
#  'date': '15/12/2018',
#  'datetime': '2018-12-15T13:17:17',
#  'latitude': -37.658,
#  'longitude': 149.339,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('60af1c679343690fa945083f'),
#  'confidence': 51,
#  'date': '15/12/2018',
#  'datetime': '2018-12-15T13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c679343690fa9450840'),
#  'confidence': 65,
#  'date': '15/12/2018',
#  'datetime': '2018-12-15T01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c679343690fa9450841'),
#  'confidence': 92,
#  'date': '14/12/2018',
#  'datetime': '2018-12-14T04:47:25',
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c679343690fa9450842'),
#  'confidence': 83,
#  'date': '13/12/2018',
#  'datetime': '2018-12-13T04:04:19',
#  'latitude': -38.231,
#  'longitude': 147.172,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c679343690fa9450843'),
#  'confidence': 53,
#  'date': '12/12/2018',
#  'datetime': '2018-12-12T00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c679343690fa9450844'),
#  'confidence': 50,
#  'date': '10/12/2018',
#  'datetime': '2018-12-10T00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c679343690fa9450845'),
#  'confidence': 67,
#  'date': '10/12/2018',
#  'datetime': '2018-12-10T00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c679343690fa9450846'),
#  'confidence': 87,
#  'date': '09/12/2018',
#  'datetime': '2018-12-09T00:14:34',
#  'latitude': -36.294,
#  'longitude': 146.149,
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('60af1c679343690fa9450847'),
#  'confidence': 81,
#  'date': '09/12/2018',
#  'datetime': '2018-12-09T00:14:34',
#  'latitude': -36.285,
#  'longitude': 146.151,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c679343690fa9450848'),
#  'confidence': 84,
#  'date': '09/12/2018',
#  'datetime': '2018-12-09T00:14:33',
#  'latitude': -36.277,
#  'longitude': 146.165,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c679343690fa9450849'),
#  'confidence': 86,
#  'date': '09/12/2018',
#  'datetime': '2018-12-09T00:14:33',
#  'latitude': -36.275,
#  'longitude': 146.154,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c679343690fa945084a'),
#  'confidence': 77,
#  'date': '08/12/2018',
#  'datetime': '2018-12-08T13:11:44',
#  'latitude': -36.273,
#  'longitude': 146.155,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('60af1c679343690fa945084b'),
#  'confidence': 100,
#  'date': '08/12/2018',
#  'datetime': '2018-12-08T13:11:44',
#  'latitude': -36.284,
#  'longitude': 146.145,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c679343690fa945084c'),
#  'confidence': 100,
#  'date': '08/12/2018',
#  'datetime': '2018-12-08T13:11:44',
#  'latitude': -36.282,
#  'longitude': 146.157,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c679343690fa945084d'),
#  'confidence': 100,
#  'date': '08/12/2018',
#  'datetime': '2018-12-08T13:11:43',
#  'latitude': -36.293,
#  'longitude': 146.148,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('60af1c679343690fa945084e'),
#  'confidence': 56,
#  'date': '08/12/2018',
#  'datetime': '2018-12-08T13:11:43',
#  'latitude': -36.291,
#  'longitude': 146.159,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c679343690fa945084f'),
#  'confidence': 52,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'_id': ObjectId('60af1c679343690fa9450850'),
#  'confidence': 100,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:36',
#  'latitude': -37.591,
#  'longitude': 149.33,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c679343690fa9450851'),
#  'confidence': 51,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c679343690fa9450852'),
#  'confidence': 64,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c679343690fa9450853'),
#  'confidence': 100,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:35',
#  'latitude': -37.585,
#  'longitude': 149.336,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c679343690fa9450854'),
#  'confidence': 69,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c679343690fa9450855'),
#  'confidence': 100,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:35',
#  'latitude': -37.583,
#  'longitude': 149.316,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c679343690fa9450856'),
#  'confidence': 61,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'_id': ObjectId('60af1c679343690fa9450857'),
#  'confidence': 62,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('60af1c679343690fa9450858'),
#  'confidence': 64,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('60af1c679343690fa9450859'),
#  'confidence': 84,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T12:22:15',
#  'latitude': -37.596,
#  'longitude': 149.319,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c679343690fa945085a'),
#  'confidence': 81,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T12:22:15',
#  'latitude': -37.63,
#  'longitude': 149.232,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c679343690fa945085b'),
#  'confidence': 100,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T12:22:15',
#  'latitude': -37.644,
#  'longitude': 149.233,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c679343690fa945085c'),
#  'confidence': 100,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T12:22:15',
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c679343690fa945085d'),
#  'confidence': 100,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T12:22:14',
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c679343690fa945085e'),
#  'confidence': 84,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T04:35:00',
#  'latitude': -37.384,
#  'longitude': 149.336,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c679343690fa945085f'),
#  'confidence': 73,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T04:35:00',
#  'latitude': -37.389,
#  'longitude': 149.311,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c679343690fa9450860'),
#  'confidence': 98,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T04:34:57',
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('60af1c679343690fa9450861'),
#  'confidence': 81,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T04:34:57',
#  'latitude': -37.627,
#  'longitude': 149.261,
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('60af1c679343690fa9450862'),
#  'confidence': 84,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T04:34:57',
#  'latitude': -37.623,
#  'longitude': 149.284,
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('60af1c679343690fa9450863'),
#  'confidence': 99,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T04:34:57',
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('60af1c679343690fa9450864'),
#  'confidence': 69,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c679343690fa9450865'),
#  'confidence': 60,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c679343690fa9450866'),
#  'confidence': 83,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:20:53',
#  'latitude': -37.608,
#  'longitude': 149.282,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c679343690fa9450867'),
#  'confidence': 87,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:20:53',
#  'latitude': -37.62,
#  'longitude': 149.294,
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('60af1c679343690fa9450868'),
#  'confidence': 95,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:20:53',
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c679343690fa9450869'),
#  'confidence': 81,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:20:53',
#  'latitude': -37.61,
#  'longitude': 149.296,
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('60af1c679343690fa945086a'),
#  'confidence': 73,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:20:53',
#  'latitude': -37.603,
#  'longitude': 149.324,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c679343690fa945086b'),
#  'confidence': 81,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:20:53',
#  'latitude': -37.602,
#  'longitude': 149.311,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c679343690fa945086c'),
#  'confidence': 69,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c679343690fa945086d'),
#  'confidence': 64,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c679343690fa945086e'),
#  'confidence': 53,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c679343690fa945086f'),
#  'confidence': 100,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T13:17:24',
#  'latitude': -37.608,
#  'longitude': 149.292,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c679343690fa9450870'),
#  'confidence': 68,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c679343690fa9450871'),
#  'confidence': 52,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c679343690fa9450872'),
#  'confidence': 100,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T03:52:10',
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c679343690fa9450873'),
#  'confidence': 64,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c679343690fa9450874'),
#  'confidence': 97,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T03:52:10',
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c679343690fa9450875'),
#  'confidence': 99,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T03:52:10',
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('60af1c689343690fa9450876'),
#  'confidence': 50,
#  'date': '28/11/2018',
#  'datetime': '2018-11-28T00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450877'),
#  'confidence': 84,
#  'date': '23/11/2018',
#  'datetime': '2018-11-23T04:28:59',
#  'latitude': -37.946,
#  'longitude': 144.342,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c689343690fa9450878'),
#  'confidence': 93,
#  'date': '23/11/2018',
#  'datetime': '2018-11-23T04:28:59',
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450879'),
#  'confidence': 68,
#  'date': '23/11/2018',
#  'datetime': '2018-11-23T00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa945087a'),
#  'confidence': 63,
#  'date': '23/11/2018',
#  'datetime': '2018-11-23T00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c689343690fa945087b'),
#  'confidence': 70,
#  'date': '23/11/2018',
#  'datetime': '2018-11-23T00:14:24',
#  'latitude': -34.965,
#  'longitude': 142.031,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa945087c'),
#  'confidence': 84,
#  'date': '22/11/2018',
#  'datetime': '2018-11-22T03:46:00',
#  'latitude': -37.978,
#  'longitude': 145.623,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c689343690fa945087d'),
#  'confidence': 88,
#  'date': '22/11/2018',
#  'datetime': '2018-11-22T03:46:00',
#  'latitude': -37.976,
#  'longitude': 145.649,
#  'surface_temperature_celcius': 64}
# {'_id': ObjectId('60af1c689343690fa945087e'),
#  'confidence': 85,
#  'date': '21/11/2018',
#  'datetime': '2018-11-21T00:27:21',
#  'latitude': -37.758,
#  'longitude': 144.693,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c689343690fa945087f'),
#  'confidence': 87,
#  'date': '14/11/2018',
#  'datetime': '2018-11-14T04:35:04',
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450880'),
#  'confidence': 64,
#  'date': '14/11/2018',
#  'datetime': '2018-11-14T00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa9450881'),
#  'confidence': 64,
#  'date': '14/11/2018',
#  'datetime': '2018-11-14T00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa9450882'),
#  'confidence': 87,
#  'date': '13/11/2018',
#  'datetime': '2018-11-13T03:52:15',
#  'latitude': -37.621,
#  'longitude': 143.447,
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('60af1c689343690fa9450883'),
#  'confidence': 81,
#  'date': '13/11/2018',
#  'datetime': '2018-11-13T03:52:14',
#  'latitude': -37.614,
#  'longitude': 143.451,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c689343690fa9450884'),
#  'confidence': 64,
#  'date': '13/11/2018',
#  'datetime': '2018-11-13T03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450885'),
#  'confidence': 51,
#  'date': '13/11/2018',
#  'datetime': '2018-11-13T01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa9450886'),
#  'confidence': 62,
#  'date': '13/11/2018',
#  'datetime': '2018-11-13T01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450887'),
#  'confidence': 63,
#  'date': '12/11/2018',
#  'datetime': '2018-11-12T04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c689343690fa9450888'),
#  'confidence': 58,
#  'date': '12/11/2018',
#  'datetime': '2018-11-12T04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450889'),
#  'confidence': 56,
#  'date': '12/11/2018',
#  'datetime': '2018-11-12T04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa945088a'),
#  'confidence': 67,
#  'date': '12/11/2018',
#  'datetime': '2018-11-12T00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa945088b'),
#  'confidence': 89,
#  'date': '12/11/2018',
#  'datetime': '2018-11-12T00:33:15',
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa945088c'),
#  'confidence': 51,
#  'date': '11/11/2018',
#  'datetime': '2018-11-11T15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('60af1c689343690fa945088d'),
#  'confidence': 80,
#  'date': '11/11/2018',
#  'datetime': '2018-11-11T13:30:08',
#  'latitude': -36.941,
#  'longitude': 143.268,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('60af1c689343690fa945088e'),
#  'confidence': 100,
#  'date': '11/11/2018',
#  'datetime': '2018-11-11T13:30:08',
#  'latitude': -36.939,
#  'longitude': 143.28,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c689343690fa945088f'),
#  'confidence': 86,
#  'date': '11/11/2018',
#  'datetime': '2018-11-11T04:04:25',
#  'latitude': -37.863,
#  'longitude': 144.17,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c689343690fa9450890'),
#  'confidence': 68,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:56',
#  'latitude': -36.759,
#  'longitude': 145.179,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('60af1c689343690fa9450891'),
#  'confidence': 62,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:56',
#  'latitude': -36.758,
#  'longitude': 145.19,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c689343690fa9450892'),
#  'confidence': 75,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:53',
#  'latitude': -37.213,
#  'longitude': 142.941,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c689343690fa9450893'),
#  'confidence': 85,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:48',
#  'latitude': -37.479,
#  'longitude': 143.358,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c689343690fa9450894'),
#  'confidence': 72,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:48',
#  'latitude': -37.467,
#  'longitude': 143.351,
#  'surface_temperature_celcius': 47}
# {'_id': ObjectId('60af1c689343690fa9450895'),
#  'confidence': 100,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:48',
#  'latitude': -37.477,
#  'longitude': 143.352,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa9450896'),
#  'confidence': 96,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:48',
#  'latitude': -37.475,
#  'longitude': 143.365,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450897'),
#  'confidence': 63,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:46',
#  'latitude': -37.719,
#  'longitude': 142.154,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450898'),
#  'confidence': 87,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:44',
#  'latitude': -37.692,
#  'longitude': 143.593,
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('60af1c689343690fa9450899'),
#  'confidence': 97,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:44',
#  'latitude': -37.69,
#  'longitude': 143.605,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa945089a'),
#  'confidence': 60,
#  'date': '08/11/2018',
#  'datetime': '2018-11-08T05:12:08',
#  'latitude': -36.538,
#  'longitude': 141.129,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa945089b'),
#  'confidence': 72,
#  'date': '08/11/2018',
#  'datetime': '2018-11-08T05:12:08',
#  'latitude': -36.543,
#  'longitude': 141.138,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa945089c'),
#  'confidence': 83,
#  'date': '05/11/2018',
#  'datetime': '2018-11-05T04:41:34',
#  'latitude': -36.341,
#  'longitude': 143.636,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c689343690fa945089d'),
#  'confidence': 71,
#  'date': '05/11/2018',
#  'datetime': '2018-11-05T04:41:34',
#  'latitude': -36.346,
#  'longitude': 143.631,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa945089e'),
#  'confidence': 90,
#  'date': '05/11/2018',
#  'datetime': '2018-11-05T04:41:19',
#  'latitude': -37.331,
#  'longitude': 143.122,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa945089f'),
#  'confidence': 89,
#  'date': '05/11/2018',
#  'datetime': '2018-11-05T04:41:19',
#  'latitude': -37.329,
#  'longitude': 143.136,
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('60af1c689343690fa94508a0'),
#  'confidence': 81,
#  'date': '28/10/2018',
#  'datetime': '2018-10-28T03:52:17',
#  'latitude': -37.34,
#  'longitude': 143.123,
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('60af1c689343690fa94508a1'),
#  'confidence': 62,
#  'date': '27/10/2018',
#  'datetime': '2018-10-27T04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94508a2'),
#  'confidence': 78,
#  'date': '27/10/2018',
#  'datetime': '2018-10-27T04:47:31',
#  'latitude': -36.752,
#  'longitude': 144.15,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c689343690fa94508a3'),
#  'confidence': 86,
#  'date': '27/10/2018',
#  'datetime': '2018-10-27T04:47:31',
#  'latitude': -36.759,
#  'longitude': 144.158,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c689343690fa94508a4'),
#  'confidence': 78,
#  'date': '27/10/2018',
#  'datetime': '2018-10-27T00:33:09',
#  'latitude': -36.764,
#  'longitude': 144.165,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa94508a5'),
#  'confidence': 74,
#  'date': '27/10/2018',
#  'datetime': '2018-10-27T00:33:09',
#  'latitude': -36.765,
#  'longitude': 144.176,
#  'surface_temperature_celcius': 47}
# {'_id': ObjectId('60af1c689343690fa94508a6'),
#  'confidence': 77,
#  'date': '26/10/2018',
#  'datetime': '2018-10-26T13:30:31',
#  'latitude': -35.325,
#  'longitude': 143.497,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('60af1c689343690fa94508a7'),
#  'confidence': 100,
#  'date': '26/10/2018',
#  'datetime': '2018-10-26T13:30:31',
#  'latitude': -35.321,
#  'longitude': 143.502,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa94508a8'),
#  'confidence': 100,
#  'date': '26/10/2018',
#  'datetime': '2018-10-26T13:30:31',
#  'latitude': -35.323,
#  'longitude': 143.509,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c689343690fa94508a9'),
#  'confidence': 67,
#  'date': '26/10/2018',
#  'datetime': '2018-10-26T04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94508aa'),
#  'confidence': 69,
#  'date': '26/10/2018',
#  'datetime': '2018-10-26T04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94508ab'),
#  'confidence': 72,
#  'date': '23/10/2018',
#  'datetime': '2018-10-23T00:57:55',
#  'latitude': -37.297,
#  'longitude': 144.384,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa94508ac'),
#  'confidence': 77,
#  'date': '21/10/2018',
#  'datetime': '2018-10-21T01:09:55',
#  'latitude': -36.1,
#  'longitude': 143.767,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94508ad'),
#  'confidence': 88,
#  'date': '21/10/2018',
#  'datetime': '2018-10-21T01:09:55',
#  'latitude': -36.098,
#  'longitude': 143.735,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c689343690fa94508ae'),
#  'confidence': 65,
#  'date': '21/10/2018',
#  'datetime': '2018-10-21T01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa94508af'),
#  'confidence': 92,
#  'date': '21/10/2018',
#  'datetime': '2018-10-21T01:09:54',
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa94508b0'),
#  'confidence': 80,
#  'date': '20/10/2018',
#  'datetime': '2018-10-20T04:41:19',
#  'latitude': -37.586,
#  'longitude': 141.271,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa94508b1'),
#  'confidence': 82,
#  'date': '20/10/2018',
#  'datetime': '2018-10-20T04:41:19',
#  'latitude': -37.588,
#  'longitude': 141.259,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa94508b2'),
#  'confidence': 65,
#  'date': '20/10/2018',
#  'datetime': '2018-10-20T00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa94508b3'),
#  'confidence': 79,
#  'date': '18/10/2018',
#  'datetime': '2018-10-18T00:39:27',
#  'latitude': -37.287,
#  'longitude': 144.392,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa94508b4'),
#  'confidence': 75,
#  'date': '18/10/2018',
#  'datetime': '2018-10-18T00:39:27',
#  'latitude': -37.295,
#  'longitude': 144.377,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa94508b5'),
#  'confidence': 72,
#  'date': '18/10/2018',
#  'datetime': '2018-10-18T00:39:03',
#  'latitude': -35.364,
#  'longitude': 141.063,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa94508b6'),
#  'confidence': 84,
#  'date': '18/10/2018',
#  'datetime': '2018-10-18T00:39:02',
#  'latitude': -35.89,
#  'longitude': 145.606,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c689343690fa94508b7'),
#  'confidence': 82,
#  'date': '18/10/2018',
#  'datetime': '2018-10-18T00:39:02',
#  'latitude': -35.889,
#  'longitude': 145.614,
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('60af1c689343690fa94508b8'),
#  'confidence': 71,
#  'date': '18/10/2018',
#  'datetime': '2018-10-18T00:39:02',
#  'latitude': -35.892,
#  'longitude': 145.62,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa94508b9'),
#  'confidence': 94,
#  'date': '17/10/2018',
#  'datetime': '2018-10-17T13:36:12',
#  'latitude': -37.247,
#  'longitude': 141.27,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94508ba'),
#  'confidence': 73,
#  'date': '17/10/2018',
#  'datetime': '2018-10-17T04:10:59',
#  'latitude': -35.937,
#  'longitude': 145.607,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c689343690fa94508bb'),
#  'confidence': 91,
#  'date': '17/10/2018',
#  'datetime': '2018-10-17T04:10:45',
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa94508bc'),
#  'confidence': 58,
#  'date': '17/10/2018',
#  'datetime': '2018-10-17T04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94508bd'),
#  'confidence': 82,
#  'date': '17/10/2018',
#  'datetime': '2018-10-17T04:10:32',
#  'latitude': -37.805,
#  'longitude': 144.15,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa94508be'),
#  'confidence': 62,
#  'date': '16/10/2018',
#  'datetime': '2018-10-16T23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('60af1c689343690fa94508bf'),
#  'confidence': 100,
#  'date': '15/10/2018',
#  'datetime': '2018-10-15T04:23:01',
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c689343690fa94508c0'),
#  'confidence': 99,
#  'date': '15/10/2018',
#  'datetime': '2018-10-15T04:23:01',
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('60af1c689343690fa94508c1'),
#  'confidence': 78,
#  'date': '15/10/2018',
#  'datetime': '2018-10-15T00:08:42',
#  'latitude': -36.851,
#  'longitude': 148.117,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa94508c2'),
#  'confidence': 72,
#  'date': '10/10/2018',
#  'datetime': '2018-10-10T04:04:34',
#  'latitude': -37.249,
#  'longitude': 143.413,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94508c3'),
#  'confidence': 96,
#  'date': '10/10/2018',
#  'datetime': '2018-10-10T04:04:19',
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa94508c4'),
#  'confidence': 76,
#  'date': '10/10/2018',
#  'datetime': '2018-10-10T04:04:19',
#  'latitude': -38.116,
#  'longitude': 143.818,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94508c5'),
#  'confidence': 78,
#  'date': '09/10/2018',
#  'datetime': '2018-10-09T00:45:42',
#  'latitude': -37.245,
#  'longitude': 143.426,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94508c6'),
#  'confidence': 72,
#  'date': '08/10/2018',
#  'datetime': '2018-10-08T04:16:48',
#  'latitude': -37.091,
#  'longitude': 145.362,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94508c7'),
#  'confidence': 91,
#  'date': '07/10/2018',
#  'datetime': '2018-10-07T12:59:33',
#  'latitude': -37.087,
#  'longitude': 145.363,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94508c8'),
#  'confidence': 76,
#  'date': '06/10/2018',
#  'datetime': '2018-10-06T04:29:25',
#  'latitude': -35.962,
#  'longitude': 143.791,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94508c9'),
#  'confidence': 77,
#  'date': '06/10/2018',
#  'datetime': '2018-10-06T04:29:13',
#  'latitude': -36.498,
#  'longitude': 144.877,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa94508ca'),
#  'confidence': 50,
#  'date': '04/10/2018',
#  'datetime': '2018-10-04T04:41:36',
#  'latitude': -36.418,
#  'longitude': 141.596,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94508cb'),
#  'confidence': 80,
#  'date': '04/10/2018',
#  'datetime': '2018-10-04T04:41:02',
#  'latitude': -37.38,
#  'longitude': 148.053,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa94508cc'),
#  'confidence': 80,
#  'date': '04/10/2018',
#  'datetime': '2018-10-04T04:41:00',
#  'latitude': -37.466,
#  'longitude': 148.143,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa94508cd'),
#  'confidence': 85,
#  'date': '04/10/2018',
#  'datetime': '2018-10-04T04:41:00',
#  'latitude': -37.472,
#  'longitude': 148.119,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa94508ce'),
#  'confidence': 88,
#  'date': '04/10/2018',
#  'datetime': '2018-10-04T04:41:00',
#  'latitude': -37.469,
#  'longitude': 148.125,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c689343690fa94508cf'),
#  'confidence': 69,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T15:01:44',
#  'latitude': -37.461,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('60af1c689343690fa94508d0'),
#  'confidence': 92,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T13:23:43',
#  'latitude': -37.459,
#  'longitude': 148.092,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94508d1'),
#  'confidence': 68,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:28',
#  'latitude': -37.236,
#  'longitude': 141.176,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('60af1c689343690fa94508d2'),
#  'confidence': 59,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:28',
#  'latitude': -37.227,
#  'longitude': 141.151,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa94508d3'),
#  'confidence': 77,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:28',
#  'latitude': -37.242,
#  'longitude': 141.153,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94508d4'),
#  'confidence': 76,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:28',
#  'latitude': -37.238,
#  'longitude': 141.145,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94508d5'),
#  'confidence': 90,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:15',
#  'latitude': -37.365,
#  'longitude': 148.052,
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('60af1c689343690fa94508d6'),
#  'confidence': 81,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:15',
#  'latitude': -37.376,
#  'longitude': 148.042,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa94508d7'),
#  'confidence': 82,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:15',
#  'latitude': -37.375,
#  'longitude': 148.054,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa94508d8'),
#  'confidence': 84,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:15',
#  'latitude': -37.386,
#  'longitude': 148.043,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa94508d9'),
#  'confidence': 90,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:15',
#  'latitude': -37.384,
#  'longitude': 148.056,
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('60af1c689343690fa94508da'),
#  'confidence': 71,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:15',
#  'latitude': -37.367,
#  'longitude': 148.04,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa94508db'),
#  'confidence': 71,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:14',
#  'latitude': -37.471,
#  'longitude': 148.091,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa94508dc'),
#  'confidence': 100,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:14',
#  'latitude': -37.462,
#  'longitude': 148.089,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa94508dd'),
#  'confidence': 88,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:14',
#  'latitude': -37.46,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa94508de'),
#  'confidence': 87,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:14',
#  'latitude': -37.469,
#  'longitude': 148.103,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c689343690fa94508df'),
#  'confidence': 73,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T01:22:44',
#  'latitude': -37.229,
#  'longitude': 141.182,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94508e0'),
#  'confidence': 54,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T01:22:44',
#  'latitude': -37.227,
#  'longitude': 141.146,
#  'surface_temperature_celcius': 31}
# {'_id': ObjectId('60af1c689343690fa94508e1'),
#  'confidence': 50,
#  'date': '02/10/2018',
#  'datetime': '2018-10-02T23:44:31',
#  'latitude': -37.466,
#  'longitude': 148.1,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('60af1c689343690fa94508e2'),
#  'confidence': 59,
#  'date': '02/10/2018',
#  'datetime': '2018-10-02T04:53:10',
#  'latitude': -37.475,
#  'longitude': 148.134,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94508e3'),
#  'confidence': 83,
#  'date': '02/10/2018',
#  'datetime': '2018-10-02T04:53:10',
#  'latitude': -37.47,
#  'longitude': 148.089,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa94508e4'),
#  'confidence': 71,
#  'date': '02/10/2018',
#  'datetime': '2018-10-02T04:53:10',
#  'latitude': -37.485,
#  'longitude': 148.095,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94508e5'),
#  'confidence': 85,
#  'date': '02/10/2018',
#  'datetime': '2018-10-02T04:53:09',
#  'latitude': -37.477,
#  'longitude': 148.097,
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('60af1c689343690fa94508e6'),
#  'confidence': 76,
#  'date': '02/10/2018',
#  'datetime': '2018-10-02T00:39:34',
#  'latitude': -37.461,
#  'longitude': 148.105,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94508e7'),
#  'confidence': 68,
#  'date': '02/10/2018',
#  'datetime': '2018-10-02T00:39:34',
#  'latitude': -37.456,
#  'longitude': 148.11,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94508e8'),
#  'confidence': 62,
#  'date': '01/10/2018',
#  'datetime': '2018-10-01T15:13:56',
#  'latitude': -37.463,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 34}
# {'_id': ObjectId('60af1c689343690fa94508e9'),
#  'confidence': 100,
#  'date': '01/10/2018',
#  'datetime': '2018-10-01T15:13:56',
#  'latitude': -37.453,
#  'longitude': 148.111,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa94508ea'),
#  'confidence': 77,
#  'date': '01/10/2018',
#  'datetime': '2018-10-01T13:36:02',
#  'latitude': -37.461,
#  'longitude': 148.103,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('60af1c689343690fa94508eb'),
#  'confidence': 79,
#  'date': '01/10/2018',
#  'datetime': '2018-10-01T04:10:30',
#  'latitude': -37.368,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c689343690fa94508ec'),
#  'confidence': 84,
#  'date': '01/10/2018',
#  'datetime': '2018-10-01T04:10:28',
#  'latitude': -37.478,
#  'longitude': 148.117,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('60af1c689343690fa94508ed'),
#  'confidence': 89,
#  'date': '01/10/2018',
#  'datetime': '2018-10-01T04:10:28',
#  'latitude': -37.467,
#  'longitude': 148.127,
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('60af1c689343690fa94508ee'),
#  'confidence': 64,
#  'date': '01/10/2018',
#  'datetime': '2018-10-01T04:10:28',
#  'latitude': -37.46,
#  'longitude': 148.113,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('60af1c689343690fa94508ef'),
#  'confidence': 78,
#  'date': '01/10/2018',
#  'datetime': '2018-10-01T04:10:28',
#  'latitude': -37.453,
#  'longitude': 148.099,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94508f0'),
#  'confidence': 70,
#  'date': '29/09/2018',
#  'datetime': '2018-09-29T04:22:41',
#  'latitude': -37.45,
#  'longitude': 148.097,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('60af1c689343690fa94508f1'),
#  'confidence': 82,
#  'date': '29/09/2018',
#  'datetime': '2018-09-29T04:22:31',
#  'latitude': -38.226,
#  'longitude': 147.167,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa94508f2'),
#  'confidence': 78,
#  'date': '27/09/2018',
#  'datetime': '2018-09-27T04:35:36',
#  'latitude': -35.954,
#  'longitude': 141.076,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa94508f3'),
#  'confidence': 83,
#  'date': '27/09/2018',
#  'datetime': '2018-09-27T04:35:36',
#  'latitude': -35.961,
#  'longitude': 141.089,
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('60af1c689343690fa94508f4'),
#  'confidence': 86,
#  'date': '27/09/2018',
#  'datetime': '2018-09-27T04:35:36',
#  'latitude': -35.963,
#  'longitude': 141.078,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c689343690fa94508f5'),
#  'confidence': 72,
#  'date': '27/09/2018',
#  'datetime': '2018-09-27T04:35:27',
#  'latitude': -36.275,
#  'longitude': 142.785,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa94508f6'),
#  'confidence': 65,
#  'date': '27/09/2018',
#  'datetime': '2018-09-27T04:35:18',
#  'latitude': -36.398,
#  'longitude': 145.286,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94508f7'),
#  'confidence': 79,
#  'date': '27/09/2018',
#  'datetime': '2018-09-27T00:21:05',
#  'latitude': -35.953,
#  'longitude': 141.078,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa94508f8'),
#  'confidence': 79,
#  'date': '27/09/2018',
#  'datetime': '2018-09-27T00:21:05',
#  'latitude': -35.957,
#  'longitude': 141.088,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa94508f9'),
#  'confidence': 64,
#  'date': '26/09/2018',
#  'datetime': '2018-09-26T03:52:14',
#  'latitude': -37.087,
#  'longitude': 145.37,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('60af1c689343690fa94508fa'),
#  'confidence': 76,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:50',
#  'latitude': -37.758,
#  'longitude': 148.721,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa94508fb'),
#  'confidence': 73,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:49',
#  'latitude': -37.561,
#  'longitude': 148.032,
#  'surface_temperature_celcius': 34}
# {'_id': ObjectId('60af1c689343690fa94508fc'),
#  'confidence': 100,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:47',
#  'latitude': -37.446,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa94508fd'),
#  'confidence': 72,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:47',
#  'latitude': -37.448,
#  'longitude': 148.114,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c689343690fa94508fe'),
#  'confidence': 71,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:47',
#  'latitude': -37.453,
#  'longitude': 148.118,
#  'surface_temperature_celcius': 34}
# {'_id': ObjectId('60af1c689343690fa94508ff'),
#  'confidence': 90,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:47',
#  'latitude': -37.457,
#  'longitude': 148.143,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450900'),
#  'confidence': 99,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:47',
#  'latitude': -37.437,
#  'longitude': 148.104,
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('60af1c689343690fa9450901'),
#  'confidence': 70,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:47',
#  'latitude': -37.434,
#  'longitude': 148.091,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('60af1c689343690fa9450902'),
#  'confidence': 74,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:46',
#  'latitude': -37.538,
#  'longitude': 148.895,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa9450903'),
#  'confidence': 94,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:45',
#  'latitude': -37.333,
#  'longitude': 148.099,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450904'),
#  'confidence': 100,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T15:07:45',
#  'latitude': -37.33,
#  'longitude': 148.087,
#  'surface_temperature_celcius': 61}
# {'_id': ObjectId('60af1c689343690fa9450905'),
#  'confidence': 100,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T13:30:10',
#  'latitude': -37.327,
#  'longitude': 148.083,
#  'surface_temperature_celcius': 47}
# {'_id': ObjectId('60af1c689343690fa9450906'),
#  'confidence': 59,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T13:30:09',
#  'latitude': -37.375,
#  'longitude': 148.063,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa9450907'),
#  'confidence': 82,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T13:30:09',
#  'latitude': -37.336,
#  'longitude': 148.073,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa9450908'),
#  'confidence': 100,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T13:30:09',
#  'latitude': -37.332,
#  'longitude': 148.091,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa9450909'),
#  'confidence': 100,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T13:30:09',
#  'latitude': -37.363,
#  'longitude': 148.06,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa945090a'),
#  'confidence': 84,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T13:30:07',
#  'latitude': -37.438,
#  'longitude': 148.09,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa945090b'),
#  'confidence': 100,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:19',
#  'latitude': -37.406,
#  'longitude': 148.123,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('60af1c689343690fa945090c'),
#  'confidence': 58,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:19',
#  'latitude': -37.397,
#  'longitude': 148.121,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c689343690fa945090d'),
#  'confidence': 68,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:18',
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa945090e'),
#  'confidence': 68,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:18',
#  'latitude': -37.465,
#  'longitude': 148.153,
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('60af1c689343690fa945090f'),
#  'confidence': 64,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:18',
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450910'),
#  'confidence': 86,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:18',
#  'latitude': -37.436,
#  'longitude': 148.088,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450911'),
#  'confidence': 73,
# ...
#  'longitude': 146.0807,
#  'surface_temperature_celcius': 111}
# {'_id': ObjectId('60af1c689343690fa9451246'),
#  'confidence': 95,
#  'date': '25/03/2018',
#  'datetime': '2018-03-25T03:57:10',
#  'latitude': -37.8774,
#  'longitude': 145.8213,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9451247'),
#  'confidence': 75,
#  'date': '25/03/2018',
#  'datetime': '2018-03-25T03:56:50',
#  'latitude': -37.5742,
#  'longitude': 144.7536,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa9451248'),
#  'confidence': 100,
#  'date': '25/03/2018',
#  'datetime': '2018-03-25T03:56:40',
#  'latitude': -37.8881,
#  'longitude': 145.8229,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('60af1c689343690fa9451249'),
#  'confidence': 73,
#  'date': '25/03/2018',
#  'datetime': '2018-03-25T03:56:40',
#  'latitude': -37.5612,
#  'longitude': 144.7701,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa945124a'),
#  'confidence': 57,
#  'date': '25/03/2018',
#  'datetime': '2018-03-25T03:56:40',
#  'latitude': -37.9022,
#  'longitude': 143.4607,
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('60af1c689343690fa945124b'),
#  'confidence': 65,
#  'date': '24/03/2018',
#  'datetime': '2018-03-24T04:58:00',
#  'latitude': -37.1603,
#  'longitude': 142.8088,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa945124c'),
#  'confidence': 55,
#  'date': '24/03/2018',
#  'datetime': '2018-03-24T04:56:10',
#  'latitude': -37.1684,
#  'longitude': 142.8183,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa945124d'),
#  'confidence': 85,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:39:50',
#  'latitude': -37.6605,
#  'longitude': 142.1116,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c689343690fa945124e'),
#  'confidence': 58,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:39:20',
#  'latitude': -37.9164,
#  'longitude': 143.4866,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa945124f'),
#  'confidence': 96,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:39:20',
#  'latitude': -37.6622,
#  'longitude': 142.1001,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa9451250'),
#  'confidence': 63,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:39:20',
#  'latitude': -37.9257,
#  'longitude': 143.4891,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa9451251'),
#  'confidence': 64,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:36:00',
#  'latitude': -37.3982,
#  'longitude': 147.0001,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c689343690fa9451252'),
#  'confidence': 90,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:36:00',
#  'latitude': -37.4523,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9451253'),
#  'confidence': 59,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:35:00',
#  'latitude': -37.4023,
#  'longitude': 147.0394,
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('60af1c689343690fa9451254'),
#  'confidence': 60,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:33:50',
#  'latitude': -37.4336,
#  'longitude': 147.0534,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c689343690fa9451255'),
#  'confidence': 61,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:33:30',
#  'latitude': -37.4003,
#  'longitude': 147.0448,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa9451256'),
#  'confidence': 53,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:33:30',
#  'latitude': -37.9184,
#  'longitude': 143.4745,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa9451257'),
#  'confidence': 61,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:33:10',
#  'latitude': -37.3911,
#  'longitude': 147.037,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa9451258'),
#  'confidence': 98,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:33:00',
#  'latitude': -37.4261,
#  'longitude': 147.0323,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('60af1c689343690fa9451259'),
#  'confidence': 100,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:32:50',
#  'latitude': -37.3949,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 91}
# {'_id': ObjectId('60af1c689343690fa945125a'),
#  'confidence': 84,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:32:50',
#  'latitude': -37.671,
#  'longitude': 144.6536,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c689343690fa945125b'),
#  'confidence': 66,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:32:50',
#  'latitude': -37.9277,
#  'longitude': 143.477,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa945125c'),
#  'confidence': 100,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:32:40',
#  'latitude': -37.4224,
#  'longitude': 147.0511,
#  'surface_temperature_celcius': 113}
# {'_id': ObjectId('60af1c689343690fa945125d'),
#  'confidence': 92,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:32:40',
#  'latitude': -37.6625,
#  'longitude': 144.287,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa945125e'),
#  'confidence': 100,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:32:40',
#  'latitude': -37.4375,
#  'longitude': 147.0336,
#  'surface_temperature_celcius': 106}
# {'_id': ObjectId('60af1c689343690fa945125f'),
#  'confidence': 73,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:32:40',
#  'latitude': -37.4414,
#  'longitude': 147.0139,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c689343690fa9451260'),
#  'confidence': 77,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T00:15:50',
#  'latitude': -37.4295,
#  'longitude': 147.0428,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c689343690fa9451261'),
#  'confidence': 60,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T00:12:50',
#  'latitude': -37.3942,
#  'longitude': 147.0455,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9451262'),
#  'confidence': 64,
#  'date': '18/03/2018',
#  'datetime': '2018-03-18T13:16:50',
#  'latitude': -37.4313,
#  'longitude': 147.0343,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('60af1c689343690fa9451263'),
#  'confidence': 100,
#  'date': '18/03/2018',
#  'datetime': '2018-03-18T03:50:50',
#  'latitude': -37.017,
#  'longitude': 148.1297,
#  'surface_temperature_celcius': 121}
# {'_id': ObjectId('60af1c689343690fa9451264'),
#  'confidence': 97,
#  'date': '18/03/2018',
#  'datetime': '2018-03-18T03:50:40',
#  'latitude': -37.0155,
#  'longitude': 148.1432,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9451265'),
#  'confidence': 76,
#  'date': '17/03/2018',
#  'datetime': '2018-03-17T04:48:20',
#  'latitude': -34.3383,
#  'longitude': 141.543,
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('60af1c689343690fa9451266'),
#  'confidence': 94,
#  'date': '17/03/2018',
#  'datetime': '2018-03-17T04:48:20',
#  'latitude': -36.7152,
#  'longitude': 141.3853,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('60af1c689343690fa9451267'),
#  'confidence': 78,
#  'date': '17/03/2018',
#  'datetime': '2018-03-17T04:46:40',
#  'latitude': -34.328,
#  'longitude': 141.5402,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c689343690fa9451268'),
#  'confidence': 84,
#  'date': '17/03/2018',
#  'datetime': '2018-03-17T04:45:10',
#  'latitude': -36.6867,
#  'longitude': 141.137,
#  'surface_temperature_celcius': 59}
# {'_id': ObjectId('60af1c689343690fa9451269'),
#  'confidence': 76,
#  'date': '17/03/2018',
#  'datetime': '2018-03-17T04:45:00',
#  'latitude': -36.6889,
#  'longitude': 141.1239,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa945126a'),
#  'confidence': 86,
#  'date': '17/03/2018',
#  'datetime': '2018-03-17T04:45:00',
#  'latitude': -36.7128,
#  'longitude': 141.3986,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c689343690fa945126b'),
#  'confidence': 76,
#  'date': '15/03/2018',
#  'datetime': '2018-03-15T05:02:00',
#  'latitude': -37.4108,
#  'longitude': 147.0196,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa945126c'),
#  'confidence': 74,
#  'date': '15/03/2018',
#  'datetime': '2018-03-15T04:59:10',
#  'latitude': -37.4058,
#  'longitude': 147.0117,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa945126d'),
#  'confidence': 52,
#  'date': '15/03/2018',
#  'datetime': '2018-03-15T00:42:50',
#  'latitude': -37.4075,
#  'longitude': 147.0233,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa945126e'),
#  'confidence': 66,
#  'date': '15/03/2018',
#  'datetime': '2018-03-15T00:42:50',
#  'latitude': -37.0228,
#  'longitude': 148.1281,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa945126f'),
#  'confidence': 51,
#  'date': '15/03/2018',
#  'datetime': '2018-03-15T00:42:40',
#  'latitude': -37.002,
#  'longitude': 148.2055,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9451270'),
#  'confidence': 75,
#  'date': '15/03/2018',
#  'datetime': '2018-03-15T00:38:10',
#  'latitude': -37.0249,
#  'longitude': 148.1561,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa9451271'),
#  'confidence': 70,
#  'date': '15/03/2018',
#  'datetime': '2018-03-15T00:37:20',
#  'latitude': -37.4098,
#  'longitude': 147.0489,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa9451272'),
#  'confidence': 90,
#  'date': '14/03/2018',
#  'datetime': '2018-03-14T04:24:40',
#  'latitude': -34.357,
#  'longitude': 141.5361,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9451273'),
#  'confidence': 93,
#  'date': '14/03/2018',
#  'datetime': '2018-03-14T04:22:20',
#  'latitude': -34.3539,
#  'longitude': 141.5547,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9451274'),
#  'confidence': 90,
#  'date': '14/03/2018',
#  'datetime': '2018-03-14T04:20:50',
#  'latitude': -36.9939,
#  'longitude': 148.2244,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9451275'),
#  'confidence': 73,
#  'date': '14/03/2018',
#  'datetime': '2018-03-14T04:19:30',
#  'latitude': -36.998,
#  'longitude': 148.1994,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa9451276'),
#  'confidence': 95,
#  'date': '14/03/2018',
#  'datetime': '2018-03-14T04:16:30',
#  'latitude': -36.9959,
#  'longitude': 148.2118,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa9451277'),
#  'confidence': 89,
#  'date': '14/03/2018',
#  'datetime': '2018-03-14T04:16:20',
#  'latitude': -34.3654,
#  'longitude': 141.543,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9451278'),
#  'confidence': 73,
#  'date': '14/03/2018',
#  'datetime': '2018-03-14T04:14:40',
#  'latitude': -37.0228,
#  'longitude': 148.1996,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('60af1c689343690fa9451279'),
#  'confidence': 81,
#  'date': '14/03/2018',
#  'datetime': '2018-03-14T04:14:40',
#  'latitude': -34.3539,
#  'longitude': 141.5629,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa945127a'),
#  'confidence': 96,
#  'date': '14/03/2018',
#  'datetime': '2018-03-14T04:14:30',
#  'latitude': -34.3554,
#  'longitude': 141.5413,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa945127b'),
#  'confidence': 94,
#  'date': '14/03/2018',
#  'datetime': '2018-03-14T04:14:30',
#  'latitude': -34.3555,
#  'longitude': 141.5495,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa945127c'),
#  'confidence': 56,
#  'date': '13/03/2018',
#  'datetime': '2018-03-13T23:58:50',
#  'latitude': -37.0286,
#  'longitude': 148.155,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa945127d'),
#  'confidence': 52,
#  'date': '13/03/2018',
#  'datetime': '2018-03-13T12:57:00',
#  'latitude': -37.0316,
#  'longitude': 148.1519,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa945127e'),
#  'confidence': 94,
#  'date': '12/03/2018',
#  'datetime': '2018-03-12T04:33:50',
#  'latitude': -37.4157,
#  'longitude': 147.0084,
#  'surface_temperature_celcius': 105}
# {'_id': ObjectId('60af1c689343690fa945127f'),
#  'confidence': 84,
#  'date': '12/03/2018',
#  'datetime': '2018-03-12T04:29:50',
#  'latitude': -37.0193,
#  'longitude': 148.1459,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa9451280'),
#  'confidence': 100,
#  'date': '12/03/2018',
#  'datetime': '2018-03-12T04:28:20',
#  'latitude': -37.4229,
#  'longitude': 147.027,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('60af1c689343690fa9451281'),
#  'confidence': 80,
#  'date': '12/03/2018',
#  'datetime': '2018-03-12T04:28:00',
#  'latitude': -37.0055,
#  'longitude': 148.1582,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9451282'),
#  'confidence': 85,
#  'date': '12/03/2018',
#  'datetime': '2018-03-12T04:27:20',
#  'latitude': -37.4128,
#  'longitude': 147.0242,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('60af1c689343690fa9451283'),
#  'confidence': 100,
#  'date': '10/03/2018',
#  'datetime': '2018-03-10T04:48:40',
#  'latitude': -37.223,
#  'longitude': 147.9431,
#  'surface_temperature_celcius': 105}
# {'_id': ObjectId('60af1c689343690fa9451284'),
#  'confidence': 100,
#  'date': '10/03/2018',
#  'datetime': '2018-03-10T04:46:20',
#  'latitude': -37.2252,
#  'longitude': 147.9363,
#  'surface_temperature_celcius': 109}
# {'_id': ObjectId('60af1c689343690fa9451285'),
#  'confidence': 94,
#  'date': '10/03/2018',
#  'datetime': '2018-03-10T04:45:30',
#  'latitude': -37.2284,
#  'longitude': 147.9187,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9451286'),
#  'confidence': 97,
#  'date': '10/03/2018',
#  'datetime': '2018-03-10T04:45:30',
#  'latitude': -37.6572,
#  'longitude': 142.0703,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9451287'),
#  'confidence': 81,
#  'date': '10/03/2018',
#  'datetime': '2018-03-10T04:43:50',
#  'latitude': -37.6592,
#  'longitude': 142.058,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa9451288'),
#  'confidence': 55,
#  'date': '10/03/2018',
#  'datetime': '2018-03-10T04:43:00',
#  'latitude': -36.2544,
#  'longitude': 148.0353,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9451289'),
#  'confidence': 54,
#  'date': '10/03/2018',
#  'datetime': '2018-03-10T04:42:30',
#  'latitude': -37.2197,
#  'longitude': 147.9621,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa945128a'),
#  'confidence': 74,
#  'date': '10/03/2018',
#  'datetime': '2018-03-10T04:39:00',
#  'latitude': -37.2128,
#  'longitude': 147.9308,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa945128b'),
#  'confidence': 86,
#  'date': '09/03/2018',
#  'datetime': '2018-03-09T13:23:40',
#  'latitude': -37.996,
#  'longitude': 146.3535,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa945128c'),
#  'confidence': 54,
#  'date': '09/03/2018',
#  'datetime': '2018-03-09T03:57:00',
#  'latitude': -37.7171,
#  'longitude': 147.5866,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa945128d'),
#  'confidence': 78,
#  'date': '09/03/2018',
#  'datetime': '2018-03-09T03:56:50',
#  'latitude': -37.7074,
#  'longitude': 147.5849,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa945128e'),
#  'confidence': 68,
#  'date': '08/03/2018',
#  'datetime': '2018-03-08T04:51:00',
#  'latitude': -37.7885,
#  'longitude': 141.9352,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa945128f'),
#  'confidence': 75,
#  'date': '08/03/2018',
#  'datetime': '2018-03-08T00:30:30',
#  'latitude': -38.1031,
#  'longitude': 142.4797,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa9451290'),
#  'confidence': 88,
#  'date': '07/03/2018',
#  'datetime': '2018-03-07T04:16:10',
#  'latitude': -37.7752,
#  'longitude': 141.9086,
#  'surface_temperature_celcius': 64}
# {'_id': ObjectId('60af1c689343690fa9451291'),
#  'confidence': 87,
#  'date': '06/03/2018',
#  'datetime': '2018-03-06T05:06:30',
#  'latitude': -34.3795,
#  'longitude': 141.6331,
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('60af1c689343690fa9451292'),
#  'confidence': 85,
#  'date': '06/03/2018',
#  'datetime': '2018-03-06T05:06:20',
#  'latitude': -34.3735,
#  'longitude': 141.6604,
#  'surface_temperature_celcius': 59}

# %% [markdown]
# We can now move on to adding the references in `climates` documents

# %%
cursor = climates.find({})
for document in cursor: 
    #get the date
    date = document["date"]
    
    #find the document in fires with corresponding date
    fires_result = fires.find({"date": date})
    #array to store the fire documents' ID's
    fires_id_array = []
    for fire_doc in fires_result:
        #get the id
        fire_id = fire_doc["_id"]
        
        #append to array
        fires_id_array.append(fire_id)
            
        
    #add fire id's references in climate document 
    climate_id = document["_id"]
    
    
    result = climates.update_one({"_id": climate_id},
    { 
    "$set": {
        "fires": fires_id_array} 
    })

# %% [markdown]
# Check the documents in `climates` again

# %%
cursor = climates.find({})
for document in cursor: 
    pprint(document)
# Out:
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60af1c5e9343690fa94506b9'),
#  'air_temperature_celcius': 19,
#  'date': '31/12/2017',
#  'fires': [],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.8,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('60af1c5e9343690fa94506ba'),
#  'air_temperature_celcius': 15,
#  'date': '02/01/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 50.7,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('60af1c5e9343690fa94506bb'),
#  'air_temperature_celcius': 16,
#  'date': '03/01/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 186,
#  '_id': ObjectId('60af1c5e9343690fa94506bc'),
#  'air_temperature_celcius': 24,
#  'date': '04/01/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 61.6,
#  'station': 948700,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 185,
#  '_id': ObjectId('60af1c5e9343690fa94506bd'),
#  'air_temperature_celcius': 24,
#  'date': '05/01/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.3,
#  'station': 948700,
#  'windspeed_knots': 7.0}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('60af1c5e9343690fa94506be'),
#  'air_temperature_celcius': 26,
#  'date': '06/01/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.8,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 265,
#  '_id': ObjectId('60af1c5e9343690fa94506bf'),
#  'air_temperature_celcius': 32,
#  'date': '07/01/2018',
#  'fires': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 160,
#  '_id': ObjectId('60af1c5e9343690fa94506c0'),
#  'air_temperature_celcius': 20,
#  'date': '08/01/2018',
#  'fires': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 57.7,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60af1c5e9343690fa94506c1'),
#  'air_temperature_celcius': 19,
#  'date': '09/01/2018',
#  'fires': [],
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('60af1c5e9343690fa94506c2'),
#  'air_temperature_celcius': 20,
#  'date': '10/01/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa94506c3'),
#  'air_temperature_celcius': 18,
#  'date': '11/01/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.3,
#  'station': 948700,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 179,
#  '_id': ObjectId('60af1c5e9343690fa94506c4'),
#  'air_temperature_celcius': 22,
#  'date': '12/01/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 56.3,
#  'station': 948700,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 157,
#  '_id': ObjectId('60af1c5e9343690fa94506c5'),
#  'air_temperature_celcius': 19,
#  'date': '13/01/2018',
#  'fires': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60af1c5e9343690fa94506c6'),
#  'air_temperature_celcius': 17,
#  'date': '14/01/2018',
#  'fires': [],
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.4,
#  'station': 948700,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('60af1c5e9343690fa94506c7'),
#  'air_temperature_celcius': 16,
#  'date': '15/01/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 50.8,
#  'station': 948700,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('60af1c5e9343690fa94506c8'),
#  'air_temperature_celcius': 24,
#  'date': '16/01/2018',
#  'fires': [],
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.4,
#  'station': 948700,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 200,
#  '_id': ObjectId('60af1c5e9343690fa94506c9'),
#  'air_temperature_celcius': 24,
#  'date': '17/01/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.4,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60af1c5e9343690fa94506ca'),
#  'air_temperature_celcius': 16,
#  'date': '18/01/2018',
#  'fires': [],
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 46.7,
#  'station': 948700,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('60af1c5e9343690fa94506cb'),
#  'air_temperature_celcius': 19,
#  'date': '19/01/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.98G',
#  'relative_humidity': 57.2,
#  'station': 948700,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('60af1c5e9343690fa94506cc'),
#  'air_temperature_celcius': 16,
#  'date': '20/01/2018',
#  'fires': [],
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.03G',
#  'relative_humidity': 50.9,
#  'station': 948700,
#  'windspeed_knots': 12.9}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa94506cd'),
#  'air_temperature_celcius': 17,
#  'date': '21/01/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 52.5,
#  'station': 948700,
#  'windspeed_knots': 6.7}
# {'GHI_w/m2': 182,
#  '_id': ObjectId('60af1c5e9343690fa94506ce'),
#  'air_temperature_celcius': 23,
#  'date': '22/01/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 59.0,
#  'station': 948700,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 199,
#  '_id': ObjectId('60af1c5e9343690fa94506cf'),
#  'air_temperature_celcius': 25,
#  'date': '23/01/2018',
#  'fires': [],
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 58.3,
#  'station': 948700,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('60af1c5e9343690fa94506d0'),
#  'air_temperature_celcius': 16,
#  'date': '24/01/2018',
#  'fires': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 48.2,
#  'station': 948700,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60af1c5e9343690fa94506d1'),
#  'air_temperature_celcius': 17,
#  'date': '25/01/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.8,
#  'station': 948700,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa94506d2'),
#  'air_temperature_celcius': 18,
#  'date': '26/01/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.5,
#  'station': 948700,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('60af1c5e9343690fa94506d3'),
#  'air_temperature_celcius': 19,
#  'date': '27/01/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00A',
#  'relative_humidity': 56.1,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60af1c5e9343690fa94506d4'),
#  'air_temperature_celcius': 18,
#  'date': '28/01/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 57.0,
#  'station': 948700,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('60af1c5e9343690fa94506d5'),
#  'air_temperature_celcius': 22,
#  'date': '29/01/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.0,
#  'station': 948700,
#  'windspeed_knots': 6.9}
# {'GHI_w/m2': 163,
#  '_id': ObjectId('60af1c5e9343690fa94506d6'),
#  'air_temperature_celcius': 20,
#  'date': '30/01/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 55.8,
#  'station': 948700,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('60af1c5e9343690fa94506d7'),
#  'air_temperature_celcius': 16,
#  'date': '31/01/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.4,
#  'station': 948700,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 138,
#  '_id': ObjectId('60af1c5e9343690fa94506d8'),
#  'air_temperature_celcius': 16,
#  'date': '01/02/2018',
#  'fires': [],
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 48.9,
#  'station': 948700,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa94506d9'),
#  'air_temperature_celcius': 18,
#  'date': '02/02/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.0,
#  'station': 948700,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60af1c5e9343690fa94506da'),
#  'air_temperature_celcius': 18,
#  'date': '03/02/2018',
#  'fires': [],
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.4,
#  'station': 948700,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 216,
#  '_id': ObjectId('60af1c5e9343690fa94506db'),
#  'air_temperature_celcius': 26,
#  'date': '04/02/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.7,
#  'station': 948700,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('60af1c5e9343690fa94506dc'),
#  'air_temperature_celcius': 21,
#  'date': '05/02/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 1.26G',
#  'relative_humidity': 64.5,
#  'station': 948700,
#  'windspeed_knots': 10.6}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('60af1c5e9343690fa94506dd'),
#  'air_temperature_celcius': 16,
#  'date': '06/02/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.1,
#  'station': 948700,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('60af1c5e9343690fa94506de'),
#  'air_temperature_celcius': 20,
#  'date': '07/02/2018',
#  'fires': [],
#  'max_wind_speed': 22.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 57.4,
#  'station': 948700,
#  'windspeed_knots': 10.9}
# {'GHI_w/m2': 239,
#  '_id': ObjectId('60af1c5e9343690fa94506df'),
#  'air_temperature_celcius': 31,
#  'date': '08/02/2018',
#  'fires': [],
#  'max_wind_speed': 23.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 61.9,
#  'station': 948700,
#  'windspeed_knots': 14.1}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('60af1c5e9343690fa94506e0'),
#  'air_temperature_celcius': 22,
#  'date': '09/02/2018',
#  'fires': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.7,
#  'station': 948700,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 164,
#  '_id': ObjectId('60af1c5e9343690fa94506e1'),
#  'air_temperature_celcius': 21,
#  'date': '10/02/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.4,
#  'station': 948700,
#  'windspeed_knots': 6.8}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('60af1c5e9343690fa94506e2'),
#  'air_temperature_celcius': 19,
#  'date': '11/02/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 53.8,
#  'station': 948700,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('60af1c5e9343690fa94506e3'),
#  'air_temperature_celcius': 16,
#  'date': '12/02/2018',
#  'fires': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.3,
#  'station': 948700,
#  'windspeed_knots': 14.4}
# {'GHI_w/m2': 133,
#  '_id': ObjectId('60af1c5e9343690fa94506e4'),
#  'air_temperature_celcius': 16,
#  'date': '13/02/2018',
#  'fires': [],
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.16G',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 12.1}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa94506e5'),
#  'air_temperature_celcius': 14,
#  'date': '14/02/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.5,
#  'station': 948700,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 183,
#  '_id': ObjectId('60af1c5e9343690fa94506e6'),
#  'air_temperature_celcius': 22,
#  'date': '15/02/2018',
#  'fires': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.4,
#  'station': 948700,
#  'windspeed_knots': 10.9}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa94506e7'),
#  'air_temperature_celcius': 18,
#  'date': '16/02/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.6,
#  'station': 948700,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('60af1c5e9343690fa94506e8'),
#  'air_temperature_celcius': 18,
#  'date': '17/02/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 49.4,
#  'station': 948700,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 134,
#  '_id': ObjectId('60af1c5e9343690fa94506e9'),
#  'air_temperature_celcius': 15,
#  'date': '18/02/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 44.6,
#  'station': 948700,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 113,
#  '_id': ObjectId('60af1c5e9343690fa94506ea'),
#  'air_temperature_celcius': 13,
#  'date': '19/02/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.71G',
#  'relative_humidity': 48.5,
#  'station': 948700,
#  'windspeed_knots': 10.7}
# {'GHI_w/m2': 130,
#  '_id': ObjectId('60af1c5e9343690fa94506eb'),
#  'air_temperature_celcius': 15,
#  'date': '20/02/2018',
#  'fires': [],
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 49.1,
#  'station': 948701,
#  'windspeed_knots': 9.6}
# {'GHI_w/m2': 136,
#  '_id': ObjectId('60af1c5e9343690fa94506ec'),
#  'air_temperature_celcius': 16,
#  'date': '21/02/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 51.0,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('60af1c5e9343690fa94506ed'),
#  'air_temperature_celcius': 23,
#  'date': '22/02/2018',
#  'fires': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 49.6,
#  'station': 948701,
#  'windspeed_knots': 10.0}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('60af1c5e9343690fa94506ee'),
#  'air_temperature_celcius': 18,
#  'date': '23/02/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 55.5,
#  'station': 948701,
#  'windspeed_knots': 8.9}
# {'GHI_w/m2': 139,
#  '_id': ObjectId('60af1c5e9343690fa94506ef'),
#  'air_temperature_celcius': 16,
#  'date': '24/02/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 48.3,
#  'station': 948701,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa94506f0'),
#  'air_temperature_celcius': 17,
#  'date': '25/02/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 52.6,
#  'station': 948701,
#  'windspeed_knots': 10.3}
# {'GHI_w/m2': 173,
#  '_id': ObjectId('60af1c5e9343690fa94506f1'),
#  'air_temperature_celcius': 21,
#  'date': '26/02/2018',
#  'fires': [],
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('60af1c5e9343690fa94506f2'),
#  'air_temperature_celcius': 24,
#  'date': '27/02/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 190,
#  '_id': ObjectId('60af1c5e9343690fa94506f3'),
#  'air_temperature_celcius': 23,
#  'date': '28/02/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.1,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('60af1c5e9343690fa94506f4'),
#  'air_temperature_celcius': 21,
#  'date': '01/03/2018',
#  'fires': [],
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 57.3,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('60af1c5e9343690fa94506f5'),
#  'air_temperature_celcius': 20,
#  'date': '02/03/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('60af1c5e9343690fa94506f6'),
#  'air_temperature_celcius': 21,
#  'date': '03/03/2018',
#  'fires': [],
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 59.5,
#  'station': 948701,
#  'windspeed_knots': 12.4}
# {'GHI_w/m2': 170,
#  '_id': ObjectId('60af1c5e9343690fa94506f7'),
#  'air_temperature_celcius': 22,
#  'date': '04/03/2018',
#  'fires': [],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.0,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60af1c5e9343690fa94506f8'),
#  'air_temperature_celcius': 20,
#  'date': '05/03/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.8,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('60af1c5e9343690fa94506f9'),
#  'air_temperature_celcius': 20,
#  'date': '06/03/2018',
#  'fires': [ObjectId('60af1c689343690fa9451291'),
#            ObjectId('60af1c689343690fa9451292')],
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.9,
#  'station': 948701,
#  'windspeed_knots': 17.0}
# {'GHI_w/m2': 161,
#  '_id': ObjectId('60af1c5e9343690fa94506fa'),
#  'air_temperature_celcius': 19,
#  'date': '07/03/2018',
#  'fires': [ObjectId('60af1c689343690fa9451290')],
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.5,
#  'station': 948701,
#  'windspeed_knots': 10.2}
# {'GHI_w/m2': 177,
#  '_id': ObjectId('60af1c5e9343690fa94506fb'),
#  'air_temperature_celcius': 21,
#  'date': '08/03/2018',
#  'fires': [ObjectId('60af1c689343690fa945128e'),
#            ObjectId('60af1c689343690fa945128f')],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.7,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 192,
#  '_id': ObjectId('60af1c5e9343690fa94506fc'),
#  'air_temperature_celcius': 23,
#  'date': '09/03/2018',
#  'fires': [ObjectId('60af1c689343690fa945128b'),
#            ObjectId('60af1c689343690fa945128c'),
#            ObjectId('60af1c689343690fa945128d')],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60af1c5e9343690fa94506fd'),
#  'air_temperature_celcius': 19,
#  'date': '10/03/2018',
#  'fires': [ObjectId('60af1c689343690fa9451283'),
#            ObjectId('60af1c689343690fa9451284'),
#            ObjectId('60af1c689343690fa9451285'),
#            ObjectId('60af1c689343690fa9451286'),
#            ObjectId('60af1c689343690fa9451287'),
#            ObjectId('60af1c689343690fa9451288'),
#            ObjectId('60af1c689343690fa9451289'),
#            ObjectId('60af1c689343690fa945128a')],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.2,
#  'station': 948701,
#  'windspeed_knots': 6.4}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('60af1c5e9343690fa94506fe'),
#  'air_temperature_celcius': 20,
#  'date': '11/03/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 59.7,
#  'station': 948701,
#  'windspeed_knots': 8.6}
# {'GHI_w/m2': 168,
#  '_id': ObjectId('60af1c5e9343690fa94506ff'),
#  'air_temperature_celcius': 21,
#  'date': '12/03/2018',
#  'fires': [ObjectId('60af1c689343690fa945127e'),
#            ObjectId('60af1c689343690fa945127f'),
#            ObjectId('60af1c689343690fa9451280'),
#            ObjectId('60af1c689343690fa9451281'),
#            ObjectId('60af1c689343690fa9451282')],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 58.1,
#  'station': 948701,
#  'windspeed_knots': 5.3}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60af1c5e9343690fa9450700'),
#  'air_temperature_celcius': 20,
#  'date': '13/03/2018',
#  'fires': [ObjectId('60af1c689343690fa945127c'),
#            ObjectId('60af1c689343690fa945127d')],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 62.2,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 199,
#  '_id': ObjectId('60af1c5e9343690fa9450701'),
#  'air_temperature_celcius': 25,
#  'date': '14/03/2018',
#  'fires': [ObjectId('60af1c689343690fa9451272'),
#            ObjectId('60af1c689343690fa9451273'),
#            ObjectId('60af1c689343690fa9451274'),
#            ObjectId('60af1c689343690fa9451275'),
#            ObjectId('60af1c689343690fa9451276'),
#            ObjectId('60af1c689343690fa9451277'),
#            ObjectId('60af1c689343690fa9451278'),
#            ObjectId('60af1c689343690fa9451279'),
#            ObjectId('60af1c689343690fa945127a'),
#            ObjectId('60af1c689343690fa945127b')],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.3,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('60af1c5e9343690fa9450702'),
#  'air_temperature_celcius': 28,
#  'date': '15/03/2018',
#  'fires': [ObjectId('60af1c689343690fa945126b'),
#            ObjectId('60af1c689343690fa945126c'),
#            ObjectId('60af1c689343690fa945126d'),
#            ObjectId('60af1c689343690fa945126e'),
#            ObjectId('60af1c689343690fa945126f'),
#            ObjectId('60af1c689343690fa9451270'),
#            ObjectId('60af1c689343690fa9451271')],
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 11.9}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa9450703'),
#  'air_temperature_celcius': 18,
#  'date': '16/03/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 53.3,
#  'station': 948701,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 153,
#  '_id': ObjectId('60af1c5e9343690fa9450704'),
#  'air_temperature_celcius': 18,
#  'date': '17/03/2018',
#  'fires': [ObjectId('60af1c689343690fa9451265'),
#            ObjectId('60af1c689343690fa9451266'),
#            ObjectId('60af1c689343690fa9451267'),
#            ObjectId('60af1c689343690fa9451268'),
#            ObjectId('60af1c689343690fa9451269'),
#            ObjectId('60af1c689343690fa945126a')],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.1,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('60af1c5e9343690fa9450705'),
#  'air_temperature_celcius': 21,
#  'date': '18/03/2018',
#  'fires': [ObjectId('60af1c689343690fa9451262'),
#            ObjectId('60af1c689343690fa9451263'),
#            ObjectId('60af1c689343690fa9451264')],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 197,
#  '_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'date': '19/03/2018',
#  'fires': [ObjectId('60af1c689343690fa945124d'),
#            ObjectId('60af1c689343690fa945124e'),
#            ObjectId('60af1c689343690fa945124f'),
#            ObjectId('60af1c689343690fa9451250'),
#            ObjectId('60af1c689343690fa9451251'),
#            ObjectId('60af1c689343690fa9451252'),
#            ObjectId('60af1c689343690fa9451253'),
#            ObjectId('60af1c689343690fa9451254'),
#            ObjectId('60af1c689343690fa9451255'),
#            ObjectId('60af1c689343690fa9451256'),
#            ObjectId('60af1c689343690fa9451257'),
#            ObjectId('60af1c689343690fa9451258'),
#            ObjectId('60af1c689343690fa9451259'),
#            ObjectId('60af1c689343690fa945125a'),
#            ObjectId('60af1c689343690fa945125b'),
#            ObjectId('60af1c689343690fa945125c'),
#            ObjectId('60af1c689343690fa945125d'),
#            ObjectId('60af1c689343690fa945125e'),
#            ObjectId('60af1c689343690fa945125f'),
#            ObjectId('60af1c689343690fa9451260'),
#            ObjectId('60af1c689343690fa9451261')],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.2,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 174,
#  '_id': ObjectId('60af1c5e9343690fa9450707'),
#  'air_temperature_celcius': 23,
#  'date': '20/03/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 63.8,
#  'station': 948701,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('60af1c5e9343690fa9450708'),
#  'air_temperature_celcius': 20,
#  'date': '21/03/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.63G',
#  'relative_humidity': 67.4,
#  'station': 948701,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60af1c5e9343690fa9450709'),
#  'air_temperature_celcius': 18,
#  'date': '22/03/2018',
#  'fires': [],
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 57.5,
#  'station': 948701,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 147,
#  '_id': ObjectId('60af1c5e9343690fa945070a'),
#  'air_temperature_celcius': 18,
#  'date': '23/03/2018',
#  'fires': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.6,
#  'station': 948701,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60af1c5e9343690fa945070b'),
#  'air_temperature_celcius': 20,
#  'date': '24/03/2018',
#  'fires': [ObjectId('60af1c689343690fa945124b'),
#            ObjectId('60af1c689343690fa945124c')],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.4,
#  'station': 948701,
#  'windspeed_knots': 6.1}
# {'GHI_w/m2': 178,
#  '_id': ObjectId('60af1c5e9343690fa945070c'),
#  'air_temperature_celcius': 23,
#  'date': '25/03/2018',
#  'fires': [ObjectId('60af1c689343690fa945123e'),
#            ObjectId('60af1c689343690fa945123f'),
#            ObjectId('60af1c689343690fa9451240'),
#            ObjectId('60af1c689343690fa9451241'),
#            ObjectId('60af1c689343690fa9451242'),
#            ObjectId('60af1c689343690fa9451243'),
#            ObjectId('60af1c689343690fa9451244'),
#            ObjectId('60af1c689343690fa9451245'),
#            ObjectId('60af1c689343690fa9451246'),
#            ObjectId('60af1c689343690fa9451247'),
#            ObjectId('60af1c689343690fa9451248'),
#            ObjectId('60af1c689343690fa9451249'),
#            ObjectId('60af1c689343690fa945124a')],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 61.9,
#  'station': 948701,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'date': '26/03/2018',
#  'fires': [ObjectId('60af1c689343690fa945122d'),
#            ObjectId('60af1c689343690fa945122e'),
#            ObjectId('60af1c689343690fa945122f'),
#            ObjectId('60af1c689343690fa9451230'),
#            ObjectId('60af1c689343690fa9451231'),
#            ObjectId('60af1c689343690fa9451232'),
#            ObjectId('60af1c689343690fa9451233'),
#            ObjectId('60af1c689343690fa9451234'),
#            ObjectId('60af1c689343690fa9451235'),
#            ObjectId('60af1c689343690fa9451236'),
#            ObjectId('60af1c689343690fa9451237'),
#            ObjectId('60af1c689343690fa9451238'),
#            ObjectId('60af1c689343690fa9451239'),
#            ObjectId('60af1c689343690fa945123a'),
#            ObjectId('60af1c689343690fa945123b'),
#            ObjectId('60af1c689343690fa945123c'),
#            ObjectId('60af1c689343690fa945123d')],
#  'max_wind_speed': 26.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.6,
#  'station': 948701,
#  'windspeed_knots': 10.1}
# {'GHI_w/m2': 142,
#  '_id': ObjectId('60af1c5e9343690fa945070e'),
#  'air_temperature_celcius': 17,
#  'date': '27/03/2018',
#  'fires': [],
#  'max_wind_speed': 25.1,
#  'precipitation ': ' 0.16G',
#  'relative_humidity': 53.4,
#  'station': 948701,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 154,
#  '_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'date': '28/03/2018',
#  'fires': [ObjectId('60af1c689343690fa94511f7'),
#            ObjectId('60af1c689343690fa94511f8'),
#            ObjectId('60af1c689343690fa94511f9'),
#            ObjectId('60af1c689343690fa94511fa'),
#            ObjectId('60af1c689343690fa94511fb'),
#            ObjectId('60af1c689343690fa94511fc'),
#            ObjectId('60af1c689343690fa94511fd'),
#            ObjectId('60af1c689343690fa94511fe'),
#            ObjectId('60af1c689343690fa94511ff'),
#            ObjectId('60af1c689343690fa9451200'),
#            ObjectId('60af1c689343690fa9451201'),
#            ObjectId('60af1c689343690fa9451202'),
#            ObjectId('60af1c689343690fa9451203'),
#            ObjectId('60af1c689343690fa9451204'),
#            ObjectId('60af1c689343690fa9451205'),
#            ObjectId('60af1c689343690fa9451206'),
#            ObjectId('60af1c689343690fa9451207'),
#            ObjectId('60af1c689343690fa9451208'),
#            ObjectId('60af1c689343690fa9451209'),
#            ObjectId('60af1c689343690fa945120a'),
#            ObjectId('60af1c689343690fa945120b'),
#            ObjectId('60af1c689343690fa945120c'),
#            ObjectId('60af1c689343690fa945120d'),
#            ObjectId('60af1c689343690fa945120e'),
#            ObjectId('60af1c689343690fa945120f'),
#            ObjectId('60af1c689343690fa9451210'),
#            ObjectId('60af1c689343690fa9451211'),
#            ObjectId('60af1c689343690fa9451212'),
#            ObjectId('60af1c689343690fa9451213'),
#            ObjectId('60af1c689343690fa9451214'),
#            ObjectId('60af1c689343690fa9451215'),
#            ObjectId('60af1c689343690fa9451216'),
#            ObjectId('60af1c689343690fa9451217'),
#            ObjectId('60af1c689343690fa9451218'),
#            ObjectId('60af1c689343690fa9451219'),
#            ObjectId('60af1c689343690fa945121a'),
#            ObjectId('60af1c689343690fa945121b'),
#            ObjectId('60af1c689343690fa945121c'),
#            ObjectId('60af1c689343690fa945121d'),
#            ObjectId('60af1c689343690fa945121e'),
#            ObjectId('60af1c689343690fa945121f'),
#            ObjectId('60af1c689343690fa9451220'),
#            ObjectId('60af1c689343690fa9451221'),
#            ObjectId('60af1c689343690fa9451222'),
#            ObjectId('60af1c689343690fa9451223'),
#            ObjectId('60af1c689343690fa9451224'),
#            ObjectId('60af1c689343690fa9451225'),
#            ObjectId('60af1c689343690fa9451226'),
#            ObjectId('60af1c689343690fa9451227'),
#            ObjectId('60af1c689343690fa9451228'),
#            ObjectId('60af1c689343690fa9451229'),
#            ObjectId('60af1c689343690fa945122a'),
#            ObjectId('60af1c689343690fa945122b'),
#            ObjectId('60af1c689343690fa945122c')],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 50.6,
#  'station': 948701,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 146,
#  '_id': ObjectId('60af1c5e9343690fa9450710'),
#  'air_temperature_celcius': 17,
#  'date': '29/03/2018',
#  'fires': [ObjectId('60af1c689343690fa94511f6')],
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 114,
#  '_id': ObjectId('60af1c5e9343690fa9450711'),
#  'air_temperature_celcius': 13,
#  'date': '30/03/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 47.0,
#  'station': 948701,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60af1c5e9343690fa9450712'),
#  'air_temperature_celcius': 14,
#  'date': '31/03/2018',
#  'fires': [ObjectId('60af1c689343690fa94511e0'),
#            ObjectId('60af1c689343690fa94511e1'),
#            ObjectId('60af1c689343690fa94511e2'),
#            ObjectId('60af1c689343690fa94511e3'),
#            ObjectId('60af1c689343690fa94511e4'),
#            ObjectId('60af1c689343690fa94511e5'),
#            ObjectId('60af1c689343690fa94511e6'),
#            ObjectId('60af1c689343690fa94511e7'),
#            ObjectId('60af1c689343690fa94511e8'),
#            ObjectId('60af1c689343690fa94511e9'),
#            ObjectId('60af1c689343690fa94511ea'),
#            ObjectId('60af1c689343690fa94511eb'),
#            ObjectId('60af1c689343690fa94511ec'),
#            ObjectId('60af1c689343690fa94511ed'),
#            ObjectId('60af1c689343690fa94511ee'),
#            ObjectId('60af1c689343690fa94511ef'),
#            ObjectId('60af1c689343690fa94511f0'),
#            ObjectId('60af1c689343690fa94511f1'),
#            ObjectId('60af1c689343690fa94511f2'),
#            ObjectId('60af1c689343690fa94511f3'),
#            ObjectId('60af1c689343690fa94511f4'),
#            ObjectId('60af1c689343690fa94511f5')],
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 45.8,
#  'station': 948701,
#  'windspeed_knots': 6.5}
# {'GHI_w/m2': 124,
#  '_id': ObjectId('60af1c5e9343690fa9450713'),
#  'air_temperature_celcius': 14,
#  'date': '01/04/2018',
#  'fires': [ObjectId('60af1c689343690fa94511d9'),
#            ObjectId('60af1c689343690fa94511da'),
#            ObjectId('60af1c689343690fa94511db'),
#            ObjectId('60af1c689343690fa94511dc'),
#            ObjectId('60af1c689343690fa94511dd'),
#            ObjectId('60af1c689343690fa94511de'),
#            ObjectId('60af1c689343690fa94511df')],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 45.7,
#  'station': 948701,
#  'windspeed_knots': 9.2}
# {'GHI_w/m2': 109,
#  '_id': ObjectId('60af1c5e9343690fa9450714'),
#  'air_temperature_celcius': 12,
#  'date': '02/04/2018',
#  'fires': [ObjectId('60af1c689343690fa94511d4'),
#            ObjectId('60af1c689343690fa94511d5'),
#            ObjectId('60af1c689343690fa94511d6'),
#            ObjectId('60af1c689343690fa94511d7'),
#            ObjectId('60af1c689343690fa94511d8')],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.4,
#  'station': 948701,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'date': '03/04/2018',
#  'fires': [ObjectId('60af1c689343690fa945118c'),
#            ObjectId('60af1c689343690fa945118d'),
#            ObjectId('60af1c689343690fa945118e'),
#            ObjectId('60af1c689343690fa945118f'),
#            ObjectId('60af1c689343690fa9451190'),
#            ObjectId('60af1c689343690fa9451191'),
#            ObjectId('60af1c689343690fa9451192'),
#            ObjectId('60af1c689343690fa9451193'),
#            ObjectId('60af1c689343690fa9451194'),
#            ObjectId('60af1c689343690fa9451195'),
#            ObjectId('60af1c689343690fa9451196'),
#            ObjectId('60af1c689343690fa9451197'),
#            ObjectId('60af1c689343690fa9451198'),
#            ObjectId('60af1c689343690fa9451199'),
#            ObjectId('60af1c689343690fa945119a'),
#            ObjectId('60af1c689343690fa945119b'),
#            ObjectId('60af1c689343690fa945119c'),
#            ObjectId('60af1c689343690fa945119d'),
#            ObjectId('60af1c689343690fa945119e'),
#            ObjectId('60af1c689343690fa945119f'),
#            ObjectId('60af1c689343690fa94511a0'),
#            ObjectId('60af1c689343690fa94511a1'),
#            ObjectId('60af1c689343690fa94511a2'),
#            ObjectId('60af1c689343690fa94511a3'),
#            ObjectId('60af1c689343690fa94511a4'),
#            ObjectId('60af1c689343690fa94511a5'),
#            ObjectId('60af1c689343690fa94511a6'),
#            ObjectId('60af1c689343690fa94511a7'),
#            ObjectId('60af1c689343690fa94511a8'),
#            ObjectId('60af1c689343690fa94511a9'),
#            ObjectId('60af1c689343690fa94511aa'),
#            ObjectId('60af1c689343690fa94511ab'),
#            ObjectId('60af1c689343690fa94511ac'),
#            ObjectId('60af1c689343690fa94511ad'),
#            ObjectId('60af1c689343690fa94511ae'),
#            ObjectId('60af1c689343690fa94511af'),
#            ObjectId('60af1c689343690fa94511b0'),
#            ObjectId('60af1c689343690fa94511b1'),
#            ObjectId('60af1c689343690fa94511b2'),
#            ObjectId('60af1c689343690fa94511b3'),
#            ObjectId('60af1c689343690fa94511b4'),
#            ObjectId('60af1c689343690fa94511b5'),
#            ObjectId('60af1c689343690fa94511b6'),
#            ObjectId('60af1c689343690fa94511b7'),
#            ObjectId('60af1c689343690fa94511b8'),
#            ObjectId('60af1c689343690fa94511b9'),
#            ObjectId('60af1c689343690fa94511ba'),
#            ObjectId('60af1c689343690fa94511bb'),
#            ObjectId('60af1c689343690fa94511bc'),
#            ObjectId('60af1c689343690fa94511bd'),
#            ObjectId('60af1c689343690fa94511be'),
#            ObjectId('60af1c689343690fa94511bf'),
#            ObjectId('60af1c689343690fa94511c0'),
#            ObjectId('60af1c689343690fa94511c1'),
#            ObjectId('60af1c689343690fa94511c2'),
#            ObjectId('60af1c689343690fa94511c3'),
#            ObjectId('60af1c689343690fa94511c4'),
#            ObjectId('60af1c689343690fa94511c5'),
#            ObjectId('60af1c689343690fa94511c6'),
#            ObjectId('60af1c689343690fa94511c7'),
#            ObjectId('60af1c689343690fa94511c8'),
#            ObjectId('60af1c689343690fa94511c9'),
#            ObjectId('60af1c689343690fa94511ca'),
#            ObjectId('60af1c689343690fa94511cb'),
#            ObjectId('60af1c689343690fa94511cc'),
#            ObjectId('60af1c689343690fa94511cd'),
#            ObjectId('60af1c689343690fa94511ce'),
#            ObjectId('60af1c689343690fa94511cf'),
#            ObjectId('60af1c689343690fa94511d0'),
#            ObjectId('60af1c689343690fa94511d1'),
#            ObjectId('60af1c689343690fa94511d2'),
#            ObjectId('60af1c689343690fa94511d3')],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.7,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'date': '04/04/2018',
#  'fires': [ObjectId('60af1c689343690fa9451133'),
#            ObjectId('60af1c689343690fa9451134'),
#            ObjectId('60af1c689343690fa9451135'),
#            ObjectId('60af1c689343690fa9451136'),
#            ObjectId('60af1c689343690fa9451137'),
#            ObjectId('60af1c689343690fa9451138'),
#            ObjectId('60af1c689343690fa9451139'),
#            ObjectId('60af1c689343690fa945113a'),
#            ObjectId('60af1c689343690fa945113b'),
#            ObjectId('60af1c689343690fa945113c'),
#            ObjectId('60af1c689343690fa945113d'),
#            ObjectId('60af1c689343690fa945113e'),
#            ObjectId('60af1c689343690fa945113f'),
#            ObjectId('60af1c689343690fa9451140'),
#            ObjectId('60af1c689343690fa9451141'),
#            ObjectId('60af1c689343690fa9451142'),
#            ObjectId('60af1c689343690fa9451143'),
#            ObjectId('60af1c689343690fa9451144'),
#            ObjectId('60af1c689343690fa9451145'),
#            ObjectId('60af1c689343690fa9451146'),
#            ObjectId('60af1c689343690fa9451147'),
#            ObjectId('60af1c689343690fa9451148'),
#            ObjectId('60af1c689343690fa9451149'),
#            ObjectId('60af1c689343690fa945114a'),
#            ObjectId('60af1c689343690fa945114b'),
#            ObjectId('60af1c689343690fa945114c'),
#            ObjectId('60af1c689343690fa945114d'),
#            ObjectId('60af1c689343690fa945114e'),
#            ObjectId('60af1c689343690fa945114f'),
#            ObjectId('60af1c689343690fa9451150'),
#            ObjectId('60af1c689343690fa9451151'),
#            ObjectId('60af1c689343690fa9451152'),
#            ObjectId('60af1c689343690fa9451153'),
#            ObjectId('60af1c689343690fa9451154'),
#            ObjectId('60af1c689343690fa9451155'),
#            ObjectId('60af1c689343690fa9451156'),
#            ObjectId('60af1c689343690fa9451157'),
#            ObjectId('60af1c689343690fa9451158'),
#            ObjectId('60af1c689343690fa9451159'),
#            ObjectId('60af1c689343690fa945115a'),
#            ObjectId('60af1c689343690fa945115b'),
#            ObjectId('60af1c689343690fa945115c'),
#            ObjectId('60af1c689343690fa945115d'),
#            ObjectId('60af1c689343690fa945115e'),
#            ObjectId('60af1c689343690fa945115f'),
#            ObjectId('60af1c689343690fa9451160'),
#            ObjectId('60af1c689343690fa9451161'),
#            ObjectId('60af1c689343690fa9451162'),
#            ObjectId('60af1c689343690fa9451163'),
#            ObjectId('60af1c689343690fa9451164'),
#            ObjectId('60af1c689343690fa9451165'),
#            ObjectId('60af1c689343690fa9451166'),
#            ObjectId('60af1c689343690fa9451167'),
#            ObjectId('60af1c689343690fa9451168'),
#            ObjectId('60af1c689343690fa9451169'),
#            ObjectId('60af1c689343690fa945116a'),
#            ObjectId('60af1c689343690fa945116b'),
#            ObjectId('60af1c689343690fa945116c'),
#            ObjectId('60af1c689343690fa945116d'),
#            ObjectId('60af1c689343690fa945116e'),
#            ObjectId('60af1c689343690fa945116f'),
#            ObjectId('60af1c689343690fa9451170'),
#            ObjectId('60af1c689343690fa9451171'),
#            ObjectId('60af1c689343690fa9451172'),
#            ObjectId('60af1c689343690fa9451173'),
#            ObjectId('60af1c689343690fa9451174'),
#            ObjectId('60af1c689343690fa9451175'),
#            ObjectId('60af1c689343690fa9451176'),
#            ObjectId('60af1c689343690fa9451177'),
#            ObjectId('60af1c689343690fa9451178'),
#            ObjectId('60af1c689343690fa9451179'),
#            ObjectId('60af1c689343690fa945117a'),
#            ObjectId('60af1c689343690fa945117b'),
#            ObjectId('60af1c689343690fa945117c'),
#            ObjectId('60af1c689343690fa945117d'),
#            ObjectId('60af1c689343690fa945117e'),
#            ObjectId('60af1c689343690fa945117f'),
#            ObjectId('60af1c689343690fa9451180'),
#            ObjectId('60af1c689343690fa9451181'),
#            ObjectId('60af1c689343690fa9451182'),
#            ObjectId('60af1c689343690fa9451183'),
#            ObjectId('60af1c689343690fa9451184'),
#            ObjectId('60af1c689343690fa9451185'),
#            ObjectId('60af1c689343690fa9451186'),
#            ObjectId('60af1c689343690fa9451187'),
#            ObjectId('60af1c689343690fa9451188'),
#            ObjectId('60af1c689343690fa9451189'),
#            ObjectId('60af1c689343690fa945118a'),
#            ObjectId('60af1c689343690fa945118b')],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 149,
#  '_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'date': '05/04/2018',
#  'fires': [ObjectId('60af1c689343690fa9451102'),
#            ObjectId('60af1c689343690fa9451103'),
#            ObjectId('60af1c689343690fa9451104'),
#            ObjectId('60af1c689343690fa9451105'),
#            ObjectId('60af1c689343690fa9451106'),
#            ObjectId('60af1c689343690fa9451107'),
#            ObjectId('60af1c689343690fa9451108'),
#            ObjectId('60af1c689343690fa9451109'),
#            ObjectId('60af1c689343690fa945110a'),
#            ObjectId('60af1c689343690fa945110b'),
#            ObjectId('60af1c689343690fa945110c'),
#            ObjectId('60af1c689343690fa945110d'),
#            ObjectId('60af1c689343690fa945110e'),
#            ObjectId('60af1c689343690fa945110f'),
#            ObjectId('60af1c689343690fa9451110'),
#            ObjectId('60af1c689343690fa9451111'),
#            ObjectId('60af1c689343690fa9451112'),
#            ObjectId('60af1c689343690fa9451113'),
#            ObjectId('60af1c689343690fa9451114'),
#            ObjectId('60af1c689343690fa9451115'),
#            ObjectId('60af1c689343690fa9451116'),
#            ObjectId('60af1c689343690fa9451117'),
#            ObjectId('60af1c689343690fa9451118'),
#            ObjectId('60af1c689343690fa9451119'),
#            ObjectId('60af1c689343690fa945111a'),
#            ObjectId('60af1c689343690fa945111b'),
#            ObjectId('60af1c689343690fa945111c'),
#            ObjectId('60af1c689343690fa945111d'),
#            ObjectId('60af1c689343690fa945111e'),
#            ObjectId('60af1c689343690fa945111f'),
#            ObjectId('60af1c689343690fa9451120'),
#            ObjectId('60af1c689343690fa9451121'),
#            ObjectId('60af1c689343690fa9451122'),
#            ObjectId('60af1c689343690fa9451123'),
#            ObjectId('60af1c689343690fa9451124'),
#            ObjectId('60af1c689343690fa9451125'),
#            ObjectId('60af1c689343690fa9451126'),
#            ObjectId('60af1c689343690fa9451127'),
#            ObjectId('60af1c689343690fa9451128'),
#            ObjectId('60af1c689343690fa9451129'),
#            ObjectId('60af1c689343690fa945112a'),
#            ObjectId('60af1c689343690fa945112b'),
#            ObjectId('60af1c689343690fa945112c'),
#            ObjectId('60af1c689343690fa945112d'),
#            ObjectId('60af1c689343690fa945112e'),
#            ObjectId('60af1c689343690fa945112f'),
#            ObjectId('60af1c689343690fa9451130'),
#            ObjectId('60af1c689343690fa9451131'),
#            ObjectId('60af1c689343690fa9451132')],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.2,
#  'station': 948701,
#  'windspeed_knots': 4.9}
# {'GHI_w/m2': 171,
#  '_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'date': '06/04/2018',
#  'fires': [ObjectId('60af1c689343690fa945108c'),
#            ObjectId('60af1c689343690fa945108d'),
#            ObjectId('60af1c689343690fa945108e'),
#            ObjectId('60af1c689343690fa945108f'),
#            ObjectId('60af1c689343690fa9451090'),
#            ObjectId('60af1c689343690fa9451091'),
#            ObjectId('60af1c689343690fa9451092'),
#            ObjectId('60af1c689343690fa9451093'),
#            ObjectId('60af1c689343690fa9451094'),
#            ObjectId('60af1c689343690fa9451095'),
#            ObjectId('60af1c689343690fa9451096'),
#            ObjectId('60af1c689343690fa9451097'),
#            ObjectId('60af1c689343690fa9451098'),
#            ObjectId('60af1c689343690fa9451099'),
#            ObjectId('60af1c689343690fa945109a'),
#            ObjectId('60af1c689343690fa945109b'),
#            ObjectId('60af1c689343690fa945109c'),
#            ObjectId('60af1c689343690fa945109d'),
#            ObjectId('60af1c689343690fa945109e'),
#            ObjectId('60af1c689343690fa945109f'),
#            ObjectId('60af1c689343690fa94510a0'),
#            ObjectId('60af1c689343690fa94510a1'),
#            ObjectId('60af1c689343690fa94510a2'),
#            ObjectId('60af1c689343690fa94510a3'),
#            ObjectId('60af1c689343690fa94510a4'),
#            ObjectId('60af1c689343690fa94510a5'),
#            ObjectId('60af1c689343690fa94510a6'),
#            ObjectId('60af1c689343690fa94510a7'),
#            ObjectId('60af1c689343690fa94510a8'),
#            ObjectId('60af1c689343690fa94510a9'),
#            ObjectId('60af1c689343690fa94510aa'),
#            ObjectId('60af1c689343690fa94510ab'),
#            ObjectId('60af1c689343690fa94510ac'),
#            ObjectId('60af1c689343690fa94510ad'),
#            ObjectId('60af1c689343690fa94510ae'),
#            ObjectId('60af1c689343690fa94510af'),
#            ObjectId('60af1c689343690fa94510b0'),
#            ObjectId('60af1c689343690fa94510b1'),
#            ObjectId('60af1c689343690fa94510b2'),
#            ObjectId('60af1c689343690fa94510b3'),
#            ObjectId('60af1c689343690fa94510b4'),
#            ObjectId('60af1c689343690fa94510b5'),
#            ObjectId('60af1c689343690fa94510b6'),
#            ObjectId('60af1c689343690fa94510b7'),
#            ObjectId('60af1c689343690fa94510b8'),
#            ObjectId('60af1c689343690fa94510b9'),
#            ObjectId('60af1c689343690fa94510ba'),
#            ObjectId('60af1c689343690fa94510bb'),
#            ObjectId('60af1c689343690fa94510bc'),
#            ObjectId('60af1c689343690fa94510bd'),
#            ObjectId('60af1c689343690fa94510be'),
#            ObjectId('60af1c689343690fa94510bf'),
#            ObjectId('60af1c689343690fa94510c0'),
#            ObjectId('60af1c689343690fa94510c1'),
#            ObjectId('60af1c689343690fa94510c2'),
#            ObjectId('60af1c689343690fa94510c3'),
#            ObjectId('60af1c689343690fa94510c4'),
#            ObjectId('60af1c689343690fa94510c5'),
#            ObjectId('60af1c689343690fa94510c6'),
#            ObjectId('60af1c689343690fa94510c7'),
#            ObjectId('60af1c689343690fa94510c8'),
#            ObjectId('60af1c689343690fa94510c9'),
#            ObjectId('60af1c689343690fa94510ca'),
#            ObjectId('60af1c689343690fa94510cb'),
#            ObjectId('60af1c689343690fa94510cc'),
#            ObjectId('60af1c689343690fa94510cd'),
#            ObjectId('60af1c689343690fa94510ce'),
#            ObjectId('60af1c689343690fa94510cf'),
#            ObjectId('60af1c689343690fa94510d0'),
#            ObjectId('60af1c689343690fa94510d1'),
#            ObjectId('60af1c689343690fa94510d2'),
#            ObjectId('60af1c689343690fa94510d3'),
#            ObjectId('60af1c689343690fa94510d4'),
#            ObjectId('60af1c689343690fa94510d5'),
#            ObjectId('60af1c689343690fa94510d6'),
#            ObjectId('60af1c689343690fa94510d7'),
#            ObjectId('60af1c689343690fa94510d8'),
# ...
#  'air_temperature_celcius': 19,
#  'date': '17/11/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60af1c5e9343690fa94507fa'),
#  'air_temperature_celcius': 20,
#  'date': '18/11/2018',
#  'fires': [],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 58.4,
#  'station': 948702,
#  'windspeed_knots': 4.7}
# {'GHI_w/m2': 178,
#  '_id': ObjectId('60af1c5e9343690fa94507fb'),
#  'air_temperature_celcius': 22,
#  'date': '19/11/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 57.0,
#  'station': 948702,
#  'windspeed_knots': 8.5}
# {'GHI_w/m2': 196,
#  '_id': ObjectId('60af1c5e9343690fa94507fc'),
#  'air_temperature_celcius': 24,
#  'date': '20/11/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.5,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 203,
#  '_id': ObjectId('60af1c5e9343690fa94507fd'),
#  'air_temperature_celcius': 24,
#  'date': '21/11/2018',
#  'fires': [ObjectId('60af1c689343690fa945087e')],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.8,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 198,
#  '_id': ObjectId('60af1c5e9343690fa94507fe'),
#  'air_temperature_celcius': 23,
#  'date': '22/11/2018',
#  'fires': [ObjectId('60af1c689343690fa945087c'),
#            ObjectId('60af1c689343690fa945087d')],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 49.6,
#  'station': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 194,
#  '_id': ObjectId('60af1c5e9343690fa94507ff'),
#  'air_temperature_celcius': 24,
#  'date': '23/11/2018',
#  'fires': [ObjectId('60af1c689343690fa9450877'),
#            ObjectId('60af1c689343690fa9450878'),
#            ObjectId('60af1c689343690fa9450879'),
#            ObjectId('60af1c689343690fa945087a'),
#            ObjectId('60af1c689343690fa945087b')],
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.8,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 183,
#  '_id': ObjectId('60af1c5e9343690fa9450800'),
#  'air_temperature_celcius': 23,
#  'date': '24/11/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 58.8,
#  'station': 948702,
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 188,
#  '_id': ObjectId('60af1c5e9343690fa9450801'),
#  'air_temperature_celcius': 24,
#  'date': '25/11/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 60.1,
#  'station': 948702,
#  'windspeed_knots': 8.0}
# {'GHI_w/m2': 156,
#  '_id': ObjectId('60af1c5e9343690fa9450802'),
#  'air_temperature_celcius': 20,
#  'date': '26/11/2018',
#  'fires': [],
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.08G',
#  'relative_humidity': 60.8,
#  'station': 948702,
#  'windspeed_knots': 10.4}
# {'GHI_w/m2': 142,
#  '_id': ObjectId('60af1c5e9343690fa9450803'),
#  'air_temperature_celcius': 17,
#  'date': '27/11/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 52.7,
#  'station': 948702,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 183,
#  '_id': ObjectId('60af1c5e9343690fa9450804'),
#  'air_temperature_celcius': 23,
#  'date': '28/11/2018',
#  'fires': [ObjectId('60af1c689343690fa9450876')],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.8,
#  'station': 948702,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 227,
#  '_id': ObjectId('60af1c5e9343690fa9450805'),
#  'air_temperature_celcius': 28,
#  'date': '29/11/2018',
#  'fires': [ObjectId('60af1c679343690fa945086e'),
#            ObjectId('60af1c679343690fa945086f'),
#            ObjectId('60af1c679343690fa9450870'),
#            ObjectId('60af1c679343690fa9450871'),
#            ObjectId('60af1c679343690fa9450872'),
#            ObjectId('60af1c679343690fa9450873'),
#            ObjectId('60af1c679343690fa9450874'),
#            ObjectId('60af1c679343690fa9450875')],
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.7,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'fires': [ObjectId('60af1c679343690fa945084f'),
#            ObjectId('60af1c679343690fa9450850'),
#            ObjectId('60af1c679343690fa9450851'),
#            ObjectId('60af1c679343690fa9450852'),
#            ObjectId('60af1c679343690fa9450853'),
#            ObjectId('60af1c679343690fa9450854'),
#            ObjectId('60af1c679343690fa9450855'),
#            ObjectId('60af1c679343690fa9450856'),
#            ObjectId('60af1c679343690fa9450857'),
#            ObjectId('60af1c679343690fa9450858'),
#            ObjectId('60af1c679343690fa9450859'),
#            ObjectId('60af1c679343690fa945085a'),
#            ObjectId('60af1c679343690fa945085b'),
#            ObjectId('60af1c679343690fa945085c'),
#            ObjectId('60af1c679343690fa945085d'),
#            ObjectId('60af1c679343690fa945085e'),
#            ObjectId('60af1c679343690fa945085f'),
#            ObjectId('60af1c679343690fa9450860'),
#            ObjectId('60af1c679343690fa9450861'),
#            ObjectId('60af1c679343690fa9450862'),
#            ObjectId('60af1c679343690fa9450863'),
#            ObjectId('60af1c679343690fa9450864'),
#            ObjectId('60af1c679343690fa9450865'),
#            ObjectId('60af1c679343690fa9450866'),
#            ObjectId('60af1c679343690fa9450867'),
#            ObjectId('60af1c679343690fa9450868'),
#            ObjectId('60af1c679343690fa9450869'),
#            ObjectId('60af1c679343690fa945086a'),
#            ObjectId('60af1c679343690fa945086b'),
#            ObjectId('60af1c679343690fa945086c'),
#            ObjectId('60af1c679343690fa945086d')],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 135,
#  '_id': ObjectId('60af1c5e9343690fa9450807'),
#  'air_temperature_celcius': 17,
#  'date': '01/12/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.75G',
#  'relative_humidity': 59.0,
#  'station': 948702,
#  'windspeed_knots': 9.4}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa9450808'),
#  'air_temperature_celcius': 15,
#  'date': '02/12/2018',
#  'fires': [],
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 1.77G',
#  'relative_humidity': 56.2,
#  'station': 948702,
#  'windspeed_knots': 16.9}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa9450809'),
#  'air_temperature_celcius': 14,
#  'date': '03/12/2018',
#  'fires': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.03G',
#  'relative_humidity': 48.2,
#  'station': 948702,
#  'windspeed_knots': 12.5}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa945080a'),
#  'air_temperature_celcius': 14,
#  'date': '04/12/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.2,
#  'station': 948702,
#  'windspeed_knots': 9.1}
# {'GHI_w/m2': 142,
#  '_id': ObjectId('60af1c5e9343690fa945080b'),
#  'air_temperature_celcius': 17,
#  'date': '05/12/2018',
#  'fires': [],
#  'max_wind_speed': 22.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.0,
#  'station': 948702,
#  'windspeed_knots': 14.6}
# {'GHI_w/m2': 135,
#  '_id': ObjectId('60af1c5e9343690fa945080c'),
#  'air_temperature_celcius': 16,
#  'date': '06/12/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 51.7,
#  'station': 948702,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 128,
#  '_id': ObjectId('60af1c5e9343690fa945080d'),
#  'air_temperature_celcius': 15,
#  'date': '07/12/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 1.26G',
#  'relative_humidity': 51.0,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 131,
#  '_id': ObjectId('60af1c5e9343690fa945080e'),
#  'air_temperature_celcius': 15,
#  'date': '08/12/2018',
#  'fires': [ObjectId('60af1c679343690fa945084a'),
#            ObjectId('60af1c679343690fa945084b'),
#            ObjectId('60af1c679343690fa945084c'),
#            ObjectId('60af1c679343690fa945084d'),
#            ObjectId('60af1c679343690fa945084e')],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 48.1,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60af1c5e9343690fa945080f'),
#  'air_temperature_celcius': 17,
#  'date': '09/12/2018',
#  'fires': [ObjectId('60af1c679343690fa9450846'),
#            ObjectId('60af1c679343690fa9450847'),
#            ObjectId('60af1c679343690fa9450848'),
#            ObjectId('60af1c679343690fa9450849')],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.6,
#  'station': 948702,
#  'windspeed_knots': 7.6}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60af1c5e9343690fa9450810'),
#  'air_temperature_celcius': 17,
#  'date': '10/12/2018',
#  'fires': [ObjectId('60af1c679343690fa9450844'),
#            ObjectId('60af1c679343690fa9450845')],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.5,
#  'station': 948702,
#  'windspeed_knots': 7.3}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa9450811'),
#  'air_temperature_celcius': 17,
#  'date': '11/12/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 8.8}
# {'GHI_w/m2': 156,
#  '_id': ObjectId('60af1c5e9343690fa9450812'),
#  'air_temperature_celcius': 19,
#  'date': '12/12/2018',
#  'fires': [ObjectId('60af1c679343690fa9450843')],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}
# {'GHI_w/m2': 240,
#  '_id': ObjectId('60af1c5e9343690fa9450813'),
#  'air_temperature_celcius': 28,
#  'date': '13/12/2018',
#  'fires': [ObjectId('60af1c679343690fa9450842')],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 49.9,
#  'station': 948702,
#  'windspeed_knots': 11.0}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa9450814'),
#  'air_temperature_celcius': 17,
#  'date': '14/12/2018',
#  'fires': [ObjectId('60af1c679343690fa9450841')],
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.5,
#  'station': 948702,
#  'windspeed_knots': 7.7}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('60af1c5e9343690fa9450815'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2018',
#  'fires': [ObjectId('60af1c679343690fa945083d'),
#            ObjectId('60af1c679343690fa945083e'),
#            ObjectId('60af1c679343690fa945083f'),
#            ObjectId('60af1c679343690fa9450840')],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.0,
#  'station': 948702,
#  'windspeed_knots': 7.1}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2018',
#  'fires': [ObjectId('60af1c679343690fa945082e'),
#            ObjectId('60af1c679343690fa945082f'),
#            ObjectId('60af1c679343690fa9450830'),
#            ObjectId('60af1c679343690fa9450831'),
#            ObjectId('60af1c679343690fa9450832'),
#            ObjectId('60af1c679343690fa9450833'),
#            ObjectId('60af1c679343690fa9450834'),
#            ObjectId('60af1c679343690fa9450835'),
#            ObjectId('60af1c679343690fa9450836'),
#            ObjectId('60af1c679343690fa9450837'),
#            ObjectId('60af1c679343690fa9450838'),
#            ObjectId('60af1c679343690fa9450839'),
#            ObjectId('60af1c679343690fa945083a'),
#            ObjectId('60af1c679343690fa945083b'),
#            ObjectId('60af1c679343690fa945083c')],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.7,
#  'station': 948702,
#  'windspeed_knots': 9.0}
# {'GHI_w/m2': 167,
#  '_id': ObjectId('60af1c5e9343690fa9450817'),
#  'air_temperature_celcius': 21,
#  'date': '17/12/2018',
#  'fires': [],
#  'max_wind_speed': 13.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 7.8}
# {'GHI_w/m2': 195,
#  '_id': ObjectId('60af1c5e9343690fa9450818'),
#  'air_temperature_celcius': 25,
#  'date': '18/12/2018',
#  'fires': [],
#  'max_wind_speed': 8.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 60.9,
#  'station': 948702,
#  'windspeed_knots': 6.3}
# {'GHI_w/m2': 169,
#  '_id': ObjectId('60af1c5e9343690fa9450819'),
#  'air_temperature_celcius': 21,
#  'date': '19/12/2018',
#  'fires': [],
#  'max_wind_speed': 22.9,
#  'precipitation ': ' 0.67G',
#  'relative_humidity': 57.4,
#  'station': 948702,
#  'windspeed_knots': 10.7}
# {'GHI_w/m2': 144,
#  '_id': ObjectId('60af1c5e9343690fa945081a'),
#  'air_temperature_celcius': 17,
#  'date': '20/12/2018',
#  'fires': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 51.2,
#  'station': 948702,
#  'windspeed_knots': 9.9}
# {'GHI_w/m2': 143,
#  '_id': ObjectId('60af1c5e9343690fa945081b'),
#  'air_temperature_celcius': 17,
#  'date': '21/12/2018',
#  'fires': [ObjectId('60af1c679343690fa945082d')],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.5,
#  'station': 948702,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 155,
#  '_id': ObjectId('60af1c5e9343690fa945081c'),
#  'air_temperature_celcius': 19,
#  'date': '22/12/2018',
#  'fires': [],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.8,
#  'station': 948702,
#  'windspeed_knots': 6.0}
# {'GHI_w/m2': 158,
#  '_id': ObjectId('60af1c5e9343690fa945081d'),
#  'air_temperature_celcius': 19,
#  'date': '23/12/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 53.9,
#  'station': 948702,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 141,
#  '_id': ObjectId('60af1c5e9343690fa945081e'),
#  'air_temperature_celcius': 16,
#  'date': '24/12/2018',
#  'fires': [ObjectId('60af1c679343690fa945082c')],
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.0,
#  'station': 948702,
#  'windspeed_knots': 12.0}
# {'GHI_w/m2': 145,
#  '_id': ObjectId('60af1c5e9343690fa945081f'),
#  'air_temperature_celcius': 17,
#  'date': '25/12/2018',
#  'fires': [ObjectId('60af1c679343690fa945082b')],
#  'max_wind_speed': 16.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 50.4,
#  'station': 948702,
#  'windspeed_knots': 10.8}
# {'GHI_w/m2': 180,
#  '_id': ObjectId('60af1c5e9343690fa9450820'),
#  'air_temperature_celcius': 22,
#  'date': '26/12/2018',
#  'fires': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.5,
#  'station': 948702,
#  'windspeed_knots': 10.3}
# {'GHI_w/m2': 223,
#  '_id': ObjectId('60af1c5e9343690fa9450821'),
#  'air_temperature_celcius': 28,
#  'date': '27/12/2018',
#  'fires': [ObjectId('60af1c679343690fa9450827'),
#            ObjectId('60af1c679343690fa9450828'),
#            ObjectId('60af1c679343690fa9450829'),
#            ObjectId('60af1c679343690fa945082a')],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 58.3,
#  'station': 948702,
#  'windspeed_knots': 9.3}
# {'GHI_w/m2': 163,
#  '_id': ObjectId('60af1c5e9343690fa9450822'),
#  'air_temperature_celcius': 21,
#  'date': '28/12/2018',
#  'fires': [],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 61.1,
#  'station': 948702,
#  'windspeed_knots': 6.6}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa9450823'),
#  'air_temperature_celcius': 19,
#  'date': '29/12/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.63G',
#  'relative_humidity': 59.7,
#  'station': 948702,
#  'windspeed_knots': 7.4}
# {'GHI_w/m2': 135,
#  '_id': ObjectId('60af1c5e9343690fa9450824'),
#  'air_temperature_celcius': 16,
#  'date': '30/12/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.02G',
#  'relative_humidity': 51.5,
#  'station': 948702,
#  'windspeed_knots': 8.7}
# {'GHI_w/m2': 150,
#  '_id': ObjectId('60af1c5e9343690fa9450825'),
#  'air_temperature_celcius': 18,
#  'date': '31/12/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.00G',
#  'relative_humidity': 53.6,
#  'station': 948702,
#  'windspeed_knots': 7.9}
# {'GHI_w/m2': 159,
#  '_id': ObjectId('60af1c5e9343690fa9450826'),
#  'air_temperature_celcius': 19,
#  'date': '01/01/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.9,
#  'station': 948702,
#  'windspeed_knots': 8.1}

# %% [markdown]
# Now that we have loaded the data into the new database, we can perform the queries.
#
# **a. Find climate data on 12th December 2018.**

# %%
results = climates.find({"date": "12/12/2018"})
for result in results: 
    pprint(result)
# Out:
# {'GHI_w/m2': 156,
#  '_id': ObjectId('60af1c5e9343690fa9450812'),
#  'air_temperature_celcius': 19,
#  'date': '12/12/2018',
#  'fires': [ObjectId('60af1c679343690fa9450843')],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %% [markdown]
# **b. Find the latitude, longitude, surface temperature (°C), and confidence when the surface temperature (°C) was between 65 °C and 100 °C.**

# %%
results = fires.find(
    {
        "$and":[
            {
                "surface_temperature_celcius":{"$gte":65}
            }, 
            {
                "surface_temperature_celcius":{"$lte":100}
            }
        ]
    },
    {
        "latitude": 1,
        "longitude": 1,
        "surface_temperature_celcius": 1,
        "confidence": 1
    }
)
for result in results:
    pprint(result)
# Out:
# {'_id': ObjectId('60af1c679343690fa9450827'),
#  'confidence': 78,
#  'latitude': -37.966,
#  'longitude': 145.051,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c679343690fa945082a'),
#  'confidence': 86,
#  'latitude': -35.543,
#  'longitude': 143.316,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c679343690fa9450831'),
#  'confidence': 93,
#  'latitude': -37.875,
#  'longitude': 142.51,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c679343690fa9450833'),
#  'confidence': 95,
#  'latitude': -37.613,
#  'longitude': 149.305,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c679343690fa9450835'),
#  'confidence': 90,
#  'latitude': -37.624,
#  'longitude': 149.314,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c679343690fa9450838'),
#  'confidence': 93,
#  'latitude': -38.057,
#  'longitude': 144.211,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c679343690fa9450841'),
#  'confidence': 92,
#  'latitude': -37.95,
#  'longitude': 142.366,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c679343690fa945084c'),
#  'confidence': 100,
#  'latitude': -36.282,
#  'longitude': 146.157,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c679343690fa945085c'),
#  'confidence': 100,
#  'latitude': -37.642,
#  'longitude': 149.263,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c679343690fa945085d'),
#  'confidence': 100,
#  'latitude': -37.634,
#  'longitude': 149.237,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c679343690fa9450860'),
#  'confidence': 98,
#  'latitude': -37.605,
#  'longitude': 149.302,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('60af1c679343690fa9450863'),
#  'confidence': 99,
#  'latitude': -37.6,
#  'longitude': 149.325,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('60af1c679343690fa9450868'),
#  'confidence': 95,
#  'latitude': -37.618,
#  'longitude': 149.281,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c679343690fa9450872'),
#  'confidence': 100,
#  'latitude': -37.606,
#  'longitude': 149.312,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c679343690fa9450874'),
#  'confidence': 97,
#  'latitude': -37.61,
#  'longitude': 149.307,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c679343690fa9450875'),
#  'confidence': 99,
#  'latitude': -37.609,
#  'longitude': 149.32,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('60af1c689343690fa9450878'),
#  'confidence': 93,
#  'latitude': -37.945,
#  'longitude': 144.354,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa945087f'),
#  'confidence': 87,
#  'latitude': -37.862,
#  'longitude': 144.175,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa945088b'),
#  'confidence': 89,
#  'latitude': -36.94,
#  'longitude': 143.281,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450895'),
#  'confidence': 100,
#  'latitude': -37.477,
#  'longitude': 143.352,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa9450896'),
#  'confidence': 96,
#  'latitude': -37.475,
#  'longitude': 143.365,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450899'),
#  'confidence': 97,
#  'latitude': -37.69,
#  'longitude': 143.605,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa945089e'),
#  'confidence': 90,
#  'latitude': -37.331,
#  'longitude': 143.122,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa94508af'),
#  'confidence': 92,
#  'latitude': -36.098,
#  'longitude': 143.74,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa94508bb'),
#  'confidence': 91,
#  'latitude': -37.247,
#  'longitude': 141.278,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa94508bf'),
#  'confidence': 100,
#  'latitude': -37.294,
#  'longitude': 141.232,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c689343690fa94508c0'),
#  'confidence': 99,
#  'latitude': -37.293,
#  'longitude': 141.245,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('60af1c689343690fa94508c3'),
#  'confidence': 96,
#  'latitude': -38.127,
#  'longitude': 143.82,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa94508dc'),
#  'confidence': 100,
#  'latitude': -37.462,
#  'longitude': 148.089,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa94508dd'),
#  'confidence': 88,
#  'latitude': -37.46,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa94508fc'),
#  'confidence': 100,
#  'latitude': -37.446,
#  'longitude': 148.102,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa945090b'),
#  'confidence': 100,
#  'latitude': -37.406,
#  'longitude': 148.123,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('60af1c689343690fa945090d'),
#  'confidence': 68,
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa945090f'),
#  'confidence': 64,
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450910'),
#  'confidence': 86,
#  'latitude': -37.436,
#  'longitude': 148.088,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450911'),
#  'confidence': 73,
#  'latitude': -37.444,
#  'longitude': 148.101,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450912'),
#  'confidence': 61,
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450919'),
#  'confidence': 58,
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa945091a'),
#  'confidence': 62,
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa945091c'),
#  'confidence': 100,
#  'latitude': -37.396,
#  'longitude': 148.086,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450921'),
#  'confidence': 100,
#  'latitude': -37.399,
#  'longitude': 148.081,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('60af1c689343690fa9450922'),
#  'confidence': 100,
#  'latitude': -37.401,
#  'longitude': 148.067,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa9450949'),
#  'confidence': 94,
#  'latitude': -37.4796,
#  'longitude': 141.9403,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c689343690fa945094b'),
#  'confidence': 89,
#  'latitude': -38.3998,
#  'longitude': 147.064,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450954'),
#  'confidence': 91,
#  'latitude': -37.8644,
#  'longitude': 143.4263,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa945096d'),
#  'confidence': 91,
#  'latitude': -36.3774,
#  'longitude': 143.7079,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa945096e'),
#  'confidence': 100,
#  'latitude': -36.3756,
#  'longitude': 143.7243,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('60af1c689343690fa945096f'),
#  'confidence': 97,
#  'latitude': -36.369,
#  'longitude': 143.7132,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9450970'),
#  'confidence': 100,
#  'latitude': -36.3799,
#  'longitude': 143.7149,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('60af1c689343690fa9450976'),
#  'confidence': 94,
#  'latitude': -36.2693,
#  'longitude': 143.1768,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('60af1c689343690fa9450984'),
#  'confidence': 96,
#  'latitude': -36.1002,
#  'longitude': 142.3405,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa945098c'),
#  'confidence': 90,
#  'latitude': -36.4325,
#  'longitude': 144.3142,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa945098f'),
#  'confidence': 91,
#  'latitude': -36.7685,
#  'longitude': 142.7134,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450992'),
#  'confidence': 91,
#  'latitude': -36.7801,
#  'longitude': 142.7151,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa94509c2'),
#  'confidence': 91,
#  'latitude': -36.7746,
#  'longitude': 146.6642,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa94509c4'),
#  'confidence': 96,
#  'latitude': -36.8359,
#  'longitude': 146.6448,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa94509c7'),
#  'confidence': 98,
#  'latitude': -37.9085,
#  'longitude': 141.1038,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa94509ca'),
#  'confidence': 100,
#  'latitude': -38.4349,
#  'longitude': 146.3122,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa94509cb'),
#  'confidence': 89,
#  'latitude': -38.4792,
#  'longitude': 146.3081,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa94509d0'),
#  'confidence': 100,
#  'latitude': -37.9047,
#  'longitude': 141.0945,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa94509e0'),
#  'confidence': 93,
#  'latitude': -37.4984,
#  'longitude': 142.9739,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa94509e1'),
#  'confidence': 96,
#  'latitude': -37.253,
#  'longitude': 144.3681,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa94509e6'),
#  'confidence': 92,
#  'latitude': -36.9396,
#  'longitude': 143.1462,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa94509ed'),
#  'confidence': 96,
#  'latitude': -36.3387,
#  'longitude': 141.7542,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa94509fb'),
#  'confidence': 100,
#  'latitude': -36.3433,
#  'longitude': 143.4369,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('60af1c689343690fa94509ff'),
#  'confidence': 100,
#  'latitude': -36.345,
#  'longitude': 143.4256,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c689343690fa9450a00'),
#  'confidence': 90,
#  'latitude': -36.7032,
#  'longitude': 144.0992,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450a0f'),
#  'confidence': 96,
#  'latitude': -36.3402,
#  'longitude': 141.7429,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450a14'),
#  'confidence': 89,
#  'latitude': -36.5661,
#  'longitude': 142.2956,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450a20'),
#  'confidence': 85,
#  'latitude': -36.5023,
#  'longitude': 143.6038,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450a22'),
#  'confidence': 90,
#  'latitude': -36.8616,
#  'longitude': 142.8025,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450a2e'),
#  'confidence': 90,
#  'latitude': -38.0372,
#  'longitude': 146.0616,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450a2f'),
#  'confidence': 94,
#  'latitude': -38.049,
#  'longitude': 146.0513,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('60af1c689343690fa9450a32'),
#  'confidence': 89,
#  'latitude': -35.4666,
#  'longitude': 142.0749,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450a35'),
#  'confidence': 95,
#  'latitude': -36.0396,
#  'longitude': 141.7183,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450a3a'),
#  'confidence': 94,
#  'latitude': -36.2775,
#  'longitude': 146.1026,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('60af1c689343690fa9450a41'),
#  'confidence': 100,
#  'latitude': -38.0361,
#  'longitude': 146.0567,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa9450a46'),
#  'confidence': 95,
#  'latitude': -36.3254,
#  'longitude': 144.3638,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450a4b'),
#  'confidence': 100,
#  'latitude': -36.0816,
#  'longitude': 145.859,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('60af1c689343690fa9450a4f'),
#  'confidence': 100,
#  'latitude': -36.1532,
#  'longitude': 143.5527,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa9450a57'),
#  'confidence': 100,
#  'latitude': -36.0077,
#  'longitude': 141.7747,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa9450a63'),
#  'confidence': 94,
#  'latitude': -36.0828,
#  'longitude': 145.873,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa9450a6a'),
#  'confidence': 91,
#  'latitude': -36.5541,
#  'longitude': 144.1321,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450a6d'),
#  'confidence': 91,
#  'latitude': -35.6819,
#  'longitude': 143.5275,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450a70'),
#  'confidence': 90,
#  'latitude': -35.6871,
#  'longitude': 143.5235,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450a75'),
#  'confidence': 100,
#  'latitude': -36.1506,
#  'longitude': 143.5671,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('60af1c689343690fa9450a7e'),
#  'confidence': 93,
#  'latitude': -37.4671,
#  'longitude': 145.9962,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450a84'),
#  'confidence': 90,
#  'latitude': -36.2911,
#  'longitude': 141.1664,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450a85'),
#  'confidence': 96,
#  'latitude': -36.2842,
#  'longitude': 141.1741,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa9450a87'),
#  'confidence': 89,
#  'latitude': -36.7218,
#  'longitude': 141.6411,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450a88'),
#  'confidence': 84,
#  'latitude': -37.3656,
#  'longitude': 141.3903,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450a8a'),
#  'confidence': 94,
#  'latitude': -36.4179,
#  'longitude': 144.2924,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa9450a8c'),
#  'confidence': 92,
#  'latitude': -36.3207,
#  'longitude': 140.9737,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450a8f'),
#  'confidence': 99,
#  'latitude': -36.2882,
#  'longitude': 141.1821,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('60af1c689343690fa9450a90'),
#  'confidence': 91,
#  'latitude': -36.3153,
#  'longitude': 140.9789,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450a92'),
#  'confidence': 97,
#  'latitude': -36.4169,
#  'longitude': 144.2994,
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('60af1c689343690fa9450a97'),
#  'confidence': 96,
#  'latitude': -36.8094,
#  'longitude': 142.8885,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450aa7'),
#  'confidence': 84,
#  'latitude': -37.8323,
#  'longitude': 147.2232,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450ab7'),
#  'confidence': 98,
#  'latitude': -38.2853,
#  'longitude': 145.9519,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('60af1c689343690fa9450ab8'),
#  'confidence': 98,
#  'latitude': -38.2375,
#  'longitude': 142.8363,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa9450aba'),
#  'confidence': 92,
#  'latitude': -37.4463,
#  'longitude': 142.7829,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450ac5'),
#  'confidence': 95,
#  'latitude': -37.6854,
#  'longitude': 143.4543,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450acb'),
#  'confidence': 99,
#  'latitude': -38.0881,
#  'longitude': 143.9391,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('60af1c689343690fa9450acc'),
#  'confidence': 96,
#  'latitude': -38.0866,
#  'longitude': 143.9534,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450acd'),
#  'confidence': 92,
#  'latitude': -38.2391,
#  'longitude': 142.82,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa9450ad0'),
#  'confidence': 100,
#  'latitude': -38.5123,
#  'longitude': 146.4007,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('60af1c689343690fa9450aed'),
#  'confidence': 96,
#  'latitude': -36.3438,
#  'longitude': 141.5832,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450af4'),
#  'confidence': 94,
#  'latitude': -37.4357,
#  'longitude': 142.7813,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('60af1c689343690fa9450b08'),
#  'confidence': 99,
#  'latitude': -37.5867,
#  'longitude': 143.6256,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('60af1c689343690fa9450b17'),
#  'confidence': 93,
#  'latitude': -36.2306,
#  'longitude': 143.6408,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450b21'),
#  'confidence': 91,
#  'latitude': -36.4168,
#  'longitude': 141.6939,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450b2c'),
#  'confidence': 97,
#  'latitude': -36.4211,
#  'longitude': 141.6875,
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('60af1c689343690fa9450b34'),
#  'confidence': 91,
#  'latitude': -35.6138,
#  'longitude': 143.8666,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450b37'),
#  'confidence': 95,
#  'latitude': -36.0885,
#  'longitude': 145.0359,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450b38'),
#  'confidence': 96,
#  'latitude': -36.3193,
#  'longitude': 145.9162,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450b3a'),
#  'confidence': 98,
#  'latitude': -36.0652,
#  'longitude': 146.0764,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa9450b3c'),
#  'confidence': 100,
#  'latitude': -36.0682,
#  'longitude': 146.0602,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa9450b40'),
#  'confidence': 92,
#  'latitude': -37.7889,
#  'longitude': 143.1324,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa9450b42'),
#  'confidence': 95,
#  'latitude': -36.6139,
#  'longitude': 143.501,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450b48'),
#  'confidence': 95,
#  'latitude': -37.9509,
#  'longitude': 143.9599,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450b55'),
#  'confidence': 97,
#  'latitude': -36.6224,
#  'longitude': 143.5092,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9450b5f'),
#  'confidence': 96,
#  'latitude': -38.0933,
#  'longitude': 143.9824,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450b61'),
#  'confidence': 92,
#  'latitude': -36.663,
#  'longitude': 142.8567,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa9450b6b'),
#  'confidence': 94,
#  'latitude': -37.6982,
#  'longitude': 143.0549,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450b6e'),
#  'confidence': 95,
#  'latitude': -36.7187,
#  'longitude': 143.805,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450b71'),
#  'confidence': 100,
#  'latitude': -36.7742,
#  'longitude': 145.1991,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('60af1c689343690fa9450b7a'),
#  'confidence': 91,
#  'latitude': -36.5061,
#  'longitude': 144.5675,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450b7e'),
#  'confidence': 100,
#  'latitude': -36.4035,
#  'longitude': 140.9935,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('60af1c689343690fa9450b87'),
#  'confidence': 99,
#  'latitude': -36.4286,
#  'longitude': 141.1567,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('60af1c689343690fa9450b8a'),
#  'confidence': 91,
#  'latitude': -36.3635,
#  'longitude': 142.2809,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450b8b'),
#  'confidence': 100,
#  'latitude': -36.664,
#  'longitude': 142.8802,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c689343690fa9450b8d'),
#  'confidence': 91,
#  'latitude': -36.6564,
#  'longitude': 142.8615,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450b9f'),
#  'confidence': 93,
#  'latitude': -36.6657,
#  'longitude': 143.1675,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450bad'),
#  'confidence': 98,
#  'latitude': -36.8742,
#  'longitude': 142.7177,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('60af1c689343690fa9450bb1'),
#  'confidence': 91,
#  'latitude': -36.7751,
#  'longitude': 145.1696,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450bb5'),
#  'confidence': 91,
#  'latitude': -36.3961,
#  'longitude': 140.9781,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450bb7'),
#  'confidence': 100,
#  'latitude': -36.7708,
#  'longitude': 145.1908,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('60af1c689343690fa9450bbb'),
#  'confidence': 98,
#  'latitude': -37.758,
#  'longitude': 143.179,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa9450bbc'),
#  'confidence': 94,
#  'latitude': -37.7609,
#  'longitude': 143.1633,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('60af1c689343690fa9450bbd'),
#  'confidence': 89,
#  'latitude': -36.5116,
#  'longitude': 144.562,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450bbf'),
#  'confidence': 92,
#  'latitude': -36.803,
#  'longitude': 142.9261,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450bc4'),
#  'confidence': 89,
#  'latitude': -36.4143,
#  'longitude': 143.272,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450bc8'),
#  'confidence': 99,
#  'latitude': -36.7153,
#  'longitude': 143.8226,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('60af1c689343690fa9450bcb'),
#  'confidence': 100,
#  'latitude': -36.8791,
#  'longitude': 142.7261,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa9450bce'),
#  'confidence': 100,
#  'latitude': -36.7309,
#  'longitude': 142.3633,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('60af1c689343690fa9450bcf'),
#  'confidence': 92,
#  'latitude': -36.882,
#  'longitude': 142.7108,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450bd6'),
#  'confidence': 93,
#  'latitude': -37.5135,
#  'longitude': 142.7238,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450bd7'),
#  'confidence': 94,
#  'latitude': -36.2121,
#  'longitude': 144.6885,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('60af1c689343690fa9450bdc'),
#  'confidence': 97,
#  'latitude': -36.2206,
#  'longitude': 144.6856,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9450be1'),
#  'confidence': 88,
#  'latitude': -38.0132,
#  'longitude': 146.5269,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450be3'),
#  'confidence': 87,
#  'latitude': -38.0148,
#  'longitude': 146.5413,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa9450be4'),
#  'confidence': 100,
#  'latitude': -37.8412,
#  'longitude': 147.2536,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c689343690fa9450be5'),
#  'confidence': 96,
#  'latitude': -37.8429,
#  'longitude': 147.2691,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450be8'),
#  'confidence': 100,
#  'latitude': -36.5454,
#  'longitude': 144.7402,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('60af1c689343690fa9450bec'),
#  'confidence': 92,
#  'latitude': -36.7593,
#  'longitude': 142.895,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450bf6'),
#  'confidence': 90,
#  'latitude': -36.3435,
#  'longitude': 141.5513,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450bfc'),
#  'confidence': 93,
#  'latitude': -36.6942,
#  'longitude': 143.8021,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450bff'),
#  'confidence': 100,
#  'latitude': -36.3459,
#  'longitude': 141.5586,
#  'surface_temperature_celcius': 91}
# {'_id': ObjectId('60af1c689343690fa9450c04'),
#  'confidence': 93,
#  'latitude': -36.4046,
#  'longitude': 141.1534,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450c09'),
#  'confidence': 96,
#  'latitude': -36.0594,
#  'longitude': 141.5907,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa9450c0a'),
#  'confidence': 100,
#  'latitude': -36.0576,
#  'longitude': 141.6122,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('60af1c689343690fa9450c14'),
#  'confidence': 93,
#  'latitude': -36.388,
#  'longitude': 141.8309,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450c16'),
#  'confidence': 90,
#  'latitude': -36.094,
#  'longitude': 145.7646,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450c1f'),
#  'confidence': 99,
#  'latitude': -36.5438,
#  'longitude': 144.7548,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('60af1c689343690fa9450c22'),
#  'confidence': 95,
#  'latitude': -36.6537,
#  'longitude': 143.8781,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450c28'),
#  'confidence': 100,
#  'latitude': -38.1917,
#  'longitude': 147.0745,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('60af1c689343690fa9450c2a'),
#  'confidence': 95,
#  'latitude': -38.1987,
#  'longitude': 147.0666,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450c3b'),
#  'confidence': 70,
#  'latitude': -36.9303,
#  'longitude': 143.1034,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450c3d'),
#  'confidence': 83,
#  'latitude': -36.3195,
#  'longitude': 146.0601,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450c3e'),
#  'confidence': 100,
#  'latitude': -36.5839,
#  'longitude': 143.0588,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('60af1c689343690fa9450c3f'),
#  'confidence': 100,
#  'latitude': -36.5854,
#  'longitude': 143.0462,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('60af1c689343690fa9450c41'),
#  'confidence': 95,
#  'latitude': -36.3014,
#  'longitude': 143.203,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450c46'),
#  'confidence': 87,
#  'latitude': -36.3332,
#  'longitude': 145.8594,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa9450c51'),
#  'confidence': 86,
#  'latitude': -37.6775,
#  'longitude': 148.5131,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450c5c'),
#  'confidence': 93,
#  'latitude': -36.9111,
#  'longitude': 142.692,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450c62'),
#  'confidence': 99,
#  'latitude': -37.5115,
#  'longitude': 143.14,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('60af1c689343690fa9450c6d'),
#  'confidence': 93,
#  'latitude': -37.769,
#  'longitude': 147.94,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450c70'),
#  'confidence': 90,
#  'latitude': -36.1303,
#  'longitude': 146.3606,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450c77'),
#  'confidence': 98,
#  'latitude': -36.1345,
#  'longitude': 146.351,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('60af1c689343690fa9450c7e'),
#  'confidence': 99,
#  'latitude': -36.1586,
#  'longitude': 145.6666,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('60af1c689343690fa9450c82'),
#  'confidence': 96,
#  'latitude': -36.5847,
#  'longitude': 145.1968,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450c95'),
#  'confidence': 89,
#  'latitude': -37.876,
#  'longitude': 143.7804,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450c96'),
#  'confidence': 88,
#  'latitude': -36.1546,
#  'longitude': 141.8146,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('60af1c689343690fa9450c99'),
#  'confidence': 87,
#  'latitude': -37.9091,
#  'longitude': 143.5105,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450c9d'),
#  'confidence': 80,
#  'latitude': -36.1559,
#  'longitude': 141.8102,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450ca1'),
#  'confidence': 100,
#  'latitude': -37.9071,
#  'longitude': 143.538,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('60af1c689343690fa9450ca7'),
#  'confidence': 100,
#  'latitude': -37.3902,
#  'longitude': 148.2955,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('60af1c689343690fa9450ca9'),
#  'confidence': 100,
#  'latitude': -37.5027,
#  'longitude': 146.347,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('60af1c689343690fa9450caa'),
#  'confidence': 100,
#  'latitude': -37.5043,
#  'longitude': 146.3299,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa9450cb5'),
#  'confidence': 93,
#  'latitude': -36.1964,
#  'longitude': 144.5217,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450cc2'),
#  'confidence': 91,
#  'latitude': -37.6397,
#  'longitude': 142.5968,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450cc7'),
#  'confidence': 90,
#  'latitude': -37.6267,
#  'longitude': 142.9993,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450cd0'),
#  'confidence': 93,
#  'latitude': -36.5871,
#  'longitude': 144.4958,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450cd3'),
#  'confidence': 89,
#  'latitude': -36.2618,
#  'longitude': 141.8783,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450cd5'),
#  'confidence': 90,
#  'latitude': -36.6828,
#  'longitude': 144.784,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450cd8'),
#  'confidence': 89,
#  'latitude': -37.4843,
#  'longitude': 143.0592,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450cf1'),
#  'confidence': 94,
#  'latitude': -37.7274,
#  'longitude': 142.9536,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450cf2'),
#  'confidence': 91,
#  'latitude': -37.6964,
#  'longitude': 142.8583,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450cf6'),
#  'confidence': 98,
#  'latitude': -38.0509,
#  'longitude': 143.9423,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa9450cf8'),
#  'confidence': 92,
#  'latitude': -37.9284,
#  'longitude': 143.108,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450cfc'),
#  'confidence': 100,
#  'latitude': -37.5701,
#  'longitude': 142.6497,
#  'surface_temperature_celcius': 94}
# {'_id': ObjectId('60af1c689343690fa9450d06'),
#  'confidence': 90,
#  'latitude': -36.7101,
#  'longitude': 142.3865,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450d0b'),
#  'confidence': 93,
#  'latitude': -38.1693,
#  'longitude': 143.0466,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450d0d'),
#  'confidence': 95,
#  'latitude': -36.7128,
#  'longitude': 142.3717,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450d0e'),
#  'confidence': 97,
#  'latitude': -37.4885,
#  'longitude': 142.0658,
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('60af1c689343690fa9450d1a'),
#  'confidence': 77,
#  'latitude': -36.7101,
#  'longitude': 142.981,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450d1b'),
#  'confidence': 89,
#  'latitude': -37.0959,
#  'longitude': 143.8206,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450d1f'),
#  'confidence': 100,
#  'latitude': -37.9594,
#  'longitude': 143.5638,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c689343690fa9450d25'),
#  'confidence': 98,
#  'latitude': -36.5921,
#  'longitude': 144.4905,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa9450d31'),
#  'confidence': 96,
#  'latitude': -36.6787,
#  'longitude': 144.8042,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa9450d39'),
#  'confidence': 84,
#  'latitude': -38.0423,
#  'longitude': 146.4048,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450d42'),
#  'confidence': 94,
#  'latitude': -38.1224,
#  'longitude': 143.7553,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450d47'),
#  'confidence': 94,
#  'latitude': -38.0792,
#  'longitude': 143.7361,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa9450d57'),
#  'confidence': 93,
#  'latitude': -37.9157,
#  'longitude': 143.3544,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450d6c'),
#  'confidence': 96,
#  'latitude': -37.7935,
#  'longitude': 143.1606,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450d6f'),
#  'confidence': 90,
#  'latitude': -37.7756,
#  'longitude': 143.1388,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450d78'),
#  'confidence': 91,
#  'latitude': -37.7171,
#  'longitude': 142.9505,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450d79'),
#  'confidence': 94,
#  'latitude': -37.7236,
#  'longitude': 142.947,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450d7b'),
#  'confidence': 100,
#  'latitude': -37.7002,
#  'longitude': 142.9562,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('60af1c689343690fa9450d85'),
#  'confidence': 92,
#  'latitude': -37.6498,
#  'longitude': 142.5997,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450d89'),
#  'confidence': 100,
#  'latitude': -37.5728,
#  'longitude': 142.6348,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('60af1c689343690fa9450d8c'),
#  'confidence': 100,
#  'latitude': -37.4352,
#  'longitude': 143.1444,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('60af1c689343690fa9450db0'),
#  'confidence': 92,
#  'latitude': -36.5828,
#  'longitude': 144.5775,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450db1'),
#  'confidence': 96,
#  'latitude': -36.5987,
#  'longitude': 144.4995,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa9450dbb'),
#  'confidence': 98,
#  'latitude': -36.5262,
#  'longitude': 144.5737,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('60af1c689343690fa9450dc5'),
#  'confidence': 95,
#  'latitude': -36.6995,
#  'longitude': 142.978,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450dca'),
#  'confidence': 93,
#  'latitude': -36.8879,
#  'longitude': 141.6647,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450dd6'),
#  'confidence': 100,
#  'latitude': -35.8768,
#  'longitude': 145.4627,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('60af1c689343690fa9450dd7'),
#  'confidence': 93,
#  'latitude': -36.4899,
#  'longitude': 142.2805,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450dd9'),
#  'confidence': 93,
#  'latitude': -36.663,
#  'longitude': 141.3038,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450de5'),
#  'confidence': 94,
#  'latitude': -36.092,
#  'longitude': 141.7306,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa9450de7'),
#  'confidence': 89,
#  'latitude': -34.9023,
#  'longitude': 142.0557,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450ded'),
#  'confidence': 91,
#  'latitude': -36.2637,
#  'longitude': 145.3649,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450dee'),
#  'confidence': 89,
#  'latitude': -37.2609,
#  'longitude': 141.7999,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450df1'),
#  'confidence': 93,
#  'latitude': -36.91,
#  'longitude': 141.0704,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450df7'),
#  'confidence': 92,
#  'latitude': -36.2652,
#  'longitude': 145.3769,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450df9'),
#  'confidence': 95,
#  'latitude': -36.738,
#  'longitude': 142.1177,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450e11'),
#  'confidence': 95,
#  'latitude': -36.5199,
#  'longitude': 144.7311,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450e15'),
#  'confidence': 91,
#  'latitude': -37.0782,
#  'longitude': 145.3625,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450e1b'),
#  'confidence': 94,
#  'latitude': -36.3966,
#  'longitude': 141.406,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('60af1c689343690fa9450e1e'),
#  'confidence': 90,
#  'latitude': -37.1349,
#  'longitude': 141.9491,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450e2e'),
#  'confidence': 91,
#  'latitude': -36.7651,
#  'longitude': 143.5801,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450e39'),
#  'confidence': 98,
#  'latitude': -36.9329,
#  'longitude': 143.7796,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa9450e3c'),
#  'confidence': 99,
#  'latitude': -35.8276,
#  'longitude': 143.7549,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('60af1c689343690fa9450e4d'),
#  'confidence': 78,
#  'latitude': -35.9326,
#  'longitude': 141.958,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450e55'),
#  'confidence': 91,
#  'latitude': -36.6892,
#  'longitude': 145.2775,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450e56'),
#  'confidence': 89,
#  'latitude': -36.73,
#  'longitude': 143.935,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450e58'),
#  'confidence': 100,
#  'latitude': -36.8283,
#  'longitude': 143.4605,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa9450e5d'),
#  'confidence': 97,
#  'latitude': -36.6527,
#  'longitude': 142.7392,
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('60af1c689343690fa9450e5e'),
#  'confidence': 96,
#  'latitude': -36.1898,
#  'longitude': 145.0922,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450e64'),
#  'confidence': 96,
#  'latitude': -36.8298,
#  'longitude': 143.4483,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa9450e67'),
#  'confidence': 100,
#  'latitude': -36.6615,
#  'longitude': 144.6014,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa9450e68'),
#  'confidence': 93,
#  'latitude': -36.8238,
#  'longitude': 143.5724,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450e7b'),
#  'confidence': 100,
#  'latitude': -36.1988,
#  'longitude': 145.0941,
#  'surface_temperature_celcius': 100}
# {'_id': ObjectId('60af1c689343690fa9450e7d'),
#  'confidence': 75,
#  'latitude': -36.7499,
#  'longitude': 141.3006,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('60af1c689343690fa9450e84'),
#  'confidence': 84,
#  'latitude': -36.7432,
#  'longitude': 141.3296,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa9450e86'),
#  'confidence': 84,
#  'latitude': -36.7531,
#  'longitude': 141.3253,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450e8a'),
#  'confidence': 99,
#  'latitude': -36.7943,
#  'longitude': 143.9571,
#  'surface_temperature_celcius': 84}
# {'_id': ObjectId('60af1c689343690fa9450e8c'),
#  'confidence': 100,
#  'latitude': -36.7957,
#  'longitude': 143.9652,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c689343690fa9450e8f'),
#  'confidence': 96,
#  'latitude': -36.9498,
#  'longitude': 142.2012,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450e90'),
#  'confidence': 93,
#  'latitude': -36.1941,
#  'longitude': 143.1604,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450e91'),
#  'confidence': 100,
#  'latitude': -36.4142,
#  'longitude': 143.1077,
#  'surface_temperature_celcius': 97}
# {'_id': ObjectId('60af1c689343690fa9450e93'),
#  'confidence': 92,
#  'latitude': -36.1924,
#  'longitude': 143.1716,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450e97'),
#  'confidence': 89,
#  'latitude': -36.0295,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450e9e'),
#  'confidence': 100,
#  'latitude': -37.0761,
#  'longitude': 141.0574,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('60af1c689343690fa9450ea0'),
#  'confidence': 93,
#  'latitude': -35.0616,
#  'longitude': 141.4417,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9450ea1'),
#  'confidence': 100,
#  'latitude': -36.3999,
#  'longitude': 144.737,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('60af1c689343690fa9450ea7'),
#  'confidence': 91,
#  'latitude': -36.1748,
#  'longitude': 145.7582,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450ea8'),
#  'confidence': 99,
#  'latitude': -36.0691,
#  'longitude': 145.7797,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('60af1c689343690fa9450eab'),
#  'confidence': 90,
#  'latitude': -35.1949,
#  'longitude': 141.0622,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450eae'),
#  'confidence': 100,
#  'latitude': -36.91,
#  'longitude': 141.2705,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('60af1c689343690fa9450eb1'),
#  'confidence': 89,
#  'latitude': -35.8071,
#  'longitude': 142.7318,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450eb3'),
#  'confidence': 97,
#  'latitude': -36.7787,
#  'longitude': 141.4449,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9450ec4'),
#  'confidence': 98,
#  'latitude': -36.2948,
#  'longitude': 141.3486,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa9450ec5'),
#  'confidence': 89,
#  'latitude': -38.1561,
#  'longitude': 143.7846,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450ec7'),
#  'confidence': 90,
#  'latitude': -37.8185,
#  'longitude': 142.5609,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450eda'),
#  'confidence': 100,
#  'latitude': -36.1771,
#  'longitude': 145.7451,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa9450edd'),
#  'confidence': 100,
#  'latitude': -38.027,
#  'longitude': 142.3844,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('60af1c689343690fa9450edf'),
#  'confidence': 89,
#  'latitude': -35.7642,
#  'longitude': 143.3321,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450ee4'),
#  'confidence': 90,
#  'latitude': -36.429,
#  'longitude': 141.5759,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450ee5'),
#  'confidence': 92,
#  'latitude': -36.1346,
#  'longitude': 145.2196,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa9450ee9'),
#  'confidence': 100,
#  'latitude': -37.0899,
#  'longitude': 141.0238,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa9450ef6'),
#  'confidence': 95,
#  'latitude': -36.3823,
#  'longitude': 141.3146,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9450ef7'),
#  'confidence': 90,
#  'latitude': -36.1462,
#  'longitude': 145.2096,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450ef9'),
#  'confidence': 93,
#  'latitude': -36.5243,
#  'longitude': 142.0839,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450f01'),
#  'confidence': 98,
#  'latitude': -37.618,
#  'longitude': 143.0013,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa9450f02'),
#  'confidence': 90,
#  'latitude': -36.8867,
#  'longitude': 142.1873,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450f04'),
#  'confidence': 92,
#  'latitude': -36.9364,
#  'longitude': 143.4996,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9450f06'),
#  'confidence': 100,
#  'latitude': -37.3847,
#  'longitude': 142.8935,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('60af1c689343690fa9450f0d'),
#  'confidence': 100,
#  'latitude': -35.6374,
#  'longitude': 142.3787,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('60af1c689343690fa9450f0e'),
#  'confidence': 90,
#  'latitude': -36.8835,
#  'longitude': 142.2098,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450f0f'),
#  'confidence': 100,
#  'latitude': -36.4125,
#  'longitude': 143.1189,
#  'surface_temperature_celcius': 92}
# {'_id': ObjectId('60af1c689343690fa9450f13'),
#  'confidence': 97,
#  'latitude': -37.0669,
#  'longitude': 141.0556,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9450f16'),
#  'confidence': 92,
#  'latitude': -36.0714,
#  'longitude': 145.7665,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa9450f22'),
#  'confidence': 94,
#  'latitude': -36.2933,
#  'longitude': 141.36,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa9450f25'),
#  'confidence': 100,
#  'latitude': -37.4591,
#  'longitude': 144.9492,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('60af1c689343690fa9450f27'),
#  'confidence': 91,
#  'latitude': -36.3487,
#  'longitude': 145.5315,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450f37'),
#  'confidence': 90,
#  'latitude': -36.5399,
#  'longitude': 144.678,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9450f3a'),
#  'confidence': 97,
#  'latitude': -36.8158,
#  'longitude': 142.6229,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9450f3b'),
#  'confidence': 100,
#  'latitude': -36.4518,
#  'longitude': 144.7752,
#  'surface_temperature_celcius': 97}
# {'_id': ObjectId('60af1c689343690fa9450f3d'),
#  'confidence': 90,
#  'latitude': -36.7903,
#  'longitude': 141.618,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450f49'),
#  'confidence': 97,
#  'latitude': -36.1067,
#  'longitude': 143.7948,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa9450f4a'),
#  'confidence': 89,
#  'latitude': -36.1441,
#  'longitude': 145.2221,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450f53'),
#  'confidence': 94,
#  'latitude': -36.4816,
#  'longitude': 141.6635,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa9450f55'),
#  'confidence': 100,
#  'latitude': -36.0837,
#  'longitude': 144.2448,
#  'surface_temperature_celcius': 87}
# {'_id': ObjectId('60af1c689343690fa9450f5a'),
#  'confidence': 90,
#  'latitude': -36.782,
#  'longitude': 141.8851,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9450f63'),
#  'confidence': 92,
#  'latitude': -36.5586,
#  'longitude': 144.0423,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa9450f64'),
#  'confidence': 90,
#  'latitude': -36.5568,
#  'longitude': 144.0538,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450f65'),
#  'confidence': 97,
#  'latitude': -36.4538,
#  'longitude': 144.763,
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('60af1c689343690fa9450f67'),
#  'confidence': 91,
#  'latitude': -36.4612,
#  'longitude': 144.7775,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9450f6a'),
#  'confidence': 100,
#  'latitude': -36.7089,
#  'longitude': 143.3518,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa9450f75'),
#  'confidence': 97,
#  'latitude': -36.601,
#  'longitude': 144.6378,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9450f7e'),
#  'confidence': 95,
#  'latitude': -36.8681,
#  'longitude': 143.5186,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9450f88'),
#  'confidence': 100,
#  'latitude': -37.1999,
#  'longitude': 143.8231,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa9450f94'),
#  'confidence': 91,
#  'latitude': -37.6171,
#  'longitude': 142.9426,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9450f9b'),
#  'confidence': 84,
#  'latitude': -37.7587,
#  'longitude': 142.8521,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9450f9f'),
#  'confidence': 91,
#  'latitude': -37.4611,
#  'longitude': 144.9371,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450fa9'),
#  'confidence': 100,
#  'latitude': -38.0254,
#  'longitude': 142.3959,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('60af1c689343690fa9450fae'),
#  'confidence': 89,
#  'latitude': -37.88,
#  'longitude': 143.7233,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9450fb1'),
#  'confidence': 99,
#  'latitude': -37.8885,
#  'longitude': 143.9157,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('60af1c689343690fa9450fb5'),
#  'confidence': 95,
#  'latitude': -35.0706,
#  'longitude': 141.4435,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa9450fb6'),
#  'confidence': 100,
#  'latitude': -38.0795,
#  'longitude': 143.2449,
#  'surface_temperature_celcius': 91}
# {'_id': ObjectId('60af1c689343690fa9450fb9'),
#  'confidence': 100,
#  'latitude': -35.1857,
#  'longitude': 141.0604,
#  'surface_temperature_celcius': 92}
# {'_id': ObjectId('60af1c689343690fa9450fc2'),
#  'confidence': 100,
#  'latitude': -35.6469,
#  'longitude': 142.376,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa9450fc3'),
#  'confidence': 91,
#  'latitude': -35.6453,
#  'longitude': 142.387,
# ...
# {'_id': ObjectId('60af1c689343690fa9451098'),
#  'confidence': 100,
#  'latitude': -37.782,
#  'longitude': 148.3844,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('60af1c689343690fa945109e'),
#  'confidence': 89,
#  'latitude': -36.9902,
#  'longitude': 141.879,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa945109f'),
#  'confidence': 89,
#  'latitude': -37.745,
#  'longitude': 142.993,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa94510a3'),
#  'confidence': 92,
#  'latitude': -36.0157,
#  'longitude': 145.9414,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa94510a7'),
#  'confidence': 99,
#  'latitude': -37.777,
#  'longitude': 148.4128,
#  'surface_temperature_celcius': 85}
# {'_id': ObjectId('60af1c689343690fa94510a8'),
#  'confidence': 93,
#  'latitude': -37.5888,
#  'longitude': 148.5949,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa94510aa'),
#  'confidence': 89,
#  'latitude': -34.3943,
#  'longitude': 141.7567,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa94510b2'),
#  'confidence': 81,
#  'latitude': -36.0844,
#  'longitude': 141.4934,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa94510b7'),
#  'confidence': 91,
#  'latitude': -36.031,
#  'longitude': 145.6824,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa94510b9'),
#  'confidence': 86,
#  'latitude': -37.5814,
#  'longitude': 148.5777,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa94510bc'),
#  'confidence': 90,
#  'latitude': -37.5788,
#  'longitude': 148.592,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa94510be'),
#  'confidence': 90,
#  'latitude': -36.6384,
#  'longitude': 142.4075,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa94510c3'),
#  'confidence': 94,
#  'latitude': -35.811,
#  'longitude': 142.1403,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('60af1c689343690fa94510c9'),
#  'confidence': 100,
#  'latitude': -36.9034,
#  'longitude': 141.0013,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('60af1c689343690fa94510ca'),
#  'confidence': 88,
#  'latitude': -37.7746,
#  'longitude': 148.3673,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa94510cf'),
#  'confidence': 83,
#  'latitude': -37.803,
#  'longitude': 142.3151,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa94510d2'),
#  'confidence': 96,
#  'latitude': -37.7542,
#  'longitude': 142.9949,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa94510d3'),
#  'confidence': 91,
#  'latitude': -37.3803,
#  'longitude': 145.611,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa94510d4'),
#  'confidence': 97,
#  'latitude': -37.7617,
#  'longitude': 143.081,
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('60af1c689343690fa94510d7'),
#  'confidence': 92,
#  'latitude': -37.8161,
#  'longitude': 142.9286,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa94510e8'),
#  'confidence': 90,
#  'latitude': -36.0387,
#  'longitude': 145.6787,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa94510ea'),
#  'confidence': 94,
#  'latitude': -36.6349,
#  'longitude': 142.2125,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('60af1c689343690fa94510f0'),
#  'confidence': 100,
#  'latitude': -36.9018,
#  'longitude': 141.0146,
#  'surface_temperature_celcius': 100}
# {'_id': ObjectId('60af1c689343690fa94510f1'),
#  'confidence': 86,
#  'latitude': -36.6986,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa94510fc'),
#  'confidence': 94,
#  'latitude': -38.0052,
#  'longitude': 142.6179,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('60af1c689343690fa9451112'),
#  'confidence': 87,
#  'latitude': -37.6387,
#  'longitude': 142.9032,
#  'surface_temperature_celcius': 88}
# {'_id': ObjectId('60af1c689343690fa9451116'),
#  'confidence': 93,
#  'latitude': -37.6439,
#  'longitude': 142.913,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('60af1c689343690fa945111b'),
#  'confidence': 93,
#  'latitude': -37.3165,
#  'longitude': 147.4932,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa945111f'),
#  'confidence': 95,
#  'latitude': -37.3158,
#  'longitude': 147.4986,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9451121'),
#  'confidence': 89,
#  'latitude': -37.4471,
#  'longitude': 147.6331,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9451124'),
#  'confidence': 90,
#  'latitude': -37.7835,
#  'longitude': 148.4138,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9451127'),
#  'confidence': 89,
#  'latitude': -37.4449,
#  'longitude': 147.6594,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9451129'),
#  'confidence': 95,
#  'latitude': -37.4323,
#  'longitude': 147.6583,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa945112a'),
#  'confidence': 100,
#  'latitude': -37.4343,
#  'longitude': 147.6327,
#  'surface_temperature_celcius': 92}
# {'_id': ObjectId('60af1c689343690fa945113c'),
#  'confidence': 90,
#  'latitude': -35.4033,
#  'longitude': 143.267,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa945113d'),
#  'confidence': 64,
#  'latitude': -36.6281,
#  'longitude': 142.4349,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa945113e'),
#  'confidence': 85,
#  'latitude': -36.111,
#  'longitude': 145.124,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa945113f'),
#  'confidence': 90,
#  'latitude': -36.1615,
#  'longitude': 141.8728,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9451152'),
#  'confidence': 90,
#  'latitude': -36.1122,
#  'longitude': 142.1491,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa9451155'),
#  'confidence': 100,
#  'latitude': -37.3735,
#  'longitude': 145.8384,
#  'surface_temperature_celcius': 95}
# {'_id': ObjectId('60af1c689343690fa9451158'),
#  'confidence': 89,
#  'latitude': -35.4255,
#  'longitude': 143.6306,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa945115b'),
#  'confidence': 96,
#  'latitude': -36.1955,
#  'longitude': 145.914,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa945115c'),
#  'confidence': 85,
#  'latitude': -35.4533,
#  'longitude': 143.2029,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa945115e'),
#  'confidence': 92,
#  'latitude': -36.5989,
#  'longitude': 141.9771,
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('60af1c689343690fa9451167'),
#  'confidence': 66,
#  'latitude': -36.6299,
#  'longitude': 142.4234,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa945116c'),
#  'confidence': 97,
#  'latitude': -36.1925,
#  'longitude': 145.93,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa945116e'),
#  'confidence': 98,
#  'latitude': -36.095,
#  'longitude': 141.7699,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa9451178'),
#  'confidence': 96,
#  'latitude': -36.6006,
#  'longitude': 141.9657,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa945117a'),
#  'confidence': 93,
#  'latitude': -37.0769,
#  'longitude': 141.042,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa945117d'),
#  'confidence': 79,
#  'latitude': -36.883,
#  'longitude': 142.1637,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa945117e'),
#  'confidence': 87,
#  'latitude': -36.0973,
#  'longitude': 143.4279,
#  'surface_temperature_celcius': 92}
# {'_id': ObjectId('60af1c689343690fa9451188'),
#  'confidence': 100,
#  'latitude': -36.1819,
#  'longitude': 145.9269,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('60af1c689343690fa9451192'),
#  'confidence': 87,
#  'latitude': -37.3735,
#  'longitude': 145.886,
#  'surface_temperature_celcius': 96}
# {'_id': ObjectId('60af1c689343690fa9451194'),
#  'confidence': 93,
#  'latitude': -37.7465,
#  'longitude': 143.3806,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9451199'),
#  'confidence': 95,
#  'latitude': -37.8072,
#  'longitude': 145.9738,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa945119a'),
#  'confidence': 96,
#  'latitude': -37.3704,
#  'longitude': 145.8942,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa945119b'),
#  'confidence': 100,
#  'latitude': -37.297,
#  'longitude': 143.5753,
#  'surface_temperature_celcius': 93}
# {'_id': ObjectId('60af1c689343690fa94511a3'),
#  'confidence': 100,
#  'latitude': -37.2988,
#  'longitude': 143.5487,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa94511a8'),
#  'confidence': 100,
#  'latitude': -37.3025,
#  'longitude': 143.5714,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('60af1c689343690fa94511a9'),
#  'confidence': 100,
#  'latitude': -37.383,
#  'longitude': 145.9089,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('60af1c689343690fa94511ae'),
#  'confidence': 89,
#  'latitude': -37.7446,
#  'longitude': 143.4085,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa94511b3'),
#  'confidence': 98,
#  'latitude': -37.7509,
#  'longitude': 143.4023,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa94511b6'),
#  'confidence': 87,
#  'latitude': -37.7974,
#  'longitude': 145.9535,
#  'surface_temperature_celcius': 97}
# {'_id': ObjectId('60af1c689343690fa94511bb'),
#  'confidence': 90,
#  'latitude': -35.7657,
#  'longitude': 142.0906,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa94511c3'),
#  'confidence': 99,
#  'latitude': -37.7236,
#  'longitude': 143.3995,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('60af1c689343690fa94511c5'),
#  'confidence': 93,
#  'latitude': -37.3046,
#  'longitude': 143.5448,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa94511c8'),
#  'confidence': 95,
#  'latitude': -36.4312,
#  'longitude': 141.2064,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa94511cb'),
#  'confidence': 89,
#  'latitude': -36.1556,
#  'longitude': 141.5904,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa94511ce'),
#  'confidence': 89,
#  'latitude': -35.7647,
#  'longitude': 142.0858,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa94511fa'),
#  'confidence': 92,
#  'latitude': -36.4557,
#  'longitude': 142.2434,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa94511fb'),
#  'confidence': 95,
#  'latitude': -36.8009,
#  'longitude': 142.7259,
#  'surface_temperature_celcius': 76}
# {'_id': ObjectId('60af1c689343690fa94511fd'),
#  'confidence': 93,
#  'latitude': -36.8099,
#  'longitude': 142.728,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9451202'),
#  'confidence': 94,
#  'latitude': -36.7806,
#  'longitude': 141.5597,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('60af1c689343690fa9451205'),
#  'confidence': 98,
#  'latitude': -34.3526,
#  'longitude': 141.6458,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa9451207'),
#  'confidence': 97,
#  'latitude': -37.0924,
#  'longitude': 141.897,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa945120f'),
#  'confidence': 97,
#  'latitude': -37.9452,
#  'longitude': 143.5834,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9451215'),
#  'confidence': 99,
#  'latitude': -34.351,
#  'longitude': 141.6567,
#  'surface_temperature_celcius': 86}
# {'_id': ObjectId('60af1c689343690fa945121b'),
#  'confidence': 100,
#  'latitude': -37.5012,
#  'longitude': 142.5853,
#  'surface_temperature_celcius': 90}
# {'_id': ObjectId('60af1c689343690fa945121f'),
#  'confidence': 97,
#  'latitude': -37.9247,
#  'longitude': 142.8999,
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('60af1c689343690fa9451227'),
#  'confidence': 97,
#  'latitude': -35.0805,
#  'longitude': 142.4642,
#  'surface_temperature_celcius': 81}
# {'_id': ObjectId('60af1c689343690fa9451234'),
#  'confidence': 71,
#  'latitude': -37.522,
#  'longitude': 143.3874,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9451235'),
#  'confidence': 91,
#  'latitude': -38.0674,
#  'longitude': 142.965,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9451236'),
#  'confidence': 92,
#  'latitude': -38.0715,
#  'longitude': 142.9591,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9451237'),
#  'confidence': 100,
#  'latitude': -38.0693,
#  'longitude': 142.9722,
#  'surface_temperature_celcius': 89}
# {'_id': ObjectId('60af1c689343690fa9451241'),
#  'confidence': 82,
#  'latitude': -37.8973,
#  'longitude': 143.4754,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa9451243'),
#  'confidence': 95,
#  'latitude': -37.7805,
#  'longitude': 143.5003,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa9451246'),
#  'confidence': 95,
#  'latitude': -37.8774,
#  'longitude': 145.8213,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa9451248'),
#  'confidence': 100,
#  'latitude': -37.8881,
#  'longitude': 145.8229,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('60af1c689343690fa945124f'),
#  'confidence': 96,
#  'latitude': -37.6622,
#  'longitude': 142.1001,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa9451252'),
#  'confidence': 90,
#  'latitude': -37.4523,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 66}
# {'_id': ObjectId('60af1c689343690fa9451258'),
#  'confidence': 98,
#  'latitude': -37.4261,
#  'longitude': 147.0323,
#  'surface_temperature_celcius': 83}
# {'_id': ObjectId('60af1c689343690fa9451259'),
#  'confidence': 100,
#  'latitude': -37.3949,
#  'longitude': 147.0175,
#  'surface_temperature_celcius': 91}
# {'_id': ObjectId('60af1c689343690fa945125d'),
#  'confidence': 92,
#  'latitude': -37.6625,
#  'longitude': 144.287,
#  'surface_temperature_celcius': 70}
# {'_id': ObjectId('60af1c689343690fa9451264'),
#  'confidence': 97,
#  'latitude': -37.0155,
#  'longitude': 148.1432,
#  'surface_temperature_celcius': 80}
# {'_id': ObjectId('60af1c689343690fa9451266'),
#  'confidence': 94,
#  'latitude': -36.7152,
#  'longitude': 141.3853,
#  'surface_temperature_celcius': 74}
# {'_id': ObjectId('60af1c689343690fa9451272'),
#  'confidence': 90,
#  'latitude': -34.357,
#  'longitude': 141.5361,
#  'surface_temperature_celcius': 67}
# {'_id': ObjectId('60af1c689343690fa9451273'),
#  'confidence': 93,
#  'latitude': -34.3539,
#  'longitude': 141.5547,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9451274'),
#  'confidence': 90,
#  'latitude': -36.9939,
#  'longitude': 148.2244,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9451276'),
#  'confidence': 95,
#  'latitude': -36.9959,
#  'longitude': 148.2118,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa9451277'),
#  'confidence': 89,
#  'latitude': -34.3654,
#  'longitude': 141.543,
#  'surface_temperature_celcius': 65}
# {'_id': ObjectId('60af1c689343690fa945127a'),
#  'confidence': 96,
#  'latitude': -34.3554,
#  'longitude': 141.5413,
#  'surface_temperature_celcius': 79}
# {'_id': ObjectId('60af1c689343690fa945127b'),
#  'confidence': 94,
#  'latitude': -34.3555,
#  'longitude': 141.5495,
#  'surface_temperature_celcius': 75}
# {'_id': ObjectId('60af1c689343690fa945127f'),
#  'confidence': 84,
#  'latitude': -37.0193,
#  'longitude': 148.1459,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa9451280'),
#  'confidence': 100,
#  'latitude': -37.4229,
#  'longitude': 147.027,
#  'surface_temperature_celcius': 99}
# {'_id': ObjectId('60af1c689343690fa9451281'),
#  'confidence': 80,
#  'latitude': -37.0055,
#  'longitude': 148.1582,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9451282'),
#  'confidence': 85,
#  'latitude': -37.4128,
#  'longitude': 147.0242,
#  'surface_temperature_celcius': 98}
# {'_id': ObjectId('60af1c689343690fa9451285'),
#  'confidence': 94,
#  'latitude': -37.2284,
#  'longitude': 147.9187,
#  'surface_temperature_celcius': 73}
# {'_id': ObjectId('60af1c689343690fa9451286'),
#  'confidence': 97,
#  'latitude': -37.6572,
#  'longitude': 142.0703,
#  'surface_temperature_celcius': 80}

# %% [markdown]
# **c. Find date, surface temperature (°C), air temperature (°C), relative humidity and max wind speed on 15th and 16th of December 2018.**

# %%
results = climates.aggregate(
    [
        {
            "$match": { "$or": [{ "date": '15/12/2018' }, {"date": '16/12/2018' }] }
        },
        {
            "$lookup":{
                    "from": "fire_historic",
                    "localField": "fires",
                    "foreignField" : "_id",
                    "as": "fires"
            }
        },
        {
            "$project": {
                "date": 1, 
                "fires.surface_temperature_celcius":1, 
                "air_temperature_celcius":1, 
                "relative_humidity": 1,
                "max_wind_speed": 1, 
            }
        }
    ]
)

for document in results:
    pprint(document)
# Out:
# {'_id': ObjectId('60af1c5e9343690fa9450815'),
#  'air_temperature_celcius': 18,
#  'date': '15/12/2018',
#  'fires': [{'surface_temperature_celcius': 42},
#            {'surface_temperature_celcius': 36},
#            {'surface_temperature_celcius': 38},
#            {'surface_temperature_celcius': 40}],
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'date': '16/12/2018',
#  'fires': [{'surface_temperature_celcius': 43},
#            {'surface_temperature_celcius': 33},
#            {'surface_temperature_celcius': 54},
#            {'surface_temperature_celcius': 73},
#            {'surface_temperature_celcius': 55},
#            {'surface_temperature_celcius': 75},
#            {'surface_temperature_celcius': 55},
#            {'surface_temperature_celcius': 66},
#            {'surface_temperature_celcius': 56},
#            {'surface_temperature_celcius': 60},
#            {'surface_temperature_celcius': 73},
#            {'surface_temperature_celcius': 48},
#            {'surface_temperature_celcius': 55},
#            {'surface_temperature_celcius': 64},
#            {'surface_temperature_celcius': 57}],
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %% [markdown]
# **d. Find datetime, air temperature (°C), surface temperature (°C) and confidence when the confidence is between 80 and 100.**

# %%
results = climates.aggregate(
    [
        
        {
            "$lookup":{
                    "from": "fire_historic",
                    "localField": "fires",
                    "foreignField" : "_id",
                    "as": "fires"
            }
        },
        {
             "$unwind": "$fires"
        },
        {
            "$match": { "$and": [{ "fires.confidence": { "$gte": 80 } }, {"fires.confidence": { "$lte": 100 } }] }
        },
        {
            "$project": {
                "fires.datetime": 1, 
                "air_temperature_celcius":1, 
                "fires.surface_temperature_celcius":1, 
                "fires.confidence": 1, 
            }
        }
    ]
)

for document in results:
    pprint(document)
# Out:
# {'_id': ObjectId('60af1c5e9343690fa94506f9'),
#  'air_temperature_celcius': 20,
#  'fires': {'confidence': 87,
#            'datetime': '2018-03-06T05:06:30',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa94506f9'),
#  'air_temperature_celcius': 20,
#  'fires': {'confidence': 85,
#            'datetime': '2018-03-06T05:06:20',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa94506fa'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 88,
#            'datetime': '2018-03-07T04:16:10',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa94506fc'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 86,
#            'datetime': '2018-03-09T13:23:40',
#            'surface_temperature_celcius': 41}}
# {'_id': ObjectId('60af1c5e9343690fa94506fd'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-10T04:48:40',
#            'surface_temperature_celcius': 105}}
# {'_id': ObjectId('60af1c5e9343690fa94506fd'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-10T04:46:20',
#            'surface_temperature_celcius': 109}}
# {'_id': ObjectId('60af1c5e9343690fa94506fd'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 94,
#            'datetime': '2018-03-10T04:45:30',
#            'surface_temperature_celcius': 73}}
# {'_id': ObjectId('60af1c5e9343690fa94506fd'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 97,
#            'datetime': '2018-03-10T04:45:30',
#            'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60af1c5e9343690fa94506fd'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 81,
#            'datetime': '2018-03-10T04:43:50',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa94506ff'),
#  'air_temperature_celcius': 21,
#  'fires': {'confidence': 94,
#            'datetime': '2018-03-12T04:33:50',
#            'surface_temperature_celcius': 105}}
# {'_id': ObjectId('60af1c5e9343690fa94506ff'),
#  'air_temperature_celcius': 21,
#  'fires': {'confidence': 84,
#            'datetime': '2018-03-12T04:29:50',
#            'surface_temperature_celcius': 71}}
# {'_id': ObjectId('60af1c5e9343690fa94506ff'),
#  'air_temperature_celcius': 21,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-12T04:28:20',
#            'surface_temperature_celcius': 99}}
# {'_id': ObjectId('60af1c5e9343690fa94506ff'),
#  'air_temperature_celcius': 21,
#  'fires': {'confidence': 80,
#            'datetime': '2018-03-12T04:28:00',
#            'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60af1c5e9343690fa94506ff'),
#  'air_temperature_celcius': 21,
#  'fires': {'confidence': 85,
#            'datetime': '2018-03-12T04:27:20',
#            'surface_temperature_celcius': 98}}
# {'_id': ObjectId('60af1c5e9343690fa9450701'),
#  'air_temperature_celcius': 25,
#  'fires': {'confidence': 90,
#            'datetime': '2018-03-14T04:24:40',
#            'surface_temperature_celcius': 67}}
# {'_id': ObjectId('60af1c5e9343690fa9450701'),
#  'air_temperature_celcius': 25,
#  'fires': {'confidence': 93,
#            'datetime': '2018-03-14T04:22:20',
#            'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60af1c5e9343690fa9450701'),
#  'air_temperature_celcius': 25,
#  'fires': {'confidence': 90,
#            'datetime': '2018-03-14T04:20:50',
#            'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60af1c5e9343690fa9450701'),
#  'air_temperature_celcius': 25,
#  'fires': {'confidence': 95,
#            'datetime': '2018-03-14T04:16:30',
#            'surface_temperature_celcius': 75}}
# {'_id': ObjectId('60af1c5e9343690fa9450701'),
#  'air_temperature_celcius': 25,
#  'fires': {'confidence': 89,
#            'datetime': '2018-03-14T04:16:20',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450701'),
#  'air_temperature_celcius': 25,
#  'fires': {'confidence': 81,
#            'datetime': '2018-03-14T04:14:40',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450701'),
#  'air_temperature_celcius': 25,
#  'fires': {'confidence': 96,
#            'datetime': '2018-03-14T04:14:30',
#            'surface_temperature_celcius': 79}}
# {'_id': ObjectId('60af1c5e9343690fa9450701'),
#  'air_temperature_celcius': 25,
#  'fires': {'confidence': 94,
#            'datetime': '2018-03-14T04:14:30',
#            'surface_temperature_celcius': 75}}
# {'_id': ObjectId('60af1c5e9343690fa9450704'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 94,
#            'datetime': '2018-03-17T04:48:20',
#            'surface_temperature_celcius': 74}}
# {'_id': ObjectId('60af1c5e9343690fa9450704'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 84,
#            'datetime': '2018-03-17T04:45:10',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa9450704'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 86,
#            'datetime': '2018-03-17T04:45:00',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa9450705'),
#  'air_temperature_celcius': 21,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-18T03:50:50',
#            'surface_temperature_celcius': 121}}
# {'_id': ObjectId('60af1c5e9343690fa9450705'),
#  'air_temperature_celcius': 21,
#  'fires': {'confidence': 97,
#            'datetime': '2018-03-18T03:50:40',
#            'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 85,
#            'datetime': '2018-03-19T04:39:50',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 96,
#            'datetime': '2018-03-19T04:39:20',
#            'surface_temperature_celcius': 79}}
# {'_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 90,
#            'datetime': '2018-03-19T04:36:00',
#            'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 98,
#            'datetime': '2018-03-19T04:33:00',
#            'surface_temperature_celcius': 83}}
# {'_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-19T04:32:50',
#            'surface_temperature_celcius': 91}}
# {'_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 84,
#            'datetime': '2018-03-19T04:32:50',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-19T04:32:40',
#            'surface_temperature_celcius': 113}}
# {'_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 92,
#            'datetime': '2018-03-19T04:32:40',
#            'surface_temperature_celcius': 70}}
# {'_id': ObjectId('60af1c5e9343690fa9450706'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-19T04:32:40',
#            'surface_temperature_celcius': 106}}
# {'_id': ObjectId('60af1c5e9343690fa945070c'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 82,
#            'datetime': '2018-03-25T03:59:50',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa945070c'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 87,
#            'datetime': '2018-03-25T03:58:10',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa945070c'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 95,
#            'datetime': '2018-03-25T03:58:10',
#            'surface_temperature_celcius': 75}}
# {'_id': ObjectId('60af1c5e9343690fa945070c'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 85,
#            'datetime': '2018-03-25T03:57:10',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa945070c'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-25T03:57:10',
#            'surface_temperature_celcius': 111}}
# {'_id': ObjectId('60af1c5e9343690fa945070c'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 95,
#            'datetime': '2018-03-25T03:57:10',
#            'surface_temperature_celcius': 77}}
# {'_id': ObjectId('60af1c5e9343690fa945070c'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-25T03:56:40',
#            'surface_temperature_celcius': 99}}
# {'_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 81,
#            'datetime': '2018-03-26T04:43:20',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 80,
#            'datetime': '2018-03-26T04:40:50',
#            'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 81,
#            'datetime': '2018-03-26T04:39:50',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 91,
#            'datetime': '2018-03-26T04:39:10',
#            'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 92,
#            'datetime': '2018-03-26T04:39:10',
#            'surface_temperature_celcius': 70}}
# {'_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-26T04:39:10',
#            'surface_temperature_celcius': 89}}
# {'_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 82,
#            'datetime': '2018-03-26T04:39:10',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 87,
#            'datetime': '2018-03-26T04:39:10',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa945070d'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 84,
#            'datetime': '2018-03-26T04:39:10',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 88,
#            'datetime': '2018-03-28T04:38:00',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 86,
#            'datetime': '2018-03-28T04:33:40',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 92,
#            'datetime': '2018-03-28T04:33:30',
#            'surface_temperature_celcius': 71}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 95,
#            'datetime': '2018-03-28T04:33:30',
#            'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 93,
#            'datetime': '2018-03-28T04:32:20',
#            'surface_temperature_celcius': 73}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 83,
#            'datetime': '2018-03-28T04:30:50',
#            'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 80,
#            'datetime': '2018-03-28T04:30:20',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 94,
#            'datetime': '2018-03-28T04:30:10',
#            'surface_temperature_celcius': 74}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 98,
#            'datetime': '2018-03-28T04:30:10',
#            'surface_temperature_celcius': 82}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 81,
#            'datetime': '2018-03-28T04:30:10',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 97,
#            'datetime': '2018-03-28T04:30:10',
#            'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 81,
#            'datetime': '2018-03-28T04:28:30',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 88,
#            'datetime': '2018-03-28T04:28:30',
#            'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 87,
#            'datetime': '2018-03-28T04:28:30',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 97,
#            'datetime': '2018-03-28T04:27:40',
#            'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-28T04:27:20',
#            'surface_temperature_celcius': 107}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-28T04:27:10',
#            'surface_temperature_celcius': 108}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 82,
#            'datetime': '2018-03-28T04:27:00',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 99,
#            'datetime': '2018-03-28T04:27:00',
#            'surface_temperature_celcius': 86}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 81,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 80,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 83,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 100,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 90}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 87,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 97,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 81}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 85,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 88,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 87,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 84,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 97,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 81}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 83,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60af1c5e9343690fa945070f'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 85,
#            'datetime': '2018-03-28T04:26:50',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa9450712'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 82,
#            'datetime': '2018-03-31T05:07:10',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450712'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 87,
#            'datetime': '2018-03-31T05:01:20',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa9450712'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 82,
#            'datetime': '2018-03-31T04:58:30',
#            'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60af1c5e9343690fa9450712'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 80,
#            'datetime': '2018-03-31T04:58:00',
#            'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60af1c5e9343690fa9450712'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 86,
#            'datetime': '2018-03-31T04:57:10',
#            'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60af1c5e9343690fa9450712'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 81,
#            'datetime': '2018-03-31T00:36:30',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 91,
#            'datetime': '2018-04-03T13:17:00',
#            'surface_temperature_celcius': 43}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 83,
#            'datetime': '2018-04-03T13:15:30',
#            'surface_temperature_celcius': 40}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-03T13:15:10',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 96,
#            'datetime': '2018-04-03T13:15:10',
#            'surface_temperature_celcius': 45}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 87,
#            'datetime': '2018-04-03T03:59:10',
#            'surface_temperature_celcius': 96}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 93,
#            'datetime': '2018-04-03T03:57:50',
#            'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 82,
#            'datetime': '2018-04-03T03:56:20',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 88,
#            'datetime': '2018-04-03T03:55:10',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 95,
#            'datetime': '2018-04-03T03:55:10',
#            'surface_temperature_celcius': 77}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 96,
#            'datetime': '2018-04-03T03:54:00',
#            'surface_temperature_celcius': 78}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-03T03:53:50',
#            'surface_temperature_celcius': 93}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 85,
#            'datetime': '2018-04-03T03:53:30',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 84,
#            'datetime': '2018-04-03T03:52:30',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-03T03:52:30',
#            'surface_temperature_celcius': 90}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-03T03:52:20',
#            'surface_temperature_celcius': 115}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 86,
#            'datetime': '2018-04-03T03:52:10',
#            'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-03T03:52:10',
#            'surface_temperature_celcius': 98}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-03T03:52:10',
#            'surface_temperature_celcius': 89}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 85,
#            'datetime': '2018-04-03T03:52:10',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 83,
#            'datetime': '2018-04-03T03:51:30',
#            'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-03T03:51:30',
#            'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 87,
#            'datetime': '2018-04-03T03:51:10',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-03T03:51:00',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 98,
#            'datetime': '2018-04-03T03:51:00',
#            'surface_temperature_celcius': 82}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 80,
#            'datetime': '2018-04-03T03:51:00',
#            'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-03T03:51:00',
#            'surface_temperature_celcius': 103}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 87,
#            'datetime': '2018-04-03T03:50:50',
#            'surface_temperature_celcius': 97}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 90,
#            'datetime': '2018-04-03T03:50:50',
#            'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 85,
#            'datetime': '2018-04-03T03:50:40',
#            'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 99,
#            'datetime': '2018-04-03T03:50:40',
#            'surface_temperature_celcius': 86}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 93,
#            'datetime': '2018-04-03T03:50:40',
#            'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 95,
#            'datetime': '2018-04-03T03:50:40',
#            'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 86,
#            'datetime': '2018-04-03T03:50:40',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-03T03:50:40',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 82,
#            'datetime': '2018-04-03T03:50:40',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-03T03:50:40',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450715'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-03T01:07:20',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 93,
#            'datetime': '2018-04-04T15:31:00',
#            'surface_temperature_celcius': 44}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-04T15:30:40',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 88,
#            'datetime': '2018-04-04T04:41:50',
#            'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 82,
#            'datetime': '2018-04-04T04:41:10',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 88,
#            'datetime': '2018-04-04T04:41:00',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 86,
#            'datetime': '2018-04-04T04:41:00',
#            'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-04T04:40:00',
#            'surface_temperature_celcius': 120}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 90,
#            'datetime': '2018-04-04T04:39:50',
#            'surface_temperature_celcius': 67}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 85,
#            'datetime': '2018-04-04T04:39:50',
#            'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 90,
#            'datetime': '2018-04-04T04:39:40',
#            'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-04T04:39:40',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-04T04:39:20',
#            'surface_temperature_celcius': 107}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 88,
#            'datetime': '2018-04-04T04:37:10',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 88,
#            'datetime': '2018-04-04T04:36:10',
#            'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 87,
#            'datetime': '2018-04-04T04:36:10',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 90,
#            'datetime': '2018-04-04T04:36:00',
#            'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-04T04:35:00',
#            'surface_temperature_celcius': 95}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 83,
#            'datetime': '2018-04-04T04:34:50',
#            'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-04T04:34:20',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 96,
#            'datetime': '2018-04-04T04:34:20',
#            'surface_temperature_celcius': 78}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 85,
#            'datetime': '2018-04-04T04:34:20',
#            'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 84,
#            'datetime': '2018-04-04T04:34:00',
#            'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 92,
#            'datetime': '2018-04-04T04:33:50',
#            'surface_temperature_celcius': 81}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-04T04:33:40',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-04T04:33:30',
#            'surface_temperature_celcius': 113}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 80,
#            'datetime': '2018-04-04T04:33:30',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 85,
#            'datetime': '2018-04-04T04:33:30',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 82,
#            'datetime': '2018-04-04T04:33:10',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 82,
#            'datetime': '2018-04-04T04:33:10',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 97,
#            'datetime': '2018-04-04T04:33:00',
#            'surface_temperature_celcius': 79}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 86,
#            'datetime': '2018-04-04T04:33:00',
#            'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 98,
#            'datetime': '2018-04-04T04:32:50',
#            'surface_temperature_celcius': 82}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 85,
#            'datetime': '2018-04-04T04:32:50',
#            'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 84,
#            'datetime': '2018-04-04T04:32:50',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 82,
#            'datetime': '2018-04-04T04:32:50',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-04T04:32:50',
#            'surface_temperature_celcius': 123}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 82,
#            'datetime': '2018-04-04T04:32:50',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-04T04:32:50',
#            'surface_temperature_celcius': 118}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 80,
#            'datetime': '2018-04-04T04:32:40',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 96,
#            'datetime': '2018-04-04T04:32:40',
#            'surface_temperature_celcius': 78}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 93,
#            'datetime': '2018-04-04T04:32:40',
#            'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-04T04:32:40',
#            'surface_temperature_celcius': 120}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 87,
#            'datetime': '2018-04-04T04:32:40',
#            'surface_temperature_celcius': 92}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-04T04:32:40',
#            'surface_temperature_celcius': 101}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-04T04:32:40',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-04T04:32:40',
#            'surface_temperature_celcius': 98}}
# {'_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'fires': {'confidence': 80,
#            'datetime': '2018-04-04T00:12:50',
#            'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-05T13:09:00',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-05T13:09:00',
#            'surface_temperature_celcius': 39}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 93,
#            'datetime': '2018-04-05T13:08:40',
#            'surface_temperature_celcius': 44}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-05T13:08:40',
#            'surface_temperature_celcius': 47}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 82,
#            'datetime': '2018-04-05T13:07:00',
#            'surface_temperature_celcius': 40}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-05T13:04:20',
#            'surface_temperature_celcius': 49}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-05T13:03:20',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 98,
#            'datetime': '2018-04-05T13:03:00',
#            'surface_temperature_celcius': 45}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-05T13:03:00',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-05T13:03:00',
#            'surface_temperature_celcius': 39}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 88,
#            'datetime': '2018-04-05T13:02:40',
#            'surface_temperature_celcius': 42}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 80,
#            'datetime': '2018-04-05T13:02:40',
#            'surface_temperature_celcius': 39}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 87,
#            'datetime': '2018-04-05T05:16:50',
#            'surface_temperature_celcius': 88}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 93,
#            'datetime': '2018-04-05T05:15:30',
#            'surface_temperature_celcius': 83}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 93,
#            'datetime': '2018-04-05T03:40:50',
#            'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 95,
#            'datetime': '2018-04-05T03:40:30',
#            'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-05T03:40:20',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-05T03:39:30',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 82,
#            'datetime': '2018-04-05T03:39:30',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 90,
#            'datetime': '2018-04-05T03:39:20',
#            'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 83,
#            'datetime': '2018-04-05T03:39:20',
#            'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-05T03:39:10',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 83,
#            'datetime': '2018-04-05T03:39:10',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 95,
#            'datetime': '2018-04-05T03:39:10',
#            'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-05T03:39:10',
#            'surface_temperature_celcius': 92}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 88,
#            'datetime': '2018-04-05T03:39:10',
#            'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60af1c5e9343690fa9450717'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-05T03:39:10',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 97,
#            'datetime': '2018-04-06T13:45:30',
#            'surface_temperature_celcius': 45}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 84,
#            'datetime': '2018-04-06T04:32:20',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 92,
#            'datetime': '2018-04-06T04:31:10',
#            'surface_temperature_celcius': 69}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-06T04:27:50',
#            'surface_temperature_celcius': 95}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-06T04:27:50',
#            'surface_temperature_celcius': 88}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-06T04:27:10',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-06T04:27:00',
#            'surface_temperature_celcius': 97}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 86,
#            'datetime': '2018-04-06T04:27:00',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 90,
#            'datetime': '2018-04-06T04:27:00',
#            'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-06T04:27:00',
#            'surface_temperature_celcius': 99}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 83,
#            'datetime': '2018-04-06T04:27:00',
#            'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 83,
#            'datetime': '2018-04-06T04:24:40',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-06T04:24:20',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-06T04:24:20',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-06T04:24:00',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 92,
#            'datetime': '2018-04-06T04:23:50',
#            'surface_temperature_celcius': 70}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 99,
#            'datetime': '2018-04-06T04:23:50',
#            'surface_temperature_celcius': 85}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 93,
#            'datetime': '2018-04-06T04:23:30',
#            'surface_temperature_celcius': 72}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 89,
#            'datetime': '2018-04-06T04:23:10',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 87,
#            'datetime': '2018-04-06T04:23:00',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 85,
#            'datetime': '2018-04-06T04:22:40',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 83,
#            'datetime': '2018-04-06T04:22:20',
#            'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-06T04:22:20',
#            'surface_temperature_celcius': 71}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 85,
#            'datetime': '2018-04-06T04:22:20',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-06T04:22:20',
#            'surface_temperature_celcius': 103}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 91,
#            'datetime': '2018-04-06T04:22:20',
#            'surface_temperature_celcius': 69}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 86,
#            'datetime': '2018-04-06T04:22:10',
#            'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 85,
#            'datetime': '2018-04-06T04:22:10',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 90,
#            'datetime': '2018-04-06T04:22:10',
#            'surface_temperature_celcius': 67}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 90,
#            'datetime': '2018-04-06T04:21:30',
#            'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 94,
#            'datetime': '2018-04-06T04:21:10',
#            'surface_temperature_celcius': 96}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-06T04:21:00',
#            'surface_temperature_celcius': 115}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 84,
#            'datetime': '2018-04-06T04:21:00',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 100,
#            'datetime': '2018-04-06T04:20:50',
#            'surface_temperature_celcius': 95}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 88,
#            'datetime': '2018-04-06T04:20:50',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 83,
#            'datetime': '2018-04-06T04:20:50',
#            'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 81,
#            'datetime': '2018-04-06T04:20:40',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 83,
#            'datetime': '2018-04-06T04:20:40',
#            'surface_temperature_celcius': 78}}
# {'_id': ObjectId('60af1c5e9343690fa9450718'),
#  'air_temperature_celcius': 19,
#  'fires': {'confidence': 96,
# ...
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 91,
#            'datetime': '2018-10-07T12:59:33',
#            'surface_temperature_celcius': 42}}
# {'_id': ObjectId('60af1c5e9343690fa94507d3'),
#  'air_temperature_celcius': 13,
#  'fires': {'confidence': 96,
#            'datetime': '2018-10-10T04:04:19',
#            'surface_temperature_celcius': 77}}
# {'_id': ObjectId('60af1c5e9343690fa94507d8'),
#  'air_temperature_celcius': 13,
#  'fires': {'confidence': 100,
#            'datetime': '2018-10-15T04:23:01',
#            'surface_temperature_celcius': 87}}
# {'_id': ObjectId('60af1c5e9343690fa94507d8'),
#  'air_temperature_celcius': 13,
#  'fires': {'confidence': 99,
#            'datetime': '2018-10-15T04:23:01',
#            'surface_temperature_celcius': 85}}
# {'_id': ObjectId('60af1c5e9343690fa94507da'),
#  'air_temperature_celcius': 22,
#  'fires': {'confidence': 94,
#            'datetime': '2018-10-17T13:36:12',
#            'surface_temperature_celcius': 43}}
# {'_id': ObjectId('60af1c5e9343690fa94507da'),
#  'air_temperature_celcius': 22,
#  'fires': {'confidence': 91,
#            'datetime': '2018-10-17T04:10:45',
#            'surface_temperature_celcius': 68}}
# {'_id': ObjectId('60af1c5e9343690fa94507da'),
#  'air_temperature_celcius': 22,
#  'fires': {'confidence': 82,
#            'datetime': '2018-10-17T04:10:32',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa94507db'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 84,
#            'datetime': '2018-10-18T00:39:02',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa94507db'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 82,
#            'datetime': '2018-10-18T00:39:02',
#            'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60af1c5e9343690fa94507dd'),
#  'air_temperature_celcius': 13,
#  'fires': {'confidence': 80,
#            'datetime': '2018-10-20T04:41:19',
#            'surface_temperature_celcius': 46}}
# {'_id': ObjectId('60af1c5e9343690fa94507dd'),
#  'air_temperature_celcius': 13,
#  'fires': {'confidence': 82,
#            'datetime': '2018-10-20T04:41:19',
#            'surface_temperature_celcius': 50}}
# {'_id': ObjectId('60af1c5e9343690fa94507de'),
#  'air_temperature_celcius': 12,
#  'fires': {'confidence': 88,
#            'datetime': '2018-10-21T01:09:55',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa94507de'),
#  'air_temperature_celcius': 12,
#  'fires': {'confidence': 92,
#            'datetime': '2018-10-21T01:09:54',
#            'surface_temperature_celcius': 67}}
# {'_id': ObjectId('60af1c5e9343690fa94507e3'),
#  'air_temperature_celcius': 13,
#  'fires': {'confidence': 100,
#            'datetime': '2018-10-26T13:30:31',
#            'surface_temperature_celcius': 48}}
# {'_id': ObjectId('60af1c5e9343690fa94507e3'),
#  'air_temperature_celcius': 13,
#  'fires': {'confidence': 100,
#            'datetime': '2018-10-26T13:30:31',
#            'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60af1c5e9343690fa94507e4'),
#  'air_temperature_celcius': 22,
#  'fires': {'confidence': 86,
#            'datetime': '2018-10-27T04:47:31',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa94507e5'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 81,
#            'datetime': '2018-10-28T03:52:17',
#            'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60af1c5e9343690fa94507ed'),
#  'air_temperature_celcius': 13,
#  'fires': {'confidence': 83,
#            'datetime': '2018-11-05T04:41:34',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa94507ed'),
#  'air_temperature_celcius': 13,
#  'fires': {'confidence': 90,
#            'datetime': '2018-11-05T04:41:19',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa94507ed'),
#  'air_temperature_celcius': 13,
#  'fires': {'confidence': 89,
#            'datetime': '2018-11-05T04:41:19',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa94507f1'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 85,
#            'datetime': '2018-11-09T04:16:48',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa94507f1'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 100,
#            'datetime': '2018-11-09T04:16:48',
#            'surface_temperature_celcius': 93}}
# {'_id': ObjectId('60af1c5e9343690fa94507f1'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 96,
#            'datetime': '2018-11-09T04:16:48',
#            'surface_temperature_celcius': 77}}
# {'_id': ObjectId('60af1c5e9343690fa94507f1'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 87,
#            'datetime': '2018-11-09T04:16:44',
#            'surface_temperature_celcius': 62}}
# {'_id': ObjectId('60af1c5e9343690fa94507f1'),
#  'air_temperature_celcius': 14,
#  'fires': {'confidence': 97,
#            'datetime': '2018-11-09T04:16:44',
#            'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60af1c5e9343690fa94507f3'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 80,
#            'datetime': '2018-11-11T13:30:08',
#            'surface_temperature_celcius': 37}}
# {'_id': ObjectId('60af1c5e9343690fa94507f3'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 100,
#            'datetime': '2018-11-11T13:30:08',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa94507f3'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 86,
#            'datetime': '2018-11-11T04:04:25',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa94507f4'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 89,
#            'datetime': '2018-11-12T00:33:15',
#            'surface_temperature_celcius': 69}}
# {'_id': ObjectId('60af1c5e9343690fa94507f5'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 87,
#            'datetime': '2018-11-13T03:52:15',
#            'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60af1c5e9343690fa94507f5'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 81,
#            'datetime': '2018-11-13T03:52:14',
#            'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60af1c5e9343690fa94507f6'),
#  'air_temperature_celcius': 28,
#  'fires': {'confidence': 87,
#            'datetime': '2018-11-14T04:35:04',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa94507fd'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 85,
#            'datetime': '2018-11-21T00:27:21',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa94507fe'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 84,
#            'datetime': '2018-11-22T03:46:00',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa94507fe'),
#  'air_temperature_celcius': 23,
#  'fires': {'confidence': 88,
#            'datetime': '2018-11-22T03:46:00',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa94507ff'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 84,
#            'datetime': '2018-11-23T04:28:59',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa94507ff'),
#  'air_temperature_celcius': 24,
#  'fires': {'confidence': 93,
#            'datetime': '2018-11-23T04:28:59',
#            'surface_temperature_celcius': 73}}
# {'_id': ObjectId('60af1c5e9343690fa9450805'),
#  'air_temperature_celcius': 28,
#  'fires': {'confidence': 100,
#            'datetime': '2018-11-29T13:17:24',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450805'),
#  'air_temperature_celcius': 28,
#  'fires': {'confidence': 100,
#            'datetime': '2018-11-29T03:52:10',
#            'surface_temperature_celcius': 87}}
# {'_id': ObjectId('60af1c5e9343690fa9450805'),
#  'air_temperature_celcius': 28,
#  'fires': {'confidence': 97,
#            'datetime': '2018-11-29T03:52:10',
#            'surface_temperature_celcius': 80}}
# {'_id': ObjectId('60af1c5e9343690fa9450805'),
#  'air_temperature_celcius': 28,
#  'fires': {'confidence': 99,
#            'datetime': '2018-11-29T03:52:10',
#            'surface_temperature_celcius': 84}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 100,
#            'datetime': '2018-11-30T15:38:36',
#            'surface_temperature_celcius': 53}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 100,
#            'datetime': '2018-11-30T15:38:35',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 100,
#            'datetime': '2018-11-30T15:38:35',
#            'surface_temperature_celcius': 49}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 84,
#            'datetime': '2018-11-30T12:22:15',
#            'surface_temperature_celcius': 38}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 81,
#            'datetime': '2018-11-30T12:22:15',
#            'surface_temperature_celcius': 42}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 100,
#            'datetime': '2018-11-30T12:22:15',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 100,
#            'datetime': '2018-11-30T12:22:15',
#            'surface_temperature_celcius': 65}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 100,
#            'datetime': '2018-11-30T12:22:14',
#            'surface_temperature_celcius': 71}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 84,
#            'datetime': '2018-11-30T04:35:00',
#            'surface_temperature_celcius': 59}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 98,
#            'datetime': '2018-11-30T04:34:57',
#            'surface_temperature_celcius': 83}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 81,
#            'datetime': '2018-11-30T04:34:57',
#            'surface_temperature_celcius': 57}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 84,
#            'datetime': '2018-11-30T04:34:57',
#            'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 99,
#            'datetime': '2018-11-30T04:34:57',
#            'surface_temperature_celcius': 86}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 83,
#            'datetime': '2018-11-30T00:20:53',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 87,
#            'datetime': '2018-11-30T00:20:53',
#            'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 95,
#            'datetime': '2018-11-30T00:20:53',
#            'surface_temperature_celcius': 76}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 81,
#            'datetime': '2018-11-30T00:20:53',
#            'surface_temperature_celcius': 56}}
# {'_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'fires': {'confidence': 81,
#            'datetime': '2018-11-30T00:20:53',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa945080e'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 100,
#            'datetime': '2018-12-08T13:11:44',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa945080e'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 100,
#            'datetime': '2018-12-08T13:11:44',
#            'surface_temperature_celcius': 71}}
# {'_id': ObjectId('60af1c5e9343690fa945080e'),
#  'air_temperature_celcius': 15,
#  'fires': {'confidence': 100,
#            'datetime': '2018-12-08T13:11:43',
#            'surface_temperature_celcius': 52}}
# {'_id': ObjectId('60af1c5e9343690fa945080f'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 87,
#            'datetime': '2018-12-09T00:14:34',
#            'surface_temperature_celcius': 61}}
# {'_id': ObjectId('60af1c5e9343690fa945080f'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 81,
#            'datetime': '2018-12-09T00:14:34',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa945080f'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 84,
#            'datetime': '2018-12-09T00:14:33',
#            'surface_temperature_celcius': 58}}
# {'_id': ObjectId('60af1c5e9343690fa945080f'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 86,
#            'datetime': '2018-12-09T00:14:33',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa9450813'),
#  'air_temperature_celcius': 28,
#  'fires': {'confidence': 83,
#            'datetime': '2018-12-13T04:04:19',
#            'surface_temperature_celcius': 60}}
# {'_id': ObjectId('60af1c5e9343690fa9450814'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 92,
#            'datetime': '2018-12-14T04:47:25',
#            'surface_temperature_celcius': 70}}
# {'_id': ObjectId('60af1c5e9343690fa9450815'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 92,
#            'datetime': '2018-12-15T13:17:17',
#            'surface_temperature_celcius': 42}}
# {'_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 94,
#            'datetime': '2018-12-16T15:38:39',
#            'surface_temperature_celcius': 43}}
# {'_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 93,
#            'datetime': '2018-12-16T04:35:13',
#            'surface_temperature_celcius': 73}}
# {'_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 84,
#            'datetime': '2018-12-16T04:34:58',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 95,
#            'datetime': '2018-12-16T04:34:58',
#            'surface_temperature_celcius': 75}}
# {'_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 90,
#            'datetime': '2018-12-16T04:34:57',
#            'surface_temperature_celcius': 66}}
# {'_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 93,
#            'datetime': '2018-12-16T00:21:12',
#            'surface_temperature_celcius': 73}}
# {'_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 82,
#            'datetime': '2018-12-16T00:21:11',
#            'surface_temperature_celcius': 55}}
# {'_id': ObjectId('60af1c5e9343690fa9450816'),
#  'air_temperature_celcius': 18,
#  'fires': {'confidence': 82,
#            'datetime': '2018-12-16T00:20:53',
#            'surface_temperature_celcius': 64}}
# {'_id': ObjectId('60af1c5e9343690fa945081f'),
#  'air_temperature_celcius': 17,
#  'fires': {'confidence': 80,
#            'datetime': '2018-12-25T04:29:08',
#            'surface_temperature_celcius': 54}}
# {'_id': ObjectId('60af1c5e9343690fa9450821'),
#  'air_temperature_celcius': 28,
#  'fires': {'confidence': 82,
#            'datetime': '2018-12-27T00:02:15',
#            'surface_temperature_celcius': 63}}
# {'_id': ObjectId('60af1c5e9343690fa9450821'),
#  'air_temperature_celcius': 28,
#  'fires': {'confidence': 86,
#            'datetime': '2018-12-27T00:02:14',
#            'surface_temperature_celcius': 67}}

# %% [markdown]
# **e. Find the top 10 records with the highest surface temperature (°C).**

# %%
results = climates.aggregate(
    [

        {
            "$lookup":{
                    "from": "fire_historic",
                    "localField": "fires",
                    "foreignField" : "_id",
                    "as": "fires"
            }
        },
        {
             "$unwind": "$fires"
        },
        {
            "$sort": {"fires.surface_temperature_celcius": -1}
        },
        {
            "$limit": 10
        }
    ]
)

for document in results:
    pprint(document)
# Out:
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa9450724'),
#  'air_temperature_celcius': 15,
#  'date': '18/04/2018',
#  'fires': {'_id': ObjectId('60af1c689343690fa9450cca'),
#            'confidence': 100,
#            'date': '18/04/2018',
#            'datetime': '2018-04-18T04:52:00',
#            'latitude': -38.1665,
#            'longitude': 143.062,
#            'surface_temperature_celcius': 124},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'date': '04/04/2018',
#  'fires': {'_id': ObjectId('60af1c689343690fa9451174'),
#            'confidence': 100,
#            'date': '04/04/2018',
#            'datetime': '2018-04-04T04:32:50',
#            'latitude': -36.343,
#            'longitude': 142.1986,
#            'surface_temperature_celcius': 123},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 121,
#  '_id': ObjectId('60af1c5e9343690fa9450731'),
#  'air_temperature_celcius': 14,
#  'date': '01/05/2018',
#  'fires': {'_id': ObjectId('60af1c689343690fa9450c3c'),
#            'confidence': 100,
#            'date': '01/05/2018',
#            'datetime': '2018-05-01T04:14:20',
#            'latitude': -36.9318,
#            'longitude': 143.0907,
#            'surface_temperature_celcius': 122},
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 49.2,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 176,
#  '_id': ObjectId('60af1c5e9343690fa9450705'),
#  'air_temperature_celcius': 21,
#  'date': '18/03/2018',
#  'fires': {'_id': ObjectId('60af1c689343690fa9451263'),
#            'confidence': 100,
#            'date': '18/03/2018',
#            'datetime': '2018-03-18T03:50:50',
#            'latitude': -37.017,
#            'longitude': 148.1297,
#            'surface_temperature_celcius': 121},
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'date': '04/04/2018',
#  'fires': {'_id': ObjectId('60af1c689343690fa945117b'),
#            'confidence': 100,
#            'date': '04/04/2018',
#            'datetime': '2018-04-04T04:32:40',
#            'latitude': -36.3521,
#            'longitude': 142.2008,
#            'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 132,
#  '_id': ObjectId('60af1c5e9343690fa945071f'),
#  'air_temperature_celcius': 16,
#  'date': '13/04/2018',
#  'fires': {'_id': ObjectId('60af1c689343690fa9450ee6'),
#            'confidence': 100,
#            'date': '13/04/2018',
#            'datetime': '2018-04-13T04:28:10',
#            'latitude': -37.0745,
#            'longitude': 141.0692,
#            'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'GHI_w/m2': 81,
#  '_id': ObjectId('60af1c5e9343690fa945073d'),
#  'air_temperature_celcius': 9,
#  'date': '13/05/2018',
#  'fires': {'_id': ObjectId('60af1c689343690fa9450a4e'),
#            'confidence': 100,
#            'date': '13/05/2018',
#            'datetime': '2018-05-13T04:40:20',
#            'latitude': -34.9938,
#            'longitude': 141.876,
#            'surface_temperature_celcius': 120},
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 44.0,
#  'station': 948701,
#  'windspeed_knots': 2.8}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa9450724'),
#  'air_temperature_celcius': 15,
#  'date': '18/04/2018',
#  'fires': {'_id': ObjectId('60af1c689343690fa9450d63'),
#            'confidence': 100,
#            'date': '18/04/2018',
#            'datetime': '2018-04-18T04:44:50',
#            'latitude': -37.8326,
#            'longitude': 143.4999,
#            'surface_temperature_celcius': 120},
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60af1c5e9343690fa9450716'),
#  'air_temperature_celcius': 16,
#  'date': '04/04/2018',
#  'fires': {'_id': ObjectId('60af1c689343690fa945113b'),
#            'confidence': 100,
#            'date': '04/04/2018',
#            'datetime': '2018-04-04T04:40:00',
#            'latitude': -36.1057,
#            'longitude': 141.7608,
#            'surface_temperature_celcius': 120},
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'GHI_w/m2': 91,
#  '_id': ObjectId('60af1c5e9343690fa9450734'),
#  'air_temperature_celcius': 10,
#  'date': '04/05/2018',
#  'fires': {'_id': ObjectId('60af1c689343690fa9450b92'),
#            'confidence': 100,
#            'date': '04/05/2018',
#            'datetime': '2018-05-04T04:44:50',
#            'latitude': -36.4057,
#            'longitude': 140.9806,
#            'surface_temperature_celcius': 119},
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 43.3,
#  'station': 948701,
#  'windspeed_knots': 2.6}

# %% [markdown]
# **f. Find the number of fires each day. You are required to only display the total number of fires and the date in the output.**

# %%
results = climates.aggregate(
    [
        {"$project": 
             { 
                 "date": 1,
                 "fire_count": { "$size":"$fires" },
                 "_id": 0
                 
             }
        }
    ]
)

for document in results:
    pprint(document)
# Out:
# {'date': '31/12/2017', 'fire_count': 0}
# {'date': '02/01/2018', 'fire_count': 0}
# {'date': '03/01/2018', 'fire_count': 0}
# {'date': '04/01/2018', 'fire_count': 0}
# {'date': '05/01/2018', 'fire_count': 0}
# {'date': '06/01/2018', 'fire_count': 0}
# {'date': '07/01/2018', 'fire_count': 0}
# {'date': '08/01/2018', 'fire_count': 0}
# {'date': '09/01/2018', 'fire_count': 0}
# {'date': '10/01/2018', 'fire_count': 0}
# {'date': '11/01/2018', 'fire_count': 0}
# {'date': '12/01/2018', 'fire_count': 0}
# {'date': '13/01/2018', 'fire_count': 0}
# {'date': '14/01/2018', 'fire_count': 0}
# {'date': '15/01/2018', 'fire_count': 0}
# {'date': '16/01/2018', 'fire_count': 0}
# {'date': '17/01/2018', 'fire_count': 0}
# {'date': '18/01/2018', 'fire_count': 0}
# {'date': '19/01/2018', 'fire_count': 0}
# {'date': '20/01/2018', 'fire_count': 0}
# {'date': '21/01/2018', 'fire_count': 0}
# {'date': '22/01/2018', 'fire_count': 0}
# {'date': '23/01/2018', 'fire_count': 0}
# {'date': '24/01/2018', 'fire_count': 0}
# {'date': '25/01/2018', 'fire_count': 0}
# {'date': '26/01/2018', 'fire_count': 0}
# {'date': '27/01/2018', 'fire_count': 0}
# {'date': '28/01/2018', 'fire_count': 0}
# {'date': '29/01/2018', 'fire_count': 0}
# {'date': '30/01/2018', 'fire_count': 0}
# {'date': '31/01/2018', 'fire_count': 0}
# {'date': '01/02/2018', 'fire_count': 0}
# {'date': '02/02/2018', 'fire_count': 0}
# {'date': '03/02/2018', 'fire_count': 0}
# {'date': '04/02/2018', 'fire_count': 0}
# {'date': '05/02/2018', 'fire_count': 0}
# {'date': '06/02/2018', 'fire_count': 0}
# {'date': '07/02/2018', 'fire_count': 0}
# {'date': '08/02/2018', 'fire_count': 0}
# {'date': '09/02/2018', 'fire_count': 0}
# {'date': '10/02/2018', 'fire_count': 0}
# {'date': '11/02/2018', 'fire_count': 0}
# {'date': '12/02/2018', 'fire_count': 0}
# {'date': '13/02/2018', 'fire_count': 0}
# {'date': '14/02/2018', 'fire_count': 0}
# {'date': '15/02/2018', 'fire_count': 0}
# {'date': '16/02/2018', 'fire_count': 0}
# {'date': '17/02/2018', 'fire_count': 0}
# {'date': '18/02/2018', 'fire_count': 0}
# {'date': '19/02/2018', 'fire_count': 0}
# {'date': '20/02/2018', 'fire_count': 0}
# {'date': '21/02/2018', 'fire_count': 0}
# {'date': '22/02/2018', 'fire_count': 0}
# {'date': '23/02/2018', 'fire_count': 0}
# {'date': '24/02/2018', 'fire_count': 0}
# {'date': '25/02/2018', 'fire_count': 0}
# {'date': '26/02/2018', 'fire_count': 0}
# {'date': '27/02/2018', 'fire_count': 0}
# {'date': '28/02/2018', 'fire_count': 0}
# {'date': '01/03/2018', 'fire_count': 0}
# {'date': '02/03/2018', 'fire_count': 0}
# {'date': '03/03/2018', 'fire_count': 0}
# {'date': '04/03/2018', 'fire_count': 0}
# {'date': '05/03/2018', 'fire_count': 0}
# {'date': '06/03/2018', 'fire_count': 2}
# {'date': '07/03/2018', 'fire_count': 1}
# {'date': '08/03/2018', 'fire_count': 2}
# {'date': '09/03/2018', 'fire_count': 3}
# {'date': '10/03/2018', 'fire_count': 8}
# {'date': '11/03/2018', 'fire_count': 0}
# {'date': '12/03/2018', 'fire_count': 5}
# {'date': '13/03/2018', 'fire_count': 2}
# {'date': '14/03/2018', 'fire_count': 10}
# {'date': '15/03/2018', 'fire_count': 7}
# {'date': '16/03/2018', 'fire_count': 0}
# {'date': '17/03/2018', 'fire_count': 6}
# {'date': '18/03/2018', 'fire_count': 3}
# {'date': '19/03/2018', 'fire_count': 21}
# {'date': '20/03/2018', 'fire_count': 0}
# {'date': '21/03/2018', 'fire_count': 0}
# {'date': '22/03/2018', 'fire_count': 0}
# {'date': '23/03/2018', 'fire_count': 0}
# {'date': '24/03/2018', 'fire_count': 2}
# {'date': '25/03/2018', 'fire_count': 13}
# {'date': '26/03/2018', 'fire_count': 17}
# {'date': '27/03/2018', 'fire_count': 0}
# {'date': '28/03/2018', 'fire_count': 54}
# {'date': '29/03/2018', 'fire_count': 1}
# {'date': '30/03/2018', 'fire_count': 0}
# {'date': '31/03/2018', 'fire_count': 22}
# {'date': '01/04/2018', 'fire_count': 7}
# {'date': '02/04/2018', 'fire_count': 5}
# {'date': '03/04/2018', 'fire_count': 72}
# {'date': '04/04/2018', 'fire_count': 89}
# {'date': '05/04/2018', 'fire_count': 49}
# {'date': '06/04/2018', 'fire_count': 118}
# {'date': '07/04/2018', 'fire_count': 39}
# {'date': '08/04/2018', 'fire_count': 20}
# {'date': '09/04/2018', 'fire_count': 0}
# {'date': '10/04/2018', 'fire_count': 0}
# {'date': '11/04/2018', 'fire_count': 24}
# {'date': '12/04/2018', 'fire_count': 69}
# {'date': '13/04/2018', 'fire_count': 357}
# {'date': '14/04/2018', 'fire_count': 18}
# {'date': '15/04/2018', 'fire_count': 69}
# {'date': '16/04/2018', 'fire_count': 18}
# {'date': '17/04/2018', 'fire_count': 38}
# {'date': '18/04/2018', 'fire_count': 325}
# {'date': '19/04/2018', 'fire_count': 50}
# {'date': '20/04/2018', 'fire_count': 31}
# {'date': '21/04/2018', 'fire_count': 0}
# {'date': '22/04/2018', 'fire_count': 2}
# {'date': '23/04/2018', 'fire_count': 19}
# {'date': '24/04/2018', 'fire_count': 8}
# {'date': '25/04/2018', 'fire_count': 3}
# {'date': '26/04/2018', 'fire_count': 1}
# {'date': '27/04/2018', 'fire_count': 0}
# {'date': '28/04/2018', 'fire_count': 0}
# {'date': '29/04/2018', 'fire_count': 3}
# {'date': '30/04/2018', 'fire_count': 0}
# {'date': '01/05/2018', 'fire_count': 20}
# {'date': '02/05/2018', 'fire_count': 10}
# {'date': '03/05/2018', 'fire_count': 64}
# {'date': '04/05/2018', 'fire_count': 135}
# {'date': '05/05/2018', 'fire_count': 31}
# {'date': '06/05/2018', 'fire_count': 17}
# {'date': '07/05/2018', 'fire_count': 3}
# {'date': '08/05/2018', 'fire_count': 24}
# {'date': '09/05/2018', 'fire_count': 13}
# {'date': '10/05/2018', 'fire_count': 114}
# {'date': '11/05/2018', 'fire_count': 19}
# {'date': '12/05/2018', 'fire_count': 10}
# {'date': '13/05/2018', 'fire_count': 54}
# {'date': '14/05/2018', 'fire_count': 1}
# {'date': '15/05/2018', 'fire_count': 102}
# {'date': '16/05/2018', 'fire_count': 3}
# {'date': '17/05/2018', 'fire_count': 1}
# {'date': '18/05/2018', 'fire_count': 7}
# {'date': '19/05/2018', 'fire_count': 0}
# {'date': '20/05/2018', 'fire_count': 0}
# {'date': '21/05/2018', 'fire_count': 0}
# {'date': '22/05/2018', 'fire_count': 33}
# {'date': '23/05/2018', 'fire_count': 5}
# {'date': '24/05/2018', 'fire_count': 3}
# {'date': '25/05/2018', 'fire_count': 0}
# {'date': '26/05/2018', 'fire_count': 4}
# {'date': '27/05/2018', 'fire_count': 0}
# {'date': '28/05/2018', 'fire_count': 0}
# {'date': '29/05/2018', 'fire_count': 0}
# {'date': '30/05/2018', 'fire_count': 0}
# {'date': '31/05/2018', 'fire_count': 0}
# {'date': '01/06/2018', 'fire_count': 2}
# {'date': '02/06/2018', 'fire_count': 11}
# {'date': '03/06/2018', 'fire_count': 2}
# {'date': '04/06/2018', 'fire_count': 9}
# {'date': '05/06/2018', 'fire_count': 0}
# {'date': '06/06/2018', 'fire_count': 0}
# {'date': '07/06/2018', 'fire_count': 14}
# {'date': '08/06/2018', 'fire_count': 0}
# {'date': '09/06/2018', 'fire_count': 3}
# {'date': '10/06/2018', 'fire_count': 0}
# {'date': '11/06/2018', 'fire_count': 2}
# {'date': '12/06/2018', 'fire_count': 0}
# {'date': '13/06/2018', 'fire_count': 1}
# {'date': '14/06/2018', 'fire_count': 4}
# {'date': '15/06/2018', 'fire_count': 0}
# {'date': '16/06/2018', 'fire_count': 2}
# {'date': '17/06/2018', 'fire_count': 0}
# {'date': '18/06/2018', 'fire_count': 2}
# {'date': '19/06/2018', 'fire_count': 0}
# {'date': '20/06/2018', 'fire_count': 6}
# {'date': '21/06/2018', 'fire_count': 0}
# {'date': '22/06/2018', 'fire_count': 1}
# {'date': '23/06/2018', 'fire_count': 0}
# {'date': '24/06/2018', 'fire_count': 0}
# {'date': '25/06/2018', 'fire_count': 0}
# {'date': '26/06/2018', 'fire_count': 0}
# {'date': '27/06/2018', 'fire_count': 0}
# {'date': '28/06/2018', 'fire_count': 0}
# {'date': '29/06/2018', 'fire_count': 0}
# {'date': '30/06/2018', 'fire_count': 6}
# {'date': '01/07/2018', 'fire_count': 4}
# {'date': '02/07/2018', 'fire_count': 8}
# {'date': '03/07/2018', 'fire_count': 0}
# {'date': '04/07/2018', 'fire_count': 1}
# {'date': '05/07/2018', 'fire_count': 1}
# {'date': '06/07/2018', 'fire_count': 3}
# {'date': '07/07/2018', 'fire_count': 0}
# {'date': '08/07/2018', 'fire_count': 0}
# {'date': '09/07/2018', 'fire_count': 0}
# {'date': '10/07/2018', 'fire_count': 0}
# {'date': '11/07/2018', 'fire_count': 0}
# {'date': '12/07/2018', 'fire_count': 0}
# {'date': '13/07/2018', 'fire_count': 0}
# {'date': '14/07/2018', 'fire_count': 2}
# {'date': '15/07/2018', 'fire_count': 0}
# {'date': '16/07/2018', 'fire_count': 0}
# {'date': '17/07/2018', 'fire_count': 0}
# {'date': '18/07/2018', 'fire_count': 0}
# {'date': '19/07/2018', 'fire_count': 0}
# {'date': '20/07/2018', 'fire_count': 0}
# {'date': '21/07/2018', 'fire_count': 0}
# {'date': '22/07/2018', 'fire_count': 0}
# {'date': '23/07/2018', 'fire_count': 0}
# {'date': '24/07/2018', 'fire_count': 0}
# {'date': '25/07/2018', 'fire_count': 0}
# {'date': '26/07/2018', 'fire_count': 0}
# {'date': '27/07/2018', 'fire_count': 0}
# {'date': '28/07/2018', 'fire_count': 0}
# {'date': '29/07/2018', 'fire_count': 2}
# {'date': '30/07/2018', 'fire_count': 0}
# {'date': '31/07/2018', 'fire_count': 2}
# {'date': '01/08/2018', 'fire_count': 2}
# {'date': '02/08/2018', 'fire_count': 2}
# {'date': '03/08/2018', 'fire_count': 0}
# {'date': '04/08/2018', 'fire_count': 0}
# {'date': '05/08/2018', 'fire_count': 1}
# {'date': '06/08/2018', 'fire_count': 0}
# {'date': '07/08/2018', 'fire_count': 0}
# {'date': '08/08/2018', 'fire_count': 0}
# {'date': '09/08/2018', 'fire_count': 0}
# {'date': '10/08/2018', 'fire_count': 1}
# {'date': '11/08/2018', 'fire_count': 0}
# {'date': '12/08/2018', 'fire_count': 0}
# {'date': '13/08/2018', 'fire_count': 9}
# {'date': '14/08/2018', 'fire_count': 5}
# {'date': '15/08/2018', 'fire_count': 0}
# {'date': '16/08/2018', 'fire_count': 0}
# {'date': '17/08/2018', 'fire_count': 0}
# {'date': '18/08/2018', 'fire_count': 0}
# {'date': '19/08/2018', 'fire_count': 0}
# {'date': '20/08/2018', 'fire_count': 0}
# {'date': '21/08/2018', 'fire_count': 0}
# {'date': '22/08/2018', 'fire_count': 0}
# {'date': '23/08/2018', 'fire_count': 0}
# {'date': '24/08/2018', 'fire_count': 0}
# {'date': '25/08/2018', 'fire_count': 0}
# {'date': '26/08/2018', 'fire_count': 0}
# {'date': '27/08/2018', 'fire_count': 0}
# {'date': '28/08/2018', 'fire_count': 0}
# {'date': '29/08/2018', 'fire_count': 0}
# {'date': '30/08/2018', 'fire_count': 0}
# {'date': '31/08/2018', 'fire_count': 0}
# {'date': '01/09/2018', 'fire_count': 0}
# {'date': '02/09/2018', 'fire_count': 0}
# {'date': '03/09/2018', 'fire_count': 0}
# {'date': '04/09/2018', 'fire_count': 0}
# {'date': '05/09/2018', 'fire_count': 0}
# {'date': '06/09/2018', 'fire_count': 0}
# {'date': '07/09/2018', 'fire_count': 0}
# {'date': '08/09/2018', 'fire_count': 0}
# {'date': '09/09/2018', 'fire_count': 0}
# {'date': '10/09/2018', 'fire_count': 4}
# {'date': '11/09/2018', 'fire_count': 0}
# {'date': '12/09/2018', 'fire_count': 0}
# {'date': '13/09/2018', 'fire_count': 0}
# {'date': '14/09/2018', 'fire_count': 0}
# {'date': '15/09/2018', 'fire_count': 0}
# {'date': '16/09/2018', 'fire_count': 0}
# {'date': '17/09/2018', 'fire_count': 0}
# {'date': '18/09/2018', 'fire_count': 0}
# {'date': '19/09/2018', 'fire_count': 0}
# {'date': '20/09/2018', 'fire_count': 5}
# {'date': '21/09/2018', 'fire_count': 2}
# {'date': '22/09/2018', 'fire_count': 1}
# {'date': '23/09/2018', 'fire_count': 23}
# {'date': '24/09/2018', 'fire_count': 28}
# {'date': '25/09/2018', 'fire_count': 0}
# {'date': '26/09/2018', 'fire_count': 1}
# {'date': '27/09/2018', 'fire_count': 7}
# {'date': '28/09/2018', 'fire_count': 0}
# {'date': '29/09/2018', 'fire_count': 2}
# {'date': '30/09/2018', 'fire_count': 0}
# {'date': '01/10/2018', 'fire_count': 8}
# {'date': '02/10/2018', 'fire_count': 7}
# {'date': '03/10/2018', 'fire_count': 18}
# {'date': '04/10/2018', 'fire_count': 5}
# {'date': '05/10/2018', 'fire_count': 0}
# {'date': '06/10/2018', 'fire_count': 2}
# {'date': '07/10/2018', 'fire_count': 1}
# {'date': '08/10/2018', 'fire_count': 1}
# {'date': '09/10/2018', 'fire_count': 1}
# {'date': '10/10/2018', 'fire_count': 3}
# {'date': '11/10/2018', 'fire_count': 0}
# {'date': '12/10/2018', 'fire_count': 0}
# {'date': '13/10/2018', 'fire_count': 0}
# {'date': '14/10/2018', 'fire_count': 0}
# {'date': '15/10/2018', 'fire_count': 3}
# {'date': '16/10/2018', 'fire_count': 1}
# {'date': '17/10/2018', 'fire_count': 5}
# {'date': '18/10/2018', 'fire_count': 6}
# {'date': '19/10/2018', 'fire_count': 0}
# {'date': '20/10/2018', 'fire_count': 3}
# {'date': '21/10/2018', 'fire_count': 4}
# {'date': '22/10/2018', 'fire_count': 0}
# {'date': '23/10/2018', 'fire_count': 1}
# {'date': '24/10/2018', 'fire_count': 0}
# {'date': '25/10/2018', 'fire_count': 0}
# {'date': '26/10/2018', 'fire_count': 5}
# {'date': '27/10/2018', 'fire_count': 5}
# {'date': '28/10/2018', 'fire_count': 1}
# {'date': '29/10/2018', 'fire_count': 0}
# {'date': '30/10/2018', 'fire_count': 0}
# {'date': '31/10/2018', 'fire_count': 0}
# {'date': '01/11/2018', 'fire_count': 0}
# {'date': '02/11/2018', 'fire_count': 0}
# {'date': '03/11/2018', 'fire_count': 0}
# {'date': '04/11/2018', 'fire_count': 0}
# {'date': '05/11/2018', 'fire_count': 4}
# {'date': '06/11/2018', 'fire_count': 0}
# {'date': '07/11/2018', 'fire_count': 0}
# {'date': '08/11/2018', 'fire_count': 2}
# {'date': '09/11/2018', 'fire_count': 10}
# {'date': '10/11/2018', 'fire_count': 0}
# {'date': '11/11/2018', 'fire_count': 4}
# {'date': '12/11/2018', 'fire_count': 5}
# {'date': '13/11/2018', 'fire_count': 5}
# {'date': '14/11/2018', 'fire_count': 3}
# {'date': '15/11/2018', 'fire_count': 0}
# {'date': '16/11/2018', 'fire_count': 0}
# {'date': '17/11/2018', 'fire_count': 0}
# {'date': '18/11/2018', 'fire_count': 0}
# {'date': '19/11/2018', 'fire_count': 0}
# {'date': '20/11/2018', 'fire_count': 0}
# {'date': '21/11/2018', 'fire_count': 1}
# {'date': '22/11/2018', 'fire_count': 2}
# {'date': '23/11/2018', 'fire_count': 5}
# {'date': '24/11/2018', 'fire_count': 0}
# {'date': '25/11/2018', 'fire_count': 0}
# {'date': '26/11/2018', 'fire_count': 0}
# {'date': '27/11/2018', 'fire_count': 0}
# {'date': '28/11/2018', 'fire_count': 1}
# {'date': '29/11/2018', 'fire_count': 8}
# {'date': '30/11/2018', 'fire_count': 31}
# {'date': '01/12/2018', 'fire_count': 0}
# {'date': '02/12/2018', 'fire_count': 0}
# {'date': '03/12/2018', 'fire_count': 0}
# {'date': '04/12/2018', 'fire_count': 0}
# {'date': '05/12/2018', 'fire_count': 0}
# {'date': '06/12/2018', 'fire_count': 0}
# {'date': '07/12/2018', 'fire_count': 0}
# {'date': '08/12/2018', 'fire_count': 5}
# {'date': '09/12/2018', 'fire_count': 4}
# {'date': '10/12/2018', 'fire_count': 2}
# {'date': '11/12/2018', 'fire_count': 0}
# {'date': '12/12/2018', 'fire_count': 1}
# {'date': '13/12/2018', 'fire_count': 1}
# {'date': '14/12/2018', 'fire_count': 1}
# {'date': '15/12/2018', 'fire_count': 4}
# {'date': '16/12/2018', 'fire_count': 15}
# {'date': '17/12/2018', 'fire_count': 0}
# {'date': '18/12/2018', 'fire_count': 0}
# {'date': '19/12/2018', 'fire_count': 0}
# {'date': '20/12/2018', 'fire_count': 0}
# {'date': '21/12/2018', 'fire_count': 1}
# {'date': '22/12/2018', 'fire_count': 0}
# {'date': '23/12/2018', 'fire_count': 0}
# {'date': '24/12/2018', 'fire_count': 1}
# {'date': '25/12/2018', 'fire_count': 1}
# {'date': '26/12/2018', 'fire_count': 0}
# {'date': '27/12/2018', 'fire_count': 4}
# {'date': '28/12/2018', 'fire_count': 0}
# {'date': '29/12/2018', 'fire_count': 0}
# {'date': '30/12/2018', 'fire_count': 0}
# {'date': '31/12/2018', 'fire_count': 0}
# {'date': '01/01/2018', 'fire_count': 0}

# %% [markdown]
# **g. Find the records of fires where the confidence is below 70.**

# %%
results = fires.find({"confidence":{"$lt":70}})

for document in results:
    pprint(document)
# Out:
# {'_id': ObjectId('60af1c679343690fa9450829'),
#  'confidence': 67,
#  'date': '27/12/2018',
#  'datetime': '2018-12-27T00:02:15',
#  'latitude': -35.554,
#  'longitude': 143.307,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c679343690fa945082c'),
#  'confidence': 65,
#  'date': '24/12/2018',
#  'datetime': '2018-12-24T13:12:01',
#  'latitude': -35.646,
#  'longitude': 142.282,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('60af1c679343690fa945082f'),
#  'confidence': 69,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T15:38:39',
#  'latitude': -37.624,
#  'longitude': 149.332,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('60af1c679343690fa9450830'),
#  'confidence': 62,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T04:35:15',
#  'latitude': -37.82,
#  'longitude': 142.323,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c679343690fa9450834'),
#  'confidence': 59,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T04:34:57',
#  'latitude': -37.644,
#  'longitude': 149.346,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c679343690fa9450839'),
#  'confidence': 60,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T00:21:11',
#  'latitude': -38.046,
#  'longitude': 144.201,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c679343690fa945083c'),
#  'confidence': 53,
#  'date': '16/12/2018',
#  'datetime': '2018-12-16T00:20:53',
#  'latitude': -37.63,
#  'longitude': 149.335,
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('60af1c679343690fa945083f'),
#  'confidence': 51,
#  'date': '15/12/2018',
#  'datetime': '2018-12-15T13:17:17',
#  'latitude': -37.623,
#  'longitude': 149.323,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c679343690fa9450840'),
#  'confidence': 65,
#  'date': '15/12/2018',
#  'datetime': '2018-12-15T01:16:23',
#  'latitude': -38.038,
#  'longitude': 142.986,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c679343690fa9450843'),
#  'confidence': 53,
#  'date': '12/12/2018',
#  'datetime': '2018-12-12T00:45:38',
#  'latitude': -37.903,
#  'longitude': 145.25,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c679343690fa9450844'),
#  'confidence': 50,
#  'date': '10/12/2018',
#  'datetime': '2018-12-10T00:57:59',
#  'latitude': -37.987,
#  'longitude': 144.005,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c679343690fa9450845'),
#  'confidence': 67,
#  'date': '10/12/2018',
#  'datetime': '2018-12-10T00:56:57',
#  'latitude': -34.289,
#  'longitude': 141.712,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c679343690fa945084e'),
#  'confidence': 56,
#  'date': '08/12/2018',
#  'datetime': '2018-12-08T13:11:43',
#  'latitude': -36.291,
#  'longitude': 146.159,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c679343690fa945084f'),
#  'confidence': 52,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T23:25:57',
#  'latitude': -37.635,
#  'longitude': 149.303,
#  'surface_temperature_celcius': 47}
# {'_id': ObjectId('60af1c679343690fa9450851'),
#  'confidence': 51,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:36',
#  'latitude': -37.59,
#  'longitude': 149.31,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c679343690fa9450852'),
#  'confidence': 64,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:36',
#  'latitude': -37.633,
#  'longitude': 149.264,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c679343690fa9450854'),
#  'confidence': 69,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:35',
#  'latitude': -37.58,
#  'longitude': 149.331,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c679343690fa9450856'),
#  'confidence': 61,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T15:38:32',
#  'latitude': -37.38,
#  'longitude': 149.334,
#  'surface_temperature_celcius': 31}
# {'_id': ObjectId('60af1c679343690fa9450857'),
#  'confidence': 62,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T12:22:15',
#  'latitude': -37.602,
#  'longitude': 149.295,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('60af1c679343690fa9450858'),
#  'confidence': 64,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T12:22:15',
#  'latitude': -37.598,
#  'longitude': 149.29,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('60af1c679343690fa9450864'),
#  'confidence': 69,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T04:34:57',
#  'latitude': -37.61,
#  'longitude': 149.279,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c679343690fa9450865'),
#  'confidence': 60,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:21:00',
#  'latitude': -37.637,
#  'longitude': 146.288,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c679343690fa945086c'),
#  'confidence': 69,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:20:53',
#  'latitude': -37.6,
#  'longitude': 149.297,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c679343690fa945086d'),
#  'confidence': 64,
#  'date': '30/11/2018',
#  'datetime': '2018-11-30T00:20:49',
#  'latitude': -37.382,
#  'longitude': 149.341,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c679343690fa945086e'),
#  'confidence': 53,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T13:17:24',
#  'latitude': -37.611,
#  'longitude': 149.277,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c679343690fa9450870'),
#  'confidence': 68,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T13:17:24',
#  'latitude': -37.605,
#  'longitude': 149.308,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c679343690fa9450871'),
#  'confidence': 52,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T03:53:16',
#  'latitude': -34.282,
#  'longitude': 142.121,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c679343690fa9450873'),
#  'confidence': 64,
#  'date': '29/11/2018',
#  'datetime': '2018-11-29T03:52:10',
#  'latitude': -37.605,
#  'longitude': 149.326,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450876'),
#  'confidence': 50,
#  'date': '28/11/2018',
#  'datetime': '2018-11-28T00:33:14',
#  'latitude': -37.749,
#  'longitude': 148.297,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450879'),
#  'confidence': 68,
#  'date': '23/11/2018',
#  'datetime': '2018-11-23T00:15:12',
#  'latitude': -38.141,
#  'longitude': 143.183,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa945087a'),
#  'confidence': 63,
#  'date': '23/11/2018',
#  'datetime': '2018-11-23T00:14:47',
#  'latitude': -36.952,
#  'longitude': 144.972,
#  'surface_temperature_celcius': 60}
# {'_id': ObjectId('60af1c689343690fa9450880'),
#  'confidence': 64,
#  'date': '14/11/2018',
#  'datetime': '2018-11-14T00:21:26',
#  'latitude': -38.527,
#  'longitude': 143.493,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa9450881'),
#  'confidence': 64,
#  'date': '14/11/2018',
#  'datetime': '2018-11-14T00:21:07',
#  'latitude': -37.332,
#  'longitude': 143.375,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa9450884'),
#  'confidence': 64,
#  'date': '13/11/2018',
#  'datetime': '2018-11-13T03:52:08',
#  'latitude': -37.954,
#  'longitude': 143.918,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450885'),
#  'confidence': 51,
#  'date': '13/11/2018',
#  'datetime': '2018-11-13T01:16:38',
#  'latitude': -38.167,
#  'longitude': 143.841,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa9450886'),
#  'confidence': 62,
#  'date': '13/11/2018',
#  'datetime': '2018-11-13T01:16:37',
#  'latitude': -38.16,
#  'longitude': 143.803,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450887'),
#  'confidence': 63,
#  'date': '12/11/2018',
#  'datetime': '2018-11-12T04:47:32',
#  'latitude': -36.942,
#  'longitude': 143.282,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c689343690fa9450888'),
#  'confidence': 58,
#  'date': '12/11/2018',
#  'datetime': '2018-11-12T04:47:16',
#  'latitude': -37.864,
#  'longitude': 144.174,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450889'),
#  'confidence': 56,
#  'date': '12/11/2018',
#  'datetime': '2018-11-12T04:46:53',
#  'latitude': -38.912,
#  'longitude': 146.272,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa945088a'),
#  'confidence': 67,
#  'date': '12/11/2018',
#  'datetime': '2018-11-12T00:33:15',
#  'latitude': -36.942,
#  'longitude': 143.292,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa945088c'),
#  'confidence': 51,
#  'date': '11/11/2018',
#  'datetime': '2018-11-11T15:08:00',
#  'latitude': -36.943,
#  'longitude': 143.286,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('60af1c689343690fa9450890'),
#  'confidence': 68,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:56',
#  'latitude': -36.759,
#  'longitude': 145.179,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('60af1c689343690fa9450891'),
#  'confidence': 62,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:56',
#  'latitude': -36.758,
#  'longitude': 145.19,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c689343690fa9450897'),
#  'confidence': 63,
#  'date': '09/11/2018',
#  'datetime': '2018-11-09T04:16:46',
#  'latitude': -37.719,
#  'longitude': 142.154,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa945089a'),
#  'confidence': 60,
#  'date': '08/11/2018',
#  'datetime': '2018-11-08T05:12:08',
#  'latitude': -36.538,
#  'longitude': 141.129,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94508a1'),
#  'confidence': 62,
#  'date': '27/10/2018',
#  'datetime': '2018-10-27T04:47:31',
#  'latitude': -36.748,
#  'longitude': 144.168,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94508a9'),
#  'confidence': 67,
#  'date': '26/10/2018',
#  'datetime': '2018-10-26T04:04:53',
#  'latitude': -36.156,
#  'longitude': 143.568,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94508aa'),
#  'confidence': 69,
#  'date': '26/10/2018',
#  'datetime': '2018-10-26T04:04:53',
#  'latitude': -36.152,
#  'longitude': 143.578,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94508ae'),
#  'confidence': 65,
#  'date': '21/10/2018',
#  'datetime': '2018-10-21T01:09:54',
#  'latitude': -36.1,
#  'longitude': 143.772,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa94508b2'),
#  'confidence': 65,
#  'date': '20/10/2018',
#  'datetime': '2018-10-20T00:27:12',
#  'latitude': -37.296,
#  'longitude': 144.386,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa94508bc'),
#  'confidence': 58,
#  'date': '17/10/2018',
#  'datetime': '2018-10-17T04:10:38',
#  'latitude': -37.587,
#  'longitude': 142.479,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94508be'),
#  'confidence': 62,
#  'date': '16/10/2018',
#  'datetime': '2018-10-16T23:56:43',
#  'latitude': -37.288,
#  'longitude': 144.39,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('60af1c689343690fa94508ca'),
#  'confidence': 50,
#  'date': '04/10/2018',
#  'datetime': '2018-10-04T04:41:36',
#  'latitude': -36.418,
#  'longitude': 141.596,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94508cf'),
#  'confidence': 69,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T15:01:44',
#  'latitude': -37.461,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('60af1c689343690fa94508d1'),
#  'confidence': 68,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:28',
#  'latitude': -37.236,
#  'longitude': 141.176,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('60af1c689343690fa94508d2'),
#  'confidence': 59,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T03:58:28',
#  'latitude': -37.227,
#  'longitude': 141.151,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa94508e0'),
#  'confidence': 54,
#  'date': '03/10/2018',
#  'datetime': '2018-10-03T01:22:44',
#  'latitude': -37.227,
#  'longitude': 141.146,
#  'surface_temperature_celcius': 31}
# {'_id': ObjectId('60af1c689343690fa94508e1'),
#  'confidence': 50,
#  'date': '02/10/2018',
#  'datetime': '2018-10-02T23:44:31',
#  'latitude': -37.466,
#  'longitude': 148.1,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('60af1c689343690fa94508e2'),
#  'confidence': 59,
#  'date': '02/10/2018',
#  'datetime': '2018-10-02T04:53:10',
#  'latitude': -37.475,
#  'longitude': 148.134,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94508e7'),
#  'confidence': 68,
#  'date': '02/10/2018',
#  'datetime': '2018-10-02T00:39:34',
#  'latitude': -37.456,
#  'longitude': 148.11,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94508e8'),
#  'confidence': 62,
#  'date': '01/10/2018',
#  'datetime': '2018-10-01T15:13:56',
#  'latitude': -37.463,
#  'longitude': 148.109,
#  'surface_temperature_celcius': 34}
# {'_id': ObjectId('60af1c689343690fa94508ee'),
#  'confidence': 64,
#  'date': '01/10/2018',
#  'datetime': '2018-10-01T04:10:28',
#  'latitude': -37.46,
#  'longitude': 148.113,
#  'surface_temperature_celcius': 52}
# {'_id': ObjectId('60af1c689343690fa94508f6'),
#  'confidence': 65,
#  'date': '27/09/2018',
#  'datetime': '2018-09-27T04:35:18',
#  'latitude': -36.398,
#  'longitude': 145.286,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94508f9'),
#  'confidence': 64,
#  'date': '26/09/2018',
#  'datetime': '2018-09-26T03:52:14',
#  'latitude': -37.087,
#  'longitude': 145.37,
#  'surface_temperature_celcius': 33}
# {'_id': ObjectId('60af1c689343690fa9450906'),
#  'confidence': 59,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T13:30:09',
#  'latitude': -37.375,
#  'longitude': 148.063,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa945090c'),
#  'confidence': 58,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:19',
#  'latitude': -37.397,
#  'longitude': 148.121,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c689343690fa945090d'),
#  'confidence': 68,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:18',
#  'latitude': -37.452,
#  'longitude': 148.115,
#  'surface_temperature_celcius': 77}
# {'_id': ObjectId('60af1c689343690fa945090e'),
#  'confidence': 68,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:18',
#  'latitude': -37.465,
#  'longitude': 148.153,
#  'surface_temperature_celcius': 63}
# {'_id': ObjectId('60af1c689343690fa945090f'),
#  'confidence': 64,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:18',
#  'latitude': -37.45,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 69}
# {'_id': ObjectId('60af1c689343690fa9450912'),
#  'confidence': 61,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:17',
#  'latitude': -37.562,
#  'longitude': 148.05,
#  'surface_temperature_celcius': 72}
# {'_id': ObjectId('60af1c689343690fa9450915'),
#  'confidence': 56,
#  'date': '24/09/2018',
#  'datetime': '2018-09-24T04:04:04',
#  'latitude': -38.495,
#  'longitude': 146.944,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c689343690fa9450918'),
#  'confidence': 56,
#  'date': '23/09/2018',
#  'datetime': '2018-09-23T23:50:43',
#  'latitude': -37.559,
#  'longitude': 148.037,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450919'),
#  'confidence': 58,
#  'date': '23/09/2018',
#  'datetime': '2018-09-23T23:50:40',
#  'latitude': -37.379,
#  'longitude': 148.126,
#  'surface_temperature_celcius': 82}
# {'_id': ObjectId('60af1c689343690fa945091a'),
#  'confidence': 62,
#  'date': '23/09/2018',
#  'datetime': '2018-09-23T23:50:40',
#  'latitude': -37.379,
#  'longitude': 148.132,
#  'surface_temperature_celcius': 78}
# {'_id': ObjectId('60af1c689343690fa9450923'),
#  'confidence': 50,
#  'date': '23/09/2018',
#  'datetime': '2018-09-23T04:59:18',
#  'latitude': -36.984,
#  'longitude': 148.25,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa9450925'),
#  'confidence': 61,
#  'date': '23/09/2018',
#  'datetime': '2018-09-23T04:59:13',
#  'latitude': -37.347,
#  'longitude': 148.019,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('60af1c689343690fa945092a'),
#  'confidence': 56,
#  'date': '23/09/2018',
#  'datetime': '2018-09-23T03:21:28',
#  'latitude': -36.995,
#  'longitude': 148.268,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('60af1c689343690fa945092b'),
#  'confidence': 63,
#  'date': '23/09/2018',
#  'datetime': '2018-09-23T03:21:19',
#  'latitude': -37.554,
#  'longitude': 148.073,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('60af1c689343690fa9450939'),
#  'confidence': 56,
#  'date': '14/08/2018',
#  'datetime': '2018-08-14T04:15:40',
#  'latitude': -37.4421,
#  'longitude': 148.259,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa945093a'),
#  'confidence': 61,
#  'date': '14/08/2018',
#  'datetime': '2018-08-14T04:11:00',
#  'latitude': -38.0173,
#  'longitude': 144.0571,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa945093b'),
#  'confidence': 67,
#  'date': '14/08/2018',
#  'datetime': '2018-08-14T04:10:20',
#  'latitude': -37.4754,
#  'longitude': 148.161,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa945093c'),
#  'confidence': 61,
#  'date': '14/08/2018',
#  'datetime': '2018-08-14T04:09:30',
#  'latitude': -37.443,
#  'longitude': 147.3064,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa945093d'),
#  'confidence': 58,
#  'date': '14/08/2018',
#  'datetime': '2018-08-14T04:07:50',
#  'latitude': -37.7836,
#  'longitude': 143.9688,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa945093e'),
#  'confidence': 54,
#  'date': '13/08/2018',
#  'datetime': '2018-08-13T05:13:30',
#  'latitude': -34.848,
#  'longitude': 141.5002,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450942'),
#  'confidence': 63,
#  'date': '13/08/2018',
#  'datetime': '2018-08-13T05:05:00',
#  'latitude': -34.8425,
#  'longitude': 141.4933,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450943'),
#  'confidence': 63,
#  'date': '13/08/2018',
#  'datetime': '2018-08-13T05:03:10',
#  'latitude': -34.793,
#  'longitude': 141.5898,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450948'),
#  'confidence': 59,
#  'date': '05/08/2018',
#  'datetime': '2018-08-05T04:20:10',
#  'latitude': -37.8519,
#  'longitude': 147.2555,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa945094a'),
#  'confidence': 54,
#  'date': '02/08/2018',
#  'datetime': '2018-08-02T03:45:00',
#  'latitude': -37.491,
#  'longitude': 141.936,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa9450951'),
#  'confidence': 63,
#  'date': '14/07/2018',
#  'datetime': '2018-07-14T04:58:10',
#  'latitude': -38.5194,
#  'longitude': 143.4522,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450952'),
#  'confidence': 61,
#  'date': '14/07/2018',
#  'datetime': '2018-07-14T04:50:20',
#  'latitude': -38.5233,
#  'longitude': 143.433,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450955'),
#  'confidence': 66,
#  'date': '06/07/2018',
#  'datetime': '2018-07-06T04:02:00',
#  'latitude': -37.8757,
#  'longitude': 143.428,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450956'),
#  'confidence': 69,
#  'date': '05/07/2018',
#  'datetime': '2018-07-05T23:44:00',
#  'latitude': -38.4031,
#  'longitude': 147.0701,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa9450957'),
#  'confidence': 57,
#  'date': '04/07/2018',
#  'datetime': '2018-07-04T04:14:00',
#  'latitude': -37.8067,
#  'longitude': 141.7598,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa945095a'),
#  'confidence': 69,
#  'date': '02/07/2018',
#  'datetime': '2018-07-02T04:29:10',
#  'latitude': -37.067,
#  'longitude': 141.379,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('60af1c689343690fa945095b'),
#  'confidence': 69,
#  'date': '02/07/2018',
#  'datetime': '2018-07-02T04:29:10',
#  'latitude': -37.067,
#  'longitude': 141.379,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('60af1c689343690fa945095e'),
#  'confidence': 50,
#  'date': '02/07/2018',
#  'datetime': '2018-07-02T04:28:42',
#  'latitude': -37.886,
#  'longitude': 147.207,
#  'surface_temperature_celcius': 28}
# {'_id': ObjectId('60af1c689343690fa945095f'),
#  'confidence': 50,
#  'date': '02/07/2018',
#  'datetime': '2018-07-02T04:28:42',
#  'latitude': -37.886,
#  'longitude': 147.207,
#  'surface_temperature_celcius': 28}
# {'_id': ObjectId('60af1c689343690fa9450960'),
#  'confidence': 53,
#  'date': '01/07/2018',
#  'datetime': '2018-07-01T13:11:41',
#  'latitude': -37.062,
#  'longitude': 141.373,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('60af1c689343690fa9450961'),
#  'confidence': 53,
#  'date': '01/07/2018',
#  'datetime': '2018-07-01T13:11:41',
#  'latitude': -37.062,
#  'longitude': 141.373,
#  'surface_temperature_celcius': 29}
# {'_id': ObjectId('60af1c689343690fa9450962'),
#  'confidence': 61,
#  'date': '01/07/2018',
#  'datetime': '2018-07-01T03:46:08',
#  'latitude': -36.779,
#  'longitude': 146.108,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('60af1c689343690fa9450963'),
#  'confidence': 61,
#  'date': '01/07/2018',
#  'datetime': '2018-07-01T03:46:08',
#  'latitude': -36.779,
#  'longitude': 146.108,
#  'surface_temperature_celcius': 32}
# {'_id': ObjectId('60af1c689343690fa9450972'),
#  'confidence': 53,
#  'date': '18/06/2018',
#  'datetime': '2018-06-18T04:14:00',
#  'latitude': -37.8387,
#  'longitude': 144.6301,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450973'),
#  'confidence': 66,
#  'date': '16/06/2018',
#  'datetime': '2018-06-16T04:34:30',
#  'latitude': -37.3583,
#  'longitude': 143.0203,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450974'),
#  'confidence': 64,
#  'date': '16/06/2018',
#  'datetime': '2018-06-16T04:26:10',
#  'latitude': -36.7084,
#  'longitude': 142.7354,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450975'),
#  'confidence': 61,
#  'date': '14/06/2018',
#  'datetime': '2018-06-14T04:44:10',
#  'latitude': -36.2669,
#  'longitude': 143.1906,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa9450977'),
#  'confidence': 55,
#  'date': '14/06/2018',
#  'datetime': '2018-06-14T04:40:10',
#  'latitude': -36.3769,
#  'longitude': 144.7505,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450978'),
#  'confidence': 69,
#  'date': '14/06/2018',
#  'datetime': '2018-06-14T04:38:30',
#  'latitude': -36.059,
#  'longitude': 143.7718,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450979'),
#  'confidence': 62,
#  'date': '13/06/2018',
#  'datetime': '2018-06-13T04:02:00',
#  'latitude': -36.0201,
#  'longitude': 143.7775,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa945097a'),
#  'confidence': 62,
#  'date': '11/06/2018',
#  'datetime': '2018-06-11T04:09:40',
#  'latitude': -37.6767,
#  'longitude': 142.9892,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa945097b'),
#  'confidence': 64,
#  'date': '11/06/2018',
#  'datetime': '2018-06-11T04:08:00',
#  'latitude': -37.6662,
#  'longitude': 142.9874,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450980'),
#  'confidence': 55,
#  'date': '07/06/2018',
#  'datetime': '2018-06-07T04:36:00',
#  'latitude': -36.1858,
#  'longitude': 143.885,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450982'),
#  'confidence': 68,
#  'date': '07/06/2018',
#  'datetime': '2018-06-07T04:35:40',
#  'latitude': -36.2111,
#  'longitude': 141.505,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450983'),
#  'confidence': 53,
#  'date': '07/06/2018',
#  'datetime': '2018-06-07T04:35:30',
#  'latitude': -36.5794,
#  'longitude': 142.5959,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450986'),
#  'confidence': 61,
#  'date': '07/06/2018',
#  'datetime': '2018-06-07T04:32:10',
#  'latitude': -36.2229,
#  'longitude': 143.4245,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450987'),
#  'confidence': 52,
#  'date': '07/06/2018',
#  'datetime': '2018-06-07T04:32:10',
#  'latitude': -36.0279,
#  'longitude': 146.0244,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa9450990'),
#  'confidence': 58,
#  'date': '04/06/2018',
#  'datetime': '2018-06-04T04:02:30',
#  'latitude': -37.4661,
#  'longitude': 143.2419,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa9450994'),
#  'confidence': 54,
#  'date': '04/06/2018',
#  'datetime': '2018-06-04T04:02:10',
#  'latitude': -36.4422,
#  'longitude': 141.427,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450995'),
#  'confidence': 59,
#  'date': '04/06/2018',
#  'datetime': '2018-06-04T04:02:10',
#  'latitude': -36.251,
#  'longitude': 142.5651,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa945099b'),
#  'confidence': 64,
#  'date': '02/06/2018',
#  'datetime': '2018-06-02T04:14:40',
#  'latitude': -36.2032,
#  'longitude': 145.3025,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa945099c'),
#  'confidence': 65,
#  'date': '02/06/2018',
#  'datetime': '2018-06-02T04:14:10',
#  'latitude': -35.779,
#  'longitude': 143.1057,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94509a1'),
#  'confidence': 62,
#  'date': '02/06/2018',
#  'datetime': '2018-06-02T04:14:10',
#  'latitude': -36.6312,
#  'longitude': 142.5058,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94509a6'),
#  'confidence': 60,
#  'date': '26/05/2018',
#  'datetime': '2018-05-26T04:08:10',
#  'latitude': -36.3334,
#  'longitude': 141.1515,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94509a9'),
#  'confidence': 61,
#  'date': '24/05/2018',
#  'datetime': '2018-05-24T04:20:20',
#  'latitude': -37.0585,
#  'longitude': 143.8589,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94509aa'),
#  'confidence': 59,
#  'date': '24/05/2018',
#  'datetime': '2018-05-24T00:04:20',
#  'latitude': -36.6859,
#  'longitude': 146.8907,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94509ab'),
#  'confidence': 56,
#  'date': '24/05/2018',
#  'datetime': '2018-05-24T00:01:50',
#  'latitude': -36.575,
#  'longitude': 146.6668,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94509af'),
#  'confidence': 68,
#  'date': '23/05/2018',
#  'datetime': '2018-05-23T00:54:50',
#  'latitude': -37.9004,
#  'longitude': 141.0921,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94509b1'),
#  'confidence': 66,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T15:30:20',
#  'latitude': -36.6396,
#  'longitude': 146.8973,
#  'surface_temperature_celcius': 36}
# {'_id': ObjectId('60af1c689343690fa94509b3'),
#  'confidence': 59,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T04:42:20',
#  'latitude': -36.7889,
#  'longitude': 146.6495,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa94509b4'),
#  'confidence': 63,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T04:38:50',
#  'latitude': -36.4794,
#  'longitude': 144.5752,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94509b5'),
#  'confidence': 52,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T04:37:20',
#  'latitude': -37.6198,
#  'longitude': 143.0357,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa94509b7'),
#  'confidence': 58,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T04:34:50',
#  'latitude': -37.4857,
#  'longitude': 143.5322,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94509bc'),
#  'confidence': 53,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T04:32:50',
#  'latitude': -36.7842,
#  'longitude': 146.9658,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94509c5'),
#  'confidence': 65,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T04:32:20',
#  'latitude': -36.7871,
#  'longitude': 146.9604,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94509c6'),
#  'confidence': 64,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T04:32:20',
#  'latitude': -37.5158,
#  'longitude': 142.8257,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94509c8'),
#  'confidence': 61,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T04:32:20',
#  'latitude': -37.7287,
#  'longitude': 143.1682,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94509c9'),
#  'confidence': 58,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T04:32:20',
#  'latitude': -37.7379,
#  'longitude': 143.1706,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94509ce'),
#  'confidence': 61,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T00:13:00',
#  'latitude': -38.4322,
#  'longitude': 146.3208,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94509cf'),
#  'confidence': 66,
#  'date': '22/05/2018',
#  'datetime': '2018-05-22T00:13:00',
#  'latitude': -37.9077,
#  'longitude': 141.1101,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94509d2'),
#  'confidence': 61,
#  'date': '18/05/2018',
#  'datetime': '2018-05-18T03:25:00',
#  'latitude': -36.1337,
#  'longitude': 146.1243,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94509d3'),
#  'confidence': 68,
#  'date': '18/05/2018',
#  'datetime': '2018-05-18T03:21:10',
#  'latitude': -36.8431,
#  'longitude': 147.5395,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94509d4'),
#  'confidence': 69,
#  'date': '18/05/2018',
#  'datetime': '2018-05-18T03:21:10',
#  'latitude': -36.8403,
#  'longitude': 147.5354,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa94509d5'),
#  'confidence': 64,
#  'date': '18/05/2018',
#  'datetime': '2018-05-18T03:21:10',
#  'latitude': -36.1369,
#  'longitude': 146.116,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94509d6'),
#  'confidence': 55,
#  'date': '18/05/2018',
#  'datetime': '2018-05-18T00:43:10',
#  'latitude': -37.164,
#  'longitude': 148.915,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94509d7'),
#  'confidence': 66,
#  'date': '18/05/2018',
#  'datetime': '2018-05-18T00:38:10',
#  'latitude': -37.1521,
#  'longitude': 148.9446,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa94509da'),
#  'confidence': 53,
#  'date': '16/05/2018',
#  'datetime': '2018-05-16T03:37:40',
#  'latitude': -36.1875,
#  'longitude': 143.5158,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94509db'),
#  'confidence': 56,
#  'date': '16/05/2018',
#  'datetime': '2018-05-16T03:32:50',
#  'latitude': -36.1887,
#  'longitude': 143.4722,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94509dc'),
#  'confidence': 61,
#  'date': '16/05/2018',
#  'datetime': '2018-05-16T00:48:40',
#  'latitude': -37.2465,
#  'longitude': 144.3795,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94509de'),
#  'confidence': 64,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:35:20',
#  'latitude': -36.4437,
#  'longitude': 143.5726,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94509df'),
#  'confidence': 59,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:34:50',
#  'latitude': -36.3987,
#  'longitude': 142.6332,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94509e3'),
#  'confidence': 69,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:33:20',
#  'latitude': -36.3065,
#  'longitude': 141.4495,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94509e4'),
#  'confidence': 66,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:33:20',
#  'latitude': -37.5074,
#  'longitude': 142.976,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94509e7'),
#  'confidence': 55,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:32:50',
#  'latitude': -37.2622,
#  'longitude': 144.3704,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94509e8'),
#  'confidence': 69,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:32:50',
#  'latitude': -36.3111,
#  'longitude': 143.7704,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94509e9'),
#  'confidence': 51,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:32:50',
#  'latitude': -36.7159,
#  'longitude': 141.4716,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa94509ea'),
#  'confidence': 51,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:32:50',
#  'latitude': -36.5963,
#  'longitude': 144.0066,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa94509f2'),
#  'confidence': 60,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:29:40',
#  'latitude': -36.4216,
#  'longitude': 141.2799,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94509f3'),
#  'confidence': 64,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:29:40',
#  'latitude': -36.4317,
#  'longitude': 143.0967,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94509f4'),
#  'confidence': 63,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:29:30',
#  'latitude': -36.2538,
#  'longitude': 145.5929,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94509f5'),
#  'confidence': 66,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:29:30',
#  'latitude': -36.437,
#  'longitude': 144.1478,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94509f6'),
#  'confidence': 55,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:29:10',
#  'latitude': -36.6217,
#  'longitude': 142.0944,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94509f7'),
#  'confidence': 66,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:28:40',
#  'latitude': -36.3652,
#  'longitude': 141.3508,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94509f8'),
#  'confidence': 56,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:28:20',
#  'latitude': -36.8241,
#  'longitude': 145.1274,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94509f9'),
#  'confidence': 63,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:28:10',
#  'latitude': -36.3296,
#  'longitude': 141.7522,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94509fa'),
#  'confidence': 64,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:28:10',
#  'latitude': -35.7542,
#  'longitude': 142.5039,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450a03'),
#  'confidence': 67,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:27:10',
#  'latitude': -36.3019,
#  'longitude': 146.4343,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450a05'),
#  'confidence': 63,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:27:10',
#  'latitude': -36.3542,
#  'longitude': 141.0935,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450a08'),
#  'confidence': 57,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:40',
#  'latitude': -35.6785,
#  'longitude': 143.5077,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450a09'),
#  'confidence': 68,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:40',
#  'latitude': -36.6755,
#  'longitude': 141.5039,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa9450a10'),
#  'confidence': 69,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.3971,
#  'longitude': 142.6444,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450a12'),
#  'confidence': 56,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.4226,
#  'longitude': 143.0946,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450a15'),
#  'confidence': 52,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.5646,
#  'longitude': 142.3068,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa9450a18'),
#  'confidence': 64,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.7126,
#  'longitude': 141.6358,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450a19'),
#  'confidence': 63,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.4347,
#  'longitude': 143.5704,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450a1c'),
#  'confidence': 68,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.7611,
#  'longitude': 141.6048,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450a1d'),
#  'confidence': 65,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.5664,
#  'longitude': 142.9892,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450a1f'),
#  'confidence': 60,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.6483,
#  'longitude': 142.4878,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450a23'),
#  'confidence': 66,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.86,
#  'longitude': 142.8137,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa9450a24'),
#  'confidence': 69,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.3119,
#  'longitude': 146.4371,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450a26'),
#  'confidence': 59,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.6463,
#  'longitude': 144.7594,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450a2a'),
#  'confidence': 51,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -37.2794,
#  'longitude': 143.5903,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450a2d'),
#  'confidence': 66,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -37.2811,
#  'longitude': 143.8819,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450a34'),
#  'confidence': 69,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -36.0411,
#  'longitude': 141.7071,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450a36'),
#  'confidence': 69,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -35.9903,
#  'longitude': 142.2708,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa9450a40'),
#  'confidence': 64,
#  'date': '15/05/2018',
#  'datetime': '2018-05-15T04:26:20',
#  'latitude': -37.7481,
#  'longitude': 143.4151,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450a47'),
#  'confidence': 50,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:42:20',
#  'latitude': -36.353,
#  'longitude': 144.5977,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa9450a48'),
#  'confidence': 69,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:42:00',
#  'latitude': -36.4489,
#  'longitude': 144.1445,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa9450a49'),
#  'confidence': 52,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:42:00',
#  'latitude': -34.9917,
#  'longitude': 141.8885,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa9450a4a'),
#  'confidence': 69,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:42:00',
#  'latitude': -36.4032,
#  'longitude': 144.0604,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa9450a4d'),
#  'confidence': 56,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:40:20',
#  'latitude': -36.3883,
#  'longitude': 143.7526,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450a50'),
#  'confidence': 66,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:40:10',
#  'latitude': -36.5513,
#  'longitude': 144.1473,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450a53'),
#  'confidence': 66,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:39:10',
#  'latitude': -36.6361,
#  'longitude': 144.5124,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450a5a'),
#  'confidence': 62,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -37.1999,
#  'longitude': 143.6425,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450a5c'),
#  'confidence': 53,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -34.9959,
#  'longitude': 141.8635,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa9450a5d'),
#  'confidence': 53,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -34.9843,
#  'longitude': 141.8736,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa9450a6b'),
#  'confidence': 57,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.8399,
#  'longitude': 142.6291,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450a6c'),
#  'confidence': 50,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -35.708,
#  'longitude': 143.7987,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa9450a71'),
#  'confidence': 68,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.3832,
#  'longitude': 143.7566,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450a72'),
#  'confidence': 59,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.304,
#  'longitude': 143.7445,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa9450a73'),
#  'confidence': 55,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.591,
#  'longitude': 141.7194,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa9450a74'),
#  'confidence': 68,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.8377,
#  'longitude': 142.642,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450a77'),
#  'confidence': 63,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.0518,
#  'longitude': 141.6846,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450a79'),
#  'confidence': 54,
#  'date': '13/05/2018',
#  'datetime': '2018-05-13T04:38:40',
#  'latitude': -36.7321,
#  'longitude': 143.1978,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa9450a7a'),
#  'confidence': 64,
#  'date': '12/05/2018',
#  'datetime': '2018-05-12T04:02:30',
#  'latitude': -36.5375,
#  'longitude': 146.0866,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450a7d'),
#  'confidence': 66,
#  'date': '12/05/2018',
#  'datetime': '2018-05-12T03:56:10',
#  'latitude': -34.9194,
#  'longitude': 140.9678,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450a7f'),
#  'confidence': 64,
#  'date': '12/05/2018',
#  'datetime': '2018-05-12T03:56:10',
#  'latitude': -36.4061,
#  'longitude': 143.0987,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450a83'),
#  'confidence': 67,
#  'date': '12/05/2018',
#  'datetime': '2018-05-12T01:15:30',
#  'latitude': -37.9774,
#  'longitude': 141.2029,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa9450a89'),
#  'confidence': 65,
#  'date': '11/05/2018',
#  'datetime': '2018-05-11T04:50:40',
#  'latitude': -36.1188,
#  'longitude': 145.156,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450a8b'),
#  'confidence': 54,
#  'date': '11/05/2018',
#  'datetime': '2018-05-11T04:50:40',
#  'latitude': -35.4173,
#  'longitude': 143.2041,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450a8e'),
#  'confidence': 54,
#  'date': '11/05/2018',
#  'datetime': '2018-05-11T04:50:40',
#  'latitude': -36.3909,
#  'longitude': 141.1843,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450a94'),
#  'confidence': 58,
#  'date': '11/05/2018',
#  'datetime': '2018-05-11T04:50:40',
#  'latitude': -36.4713,
#  'longitude': 144.4747,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa9450a96'),
#  'confidence': 68,
#  'date': '11/05/2018',
#  'datetime': '2018-05-11T00:33:20',
#  'latitude': -38.5675,
#  'longitude': 146.4563,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450a9b'),
#  'confidence': 66,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:14:30',
#  'latitude': -36.7937,
#  'longitude': 141.3669,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450a9e'),
#  'confidence': 55,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:14:10',
#  'latitude': -36.2359,
#  'longitude': 141.3007,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450aa0'),
#  'confidence': 65,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:14:00',
#  'latitude': -36.587,
#  'longitude': 142.87,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450aa6'),
#  'confidence': 69,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:11:10',
#  'latitude': -36.9731,
#  'longitude': 143.9437,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450aa8'),
#  'confidence': 63,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:11:10',
#  'latitude': -36.7532,
#  'longitude': 141.7986,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450aab'),
#  'confidence': 64,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:11:10',
#  'latitude': -36.6258,
#  'longitude': 142.9987,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9450aac'),
#  'confidence': 67,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:10:10',
#  'latitude': -36.0236,
#  'longitude': 143.2158,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450aad'),
#  'confidence': 59,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:10:00',
#  'latitude': -37.4574,
#  'longitude': 142.9354,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa9450aae'),
#  'confidence': 57,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:09:50',
#  'latitude': -37.3317,
#  'longitude': 143.822,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450aaf'),
#  'confidence': 57,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:09:40',
#  'latitude': -36.6329,
#  'longitude': 142.9903,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450ab0'),
#  'confidence': 66,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:09:40',
#  'latitude': -36.884,
#  'longitude': 145.8938,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450ab1'),
#  'confidence': 56,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:09:40',
#  'latitude': -37.5263,
#  'longitude': 143.0882,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c689343690fa9450ab4'),
#  'confidence': 62,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:09:20',
#  'latitude': -36.2455,
#  'longitude': 141.3205,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450ab6'),
#  'confidence': 56,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:08:50',
#  'latitude': -37.7461,
#  'longitude': 142.7369,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa9450ac0'),
#  'confidence': 60,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:08:20',
#  'latitude': -38.294,
#  'longitude': 143.7227,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450ac3'),
#  'confidence': 61,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -37.6659,
#  'longitude': 143.186,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450ac4'),
#  'confidence': 63,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -37.7506,
#  'longitude': 142.7265,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa9450ac7'),
#  'confidence': 60,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -37.959,
#  'longitude': 143.5497,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa9450ac9'),
#  'confidence': 68,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -38.0189,
#  'longitude': 143.6406,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450ace'),
#  'confidence': 68,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -38.2481,
#  'longitude': 142.8381,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9450ad2'),
#  'confidence': 65,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -38.293,
#  'longitude': 145.966,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9450ad7'),
#  'confidence': 62,
#  'date': '10/05/2018',
#  'datetime': '2018-05-10T04:08:10',
#  'latitude': -36.9827,
#  'longitude': 141.4064,
#  'surface_temperature_celcius': 41}
# ...
#  'latitude': -36.6281,
#  'longitude': 142.4349,
#  'surface_temperature_celcius': 68}
# {'_id': ObjectId('60af1c689343690fa9451141'),
#  'confidence': 61,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:39:40',
#  'latitude': -36.937,
#  'longitude': 142.1176,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa9451146'),
#  'confidence': 50,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:38:10',
#  'latitude': -36.6951,
#  'longitude': 145.424,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa945114a'),
#  'confidence': 67,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:36:30',
#  'latitude': -37.6714,
#  'longitude': 144.2154,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa945114c'),
#  'confidence': 63,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:36:30',
#  'latitude': -38.0494,
#  'longitude': 143.9141,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c689343690fa945115a'),
#  'confidence': 54,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:34:20',
#  'latitude': -38.4879,
#  'longitude': 143.9971,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa9451160'),
#  'confidence': 63,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:33:30',
#  'latitude': -37.1744,
#  'longitude': 143.9256,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9451162'),
#  'confidence': 69,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:33:30',
#  'latitude': -36.4918,
#  'longitude': 142.2465,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa9451167'),
#  'confidence': 66,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:33:10',
#  'latitude': -36.6299,
#  'longitude': 142.4234,
#  'surface_temperature_celcius': 71}
# {'_id': ObjectId('60af1c689343690fa945116b'),
#  'confidence': 53,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:33:10',
#  'latitude': -36.1439,
#  'longitude': 145.832,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa9451172'),
#  'confidence': 54,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:32:50',
#  'latitude': -36.7009,
#  'longitude': 141.541,
#  'surface_temperature_celcius': 49}
# {'_id': ObjectId('60af1c689343690fa9451179'),
#  'confidence': 55,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -36.4611,
#  'longitude': 143.146,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa945117c'),
#  'confidence': 53,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -36.3539,
#  'longitude': 142.1894,
#  'surface_temperature_celcius': 53}
# {'_id': ObjectId('60af1c689343690fa9451180'),
#  'confidence': 66,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -37.0081,
#  'longitude': 141.7654,
#  'surface_temperature_celcius': 62}
# {'_id': ObjectId('60af1c689343690fa9451183'),
#  'confidence': 64,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -36.2889,
#  'longitude': 141.7692,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c689343690fa9451185'),
#  'confidence': 67,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -36.6228,
#  'longitude': 142.428,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa9451187'),
#  'confidence': 60,
#  'date': '04/04/2018',
#  'datetime': '2018-04-04T04:32:40',
#  'latitude': -38.1177,
#  'longitude': 143.6409,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa945119d'),
#  'confidence': 69,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:53:50',
#  'latitude': -37.8668,
#  'longitude': 143.0472,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa945119e'),
#  'confidence': 68,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:53:40',
#  'latitude': -37.7602,
#  'longitude': 143.382,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94511a0'),
#  'confidence': 66,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:53:30',
#  'latitude': -37.7885,
#  'longitude': 142.9509,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94511ac'),
#  'confidence': 66,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:52:10',
#  'latitude': -37.8717,
#  'longitude': 143.2566,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94511b1'),
#  'confidence': 67,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:51:10',
#  'latitude': -37.8011,
#  'longitude': 144.7343,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94511b7'),
#  'confidence': 67,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:50:50',
#  'latitude': -37.0241,
#  'longitude': 141.5163,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94511b8'),
#  'confidence': 66,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:50:50',
#  'latitude': -37.2912,
#  'longitude': 143.543,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94511b9'),
#  'confidence': 52,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:50:50',
#  'latitude': -37.313,
#  'longitude': 146.1561,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa94511ba'),
#  'confidence': 56,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:50:50',
#  'latitude': -38.0226,
#  'longitude': 143.6739,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94511bf'),
#  'confidence': 56,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:50:40',
#  'latitude': -37.8089,
#  'longitude': 145.9555,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94511c0'),
#  'confidence': 62,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:50:40',
#  'latitude': -37.9009,
#  'longitude': 143.6217,
#  'surface_temperature_celcius': 45}
# {'_id': ObjectId('60af1c689343690fa94511c2'),
#  'confidence': 69,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:50:40',
#  'latitude': -37.7836,
#  'longitude': 142.9437,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94511c6'),
#  'confidence': 52,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:50:40',
#  'latitude': -37.0484,
#  'longitude': 141.6245,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94511c7'),
#  'confidence': 68,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T03:50:40',
#  'latitude': -36.911,
#  'longitude': 142.1445,
#  'surface_temperature_celcius': 47}
# {'_id': ObjectId('60af1c689343690fa94511cf'),
#  'confidence': 67,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T01:11:00',
#  'latitude': -34.2536,
#  'longitude': 141.6199,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa94511d3'),
#  'confidence': 57,
#  'date': '03/04/2018',
#  'datetime': '2018-04-03T01:07:00',
#  'latitude': -34.2614,
#  'longitude': 141.6412,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94511d4'),
#  'confidence': 60,
#  'date': '02/04/2018',
#  'datetime': '2018-04-02T04:53:30',
#  'latitude': -36.3872,
#  'longitude': 145.3858,
#  'surface_temperature_celcius': 40}
# {'_id': ObjectId('60af1c689343690fa94511d7'),
#  'confidence': 63,
#  'date': '02/04/2018',
#  'datetime': '2018-04-02T04:45:10',
#  'latitude': -36.494,
#  'longitude': 145.4522,
#  'surface_temperature_celcius': 41}
# {'_id': ObjectId('60af1c689343690fa94511d8'),
#  'confidence': 60,
#  'date': '02/04/2018',
#  'datetime': '2018-04-02T00:24:50',
#  'latitude': -37.324,
#  'longitude': 146.1647,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa94511dd'),
#  'confidence': 58,
#  'date': '01/04/2018',
#  'datetime': '2018-04-01T04:02:40',
#  'latitude': -36.2044,
#  'longitude': 145.7706,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c689343690fa94511de'),
#  'confidence': 57,
#  'date': '01/04/2018',
#  'datetime': '2018-04-01T04:02:40',
#  'latitude': -36.5245,
#  'longitude': 143.1556,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa94511df'),
#  'confidence': 50,
#  'date': '01/04/2018',
#  'datetime': '2018-04-01T04:02:40',
#  'latitude': -36.1002,
#  'longitude': 147.6494,
#  'surface_temperature_celcius': 39}
# {'_id': ObjectId('60af1c689343690fa94511e9'),
#  'confidence': 68,
#  'date': '31/03/2018',
#  'datetime': '2018-03-31T04:57:50',
#  'latitude': -36.1649,
#  'longitude': 145.9352,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94511ea'),
#  'confidence': 68,
#  'date': '31/03/2018',
#  'datetime': '2018-03-31T04:57:40',
#  'latitude': -36.0436,
#  'longitude': 145.7964,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94511f0'),
#  'confidence': 52,
#  'date': '31/03/2018',
#  'datetime': '2018-03-31T04:57:10',
#  'latitude': -36.7134,
#  'longitude': 145.2151,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa94511f1'),
#  'confidence': 61,
#  'date': '31/03/2018',
#  'datetime': '2018-03-31T04:57:10',
#  'latitude': -36.7028,
#  'longitude': 145.2519,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa94511f2'),
#  'confidence': 51,
#  'date': '31/03/2018',
#  'datetime': '2018-03-31T04:57:10',
#  'latitude': -37.561,
#  'longitude': 143.242,
#  'surface_temperature_celcius': 38}
# {'_id': ObjectId('60af1c689343690fa94511f3'),
#  'confidence': 56,
#  'date': '31/03/2018',
#  'datetime': '2018-03-31T04:57:10',
#  'latitude': -37.982,
#  'longitude': 143.6422,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94511f5'),
#  'confidence': 51,
#  'date': '31/03/2018',
#  'datetime': '2018-03-31T00:36:30',
#  'latitude': -34.2568,
#  'longitude': 141.64,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa94511f6'),
#  'confidence': 69,
#  'date': '29/03/2018',
#  'datetime': '2018-03-29T00:48:40',
#  'latitude': -34.2648,
#  'longitude': 141.6325,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c689343690fa9451209'),
#  'confidence': 53,
#  'date': '28/03/2018',
#  'datetime': '2018-03-28T04:29:30',
#  'latitude': -37.6195,
#  'longitude': 143.4212,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa945121c'),
#  'confidence': 63,
#  'date': '28/03/2018',
#  'datetime': '2018-03-28T04:26:50',
#  'latitude': -37.6376,
#  'longitude': 143.4255,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa9451226'),
#  'confidence': 69,
#  'date': '28/03/2018',
#  'datetime': '2018-03-28T04:26:50',
#  'latitude': -36.4422,
#  'longitude': 141.4172,
#  'surface_temperature_celcius': 46}
# {'_id': ObjectId('60af1c689343690fa945122c'),
#  'confidence': 55,
#  'date': '28/03/2018',
#  'datetime': '2018-03-28T04:26:50',
#  'latitude': -34.342,
#  'longitude': 141.6548,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa9451230'),
#  'confidence': 68,
#  'date': '26/03/2018',
#  'datetime': '2018-03-26T04:41:10',
#  'latitude': -38.1131,
#  'longitude': 143.7173,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa945123a'),
#  'confidence': 60,
#  'date': '26/03/2018',
#  'datetime': '2018-03-26T04:39:10',
#  'latitude': -37.8469,
#  'longitude': 143.5343,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa945123c'),
#  'confidence': 67,
#  'date': '26/03/2018',
#  'datetime': '2018-03-26T04:39:10',
#  'latitude': -37.1956,
#  'longitude': 141.0252,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa945123f'),
#  'confidence': 62,
#  'date': '25/03/2018',
#  'datetime': '2018-03-25T04:03:10',
#  'latitude': -37.8992,
#  'longitude': 143.4534,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa945124a'),
#  'confidence': 57,
#  'date': '25/03/2018',
#  'datetime': '2018-03-25T03:56:40',
#  'latitude': -37.9022,
#  'longitude': 143.4607,
#  'surface_temperature_celcius': 57}
# {'_id': ObjectId('60af1c689343690fa945124b'),
#  'confidence': 65,
#  'date': '24/03/2018',
#  'datetime': '2018-03-24T04:58:00',
#  'latitude': -37.1603,
#  'longitude': 142.8088,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa945124c'),
#  'confidence': 55,
#  'date': '24/03/2018',
#  'datetime': '2018-03-24T04:56:10',
#  'latitude': -37.1684,
#  'longitude': 142.8183,
#  'surface_temperature_celcius': 48}
# {'_id': ObjectId('60af1c689343690fa945124e'),
#  'confidence': 58,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:39:20',
#  'latitude': -37.9164,
#  'longitude': 143.4866,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa9451250'),
#  'confidence': 63,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:39:20',
#  'latitude': -37.9257,
#  'longitude': 143.4891,
#  'surface_temperature_celcius': 54}
# {'_id': ObjectId('60af1c689343690fa9451251'),
#  'confidence': 64,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:36:00',
#  'latitude': -37.3982,
#  'longitude': 147.0001,
#  'surface_temperature_celcius': 58}
# {'_id': ObjectId('60af1c689343690fa9451253'),
#  'confidence': 59,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:35:00',
#  'latitude': -37.4023,
#  'longitude': 147.0394,
#  'surface_temperature_celcius': 56}
# {'_id': ObjectId('60af1c689343690fa9451254'),
#  'confidence': 60,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:33:50',
#  'latitude': -37.4336,
#  'longitude': 147.0534,
#  'surface_temperature_celcius': 51}
# {'_id': ObjectId('60af1c689343690fa9451255'),
#  'confidence': 61,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:33:30',
#  'latitude': -37.4003,
#  'longitude': 147.0448,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa9451256'),
#  'confidence': 53,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:33:30',
#  'latitude': -37.9184,
#  'longitude': 143.4745,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa9451257'),
#  'confidence': 61,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:33:10',
#  'latitude': -37.3911,
#  'longitude': 147.037,
#  'surface_temperature_celcius': 50}
# {'_id': ObjectId('60af1c689343690fa945125b'),
#  'confidence': 66,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T04:32:50',
#  'latitude': -37.9277,
#  'longitude': 143.477,
#  'surface_temperature_celcius': 55}
# {'_id': ObjectId('60af1c689343690fa9451261'),
#  'confidence': 60,
#  'date': '19/03/2018',
#  'datetime': '2018-03-19T00:12:50',
#  'latitude': -37.3942,
#  'longitude': 147.0455,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa9451262'),
#  'confidence': 64,
#  'date': '18/03/2018',
#  'datetime': '2018-03-18T13:16:50',
#  'latitude': -37.4313,
#  'longitude': 147.0343,
#  'surface_temperature_celcius': 37}
# {'_id': ObjectId('60af1c689343690fa945126d'),
#  'confidence': 52,
#  'date': '15/03/2018',
#  'datetime': '2018-03-15T00:42:50',
#  'latitude': -37.4075,
#  'longitude': 147.0233,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa945126e'),
#  'confidence': 66,
#  'date': '15/03/2018',
#  'datetime': '2018-03-15T00:42:50',
#  'latitude': -37.0228,
#  'longitude': 148.1281,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa945126f'),
#  'confidence': 51,
#  'date': '15/03/2018',
#  'datetime': '2018-03-15T00:42:40',
#  'latitude': -37.002,
#  'longitude': 148.2055,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa945127c'),
#  'confidence': 56,
#  'date': '13/03/2018',
#  'datetime': '2018-03-13T23:58:50',
#  'latitude': -37.0286,
#  'longitude': 148.155,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa945127d'),
#  'confidence': 52,
#  'date': '13/03/2018',
#  'datetime': '2018-03-13T12:57:00',
#  'latitude': -37.0316,
#  'longitude': 148.1519,
#  'surface_temperature_celcius': 35}
# {'_id': ObjectId('60af1c689343690fa9451288'),
#  'confidence': 55,
#  'date': '10/03/2018',
#  'datetime': '2018-03-10T04:43:00',
#  'latitude': -36.2544,
#  'longitude': 148.0353,
#  'surface_temperature_celcius': 42}
# {'_id': ObjectId('60af1c689343690fa9451289'),
#  'confidence': 54,
#  'date': '10/03/2018',
#  'datetime': '2018-03-10T04:42:30',
#  'latitude': -37.2197,
#  'longitude': 147.9621,
#  'surface_temperature_celcius': 43}
# {'_id': ObjectId('60af1c689343690fa945128c'),
#  'confidence': 54,
#  'date': '09/03/2018',
#  'datetime': '2018-03-09T03:57:00',
#  'latitude': -37.7171,
#  'longitude': 147.5866,
#  'surface_temperature_celcius': 44}
# {'_id': ObjectId('60af1c689343690fa945128e'),
#  'confidence': 68,
#  'date': '08/03/2018',
#  'datetime': '2018-03-08T04:51:00',
#  'latitude': -37.7885,
#  'longitude': 141.9352,
#  'surface_temperature_celcius': 55}

# %% [markdown]
# **h. Find the average surface temperature (°C) for each day. You are required to only display average surface temperature (°C) and the date in the output.**

# %%
results = climates.aggregate(
    [

        {
            "$lookup":{
                    "from": "fire_historic",
                    "localField": "fires",
                    "foreignField" : "_id",
                    "as": "fires"
            }
        },
        {
            "$unwind": {
                 "path": "$fires",
                 "preserveNullAndEmptyArrays": True
                 
             }
        },
        {
            "$group": {
                "_id": "$date",
                "avg_surface_temp": {
                    "$avg": "$fires.surface_temperature_celcius"
                }
            }
        },
        { 
            "$project": {  
                        "_id": 0,
                        "date": "$_id",
                        "avg_surface_temp": 1
            }
        }
        
    ]
)

for document in results:
    pprint(document)
# Out:
# {'avg_surface_temp': None, 'date': '31/12/2018'}
# {'avg_surface_temp': 62.75, 'date': '27/12/2018'}
# {'avg_surface_temp': 54.0, 'date': '25/12/2018'}
# {'avg_surface_temp': None, 'date': '23/12/2018'}
# {'avg_surface_temp': None, 'date': '19/12/2018'}
# {'avg_surface_temp': 60.0, 'date': '13/12/2018'}
# {'avg_surface_temp': 44.0, 'date': '12/12/2018'}
# {'avg_surface_temp': 50.6, 'date': '08/12/2018'}
# {'avg_surface_temp': None, 'date': '07/12/2018'}
# {'avg_surface_temp': None, 'date': '06/12/2018'}
# {'avg_surface_temp': None, 'date': '03/12/2018'}
# {'avg_surface_temp': None, 'date': '20/12/2018'}
# {'avg_surface_temp': None, 'date': '02/12/2018'}
# {'avg_surface_temp': 42.0, 'date': '28/11/2018'}
# {'avg_surface_temp': None, 'date': '26/11/2018'}
# {'avg_surface_temp': None, 'date': '20/11/2018'}
# {'avg_surface_temp': None, 'date': '17/11/2018'}
# {'avg_surface_temp': None, 'date': '16/11/2018'}
# {'avg_surface_temp': 60.625, 'date': '29/11/2018'}
# {'avg_surface_temp': None, 'date': '15/11/2018'}
# {'avg_surface_temp': 52.0, 'date': '14/11/2018'}
# {'avg_surface_temp': 46.25, 'date': '11/11/2018'}
# {'avg_surface_temp': None, 'date': '07/11/2018'}
# {'avg_surface_temp': 58.5, 'date': '05/11/2018'}
# {'avg_surface_temp': None, 'date': '01/11/2018'}
# {'avg_surface_temp': None, 'date': '31/10/2018'}
# {'avg_surface_temp': 50.4, 'date': '27/10/2018'}
# {'avg_surface_temp': 44.6, 'date': '26/10/2018'}
# {'avg_surface_temp': None, 'date': '24/10/2018'}
# {'avg_surface_temp': 38.0, 'date': '23/10/2018'}
# {'avg_surface_temp': None, 'date': '22/12/2018'}
# {'avg_surface_temp': None, 'date': '22/10/2018'}
# {'avg_surface_temp': 50.0, 'date': '20/10/2018'}
# {'avg_surface_temp': 51.6, 'date': '17/10/2018'}
# {'avg_surface_temp': None, 'date': '13/10/2018'}
# {'avg_surface_temp': 56.0, 'date': '28/10/2018'}
# {'avg_surface_temp': 53.333333333333336, 'date': '10/10/2018'}
# {'avg_surface_temp': 44.0, 'date': '09/10/2018'}
# {'avg_surface_temp': 41.0, 'date': '08/10/2018'}
# {'avg_surface_temp': None, 'date': '05/10/2018'}
# {'avg_surface_temp': 49.0, 'date': '04/10/2018'}
# {'avg_surface_temp': 50.0, 'date': '03/10/2018'}
# {'avg_surface_temp': 43.57142857142857, 'date': '02/10/2018'}
# {'avg_surface_temp': 48.25, 'date': '01/10/2018'}
# {'avg_surface_temp': 43.0, 'date': '29/09/2018'}
# {'avg_surface_temp': 49.714285714285715, 'date': '27/09/2018'}
# {'avg_surface_temp': 51.25, 'date': '21/10/2018'}
# {'avg_surface_temp': 33.0, 'date': '26/09/2018'}
# {'avg_surface_temp': 45.0, 'date': '22/09/2018'}
# {'avg_surface_temp': 63.6, 'date': '20/09/2018'}
# {'avg_surface_temp': None, 'date': '17/09/2018'}
# {'avg_surface_temp': None, 'date': '16/09/2018'}
# {'avg_surface_temp': None, 'date': '14/09/2018'}
# {'avg_surface_temp': None, 'date': '11/09/2018'}
# {'avg_surface_temp': 56.5, 'date': '10/09/2018'}
# {'avg_surface_temp': None, 'date': '13/09/2018'}
# {'avg_surface_temp': None, 'date': '09/09/2018'}
# {'avg_surface_temp': None, 'date': '08/09/2018'}
# {'avg_surface_temp': None, 'date': '01/01/2018'}
# {'avg_surface_temp': None, 'date': '07/09/2018'}
# {'avg_surface_temp': None, 'date': '06/09/2018'}
# {'avg_surface_temp': None, 'date': '04/09/2018'}
# {'avg_surface_temp': None, 'date': '03/09/2018'}
# {'avg_surface_temp': None, 'date': '18/12/2018'}
# {'avg_surface_temp': None, 'date': '02/09/2018'}
# {'avg_surface_temp': None, 'date': '26/12/2018'}
# {'avg_surface_temp': None, 'date': '31/08/2018'}
# {'avg_surface_temp': None, 'date': '30/08/2018'}
# {'avg_surface_temp': None, 'date': '27/08/2018'}
# {'avg_surface_temp': 58.8, 'date': '23/11/2018'}
# {'avg_surface_temp': None, 'date': '26/08/2018'}
# {'avg_surface_temp': None, 'date': '24/08/2018'}
# {'avg_surface_temp': None, 'date': '23/08/2018'}
# {'avg_surface_temp': None, 'date': '22/08/2018'}
# {'avg_surface_temp': None, 'date': '19/08/2018'}
# {'avg_surface_temp': None, 'date': '18/08/2018'}
# {'avg_surface_temp': 36.0, 'date': '16/10/2018'}
# {'avg_surface_temp': None, 'date': '16/08/2018'}
# {'avg_surface_temp': 49.0, 'date': '13/08/2018'}
# {'avg_surface_temp': None, 'date': '12/08/2018'}
# {'avg_surface_temp': None, 'date': '11/08/2018'}
# {'avg_surface_temp': 63.0, 'date': '10/08/2018'}
# {'avg_surface_temp': None, 'date': '08/08/2018'}
# {'avg_surface_temp': None, 'date': '06/08/2018'}
# {'avg_surface_temp': None, 'date': '30/10/2018'}
# {'avg_surface_temp': 40.0, 'date': '05/08/2018'}
# {'avg_surface_temp': 47.0, 'date': '31/07/2018'}
# {'avg_surface_temp': None, 'date': '11/12/2018'}
# {'avg_surface_temp': None, 'date': '30/07/2018'}
# {'avg_surface_temp': 48.0, 'date': '29/07/2018'}
# {'avg_surface_temp': None, 'date': '28/07/2018'}
# {'avg_surface_temp': None, 'date': '26/07/2018'}
# {'avg_surface_temp': None, 'date': '29/10/2018'}
# {'avg_surface_temp': None, 'date': '25/07/2018'}
# {'avg_surface_temp': None, 'date': '23/07/2018'}
# {'avg_surface_temp': None, 'date': '22/07/2018'}
# {'avg_surface_temp': None, 'date': '20/07/2018'}
# {'avg_surface_temp': 52.41935483870968, 'date': '30/11/2018'}
# {'avg_surface_temp': None, 'date': '18/07/2018'}
# {'avg_surface_temp': 58.25, 'date': '09/12/2018'}
# {'avg_surface_temp': 58.44444444444444, 'date': '03/04/2018'}
# {'avg_surface_temp': None, 'date': '30/04/2018'}
# {'avg_surface_temp': 40.5, 'date': '21/09/2018'}
# {'avg_surface_temp': 48.72727272727273, 'date': '31/03/2018'}
# {'avg_surface_temp': 39.0, 'date': '15/12/2018'}
# {'avg_surface_temp': None, 'date': '02/11/2018'}
# {'avg_surface_temp': None, 'date': '12/09/2018'}
# {'avg_surface_temp': None, 'date': '21/08/2018'}
# {'avg_surface_temp': None, 'date': '23/03/2018'}
# {'avg_surface_temp': None, 'date': '07/08/2018'}
# {'avg_surface_temp': 88.2, 'date': '12/03/2018'}
# {'avg_surface_temp': 53.0, 'date': '12/11/2018'}
# {'avg_surface_temp': 65.57142857142857, 'date': '19/03/2018'}
# {'avg_surface_temp': None, 'date': '16/02/2018'}
# {'avg_surface_temp': 69.375, 'date': '10/03/2018'}
# {'avg_surface_temp': 51.5, 'date': '08/03/2018'}
# {'avg_surface_temp': 51.857142857142854, 'date': '07/06/2018'}
# {'avg_surface_temp': 53.57142857142857, 'date': '24/09/2018'}
# {'avg_surface_temp': None, 'date': '08/07/2018'}
# {'avg_surface_temp': 46.0, 'date': '21/12/2018'}
# {'avg_surface_temp': 56.80740740740741, 'date': '04/05/2018'}
# {'avg_surface_temp': None, 'date': '11/03/2018'}
# {'avg_surface_temp': None, 'date': '25/11/2018'}
# {'avg_surface_temp': 59.0, 'date': '21/11/2018'}
# {'avg_surface_temp': 42.0, 'date': '07/10/2018'}
# {'avg_surface_temp': None, 'date': '08/06/2018'}
# {'avg_surface_temp': None, 'date': '27/02/2018'}
# {'avg_surface_temp': 52.166666666666664, 'date': '18/10/2018'}
# {'avg_surface_temp': 52.73913043478261, 'date': '23/09/2018'}
# {'avg_surface_temp': 46.0, 'date': '15/03/2018'}
# {'avg_surface_temp': 54.16, 'date': '19/04/2018'}
# {'avg_surface_temp': None, 'date': '06/02/2018'}
# {'avg_surface_temp': 41.0, 'date': '13/06/2018'}
# {'avg_surface_temp': 72.66666666666667, 'date': '15/10/2018'}
# {'avg_surface_temp': 64.0, 'date': '07/03/2018'}
# {'avg_surface_temp': None, 'date': '04/03/2018'}
# {'avg_surface_temp': None, 'date': '18/02/2018'}
# {'avg_surface_temp': 56.58064516129032, 'date': '20/04/2018'}
# {'avg_surface_temp': None, 'date': '24/02/2018'}
# {'avg_surface_temp': None, 'date': '15/01/2018'}
# {'avg_surface_temp': 66.0, 'date': '25/03/2018'}
# {'avg_surface_temp': None, 'date': '20/01/2018'}
# {'avg_surface_temp': None, 'date': '03/02/2018'}
# {'avg_surface_temp': None, 'date': '22/03/2018'}
# {'avg_surface_temp': None, 'date': '13/02/2018'}
# {'avg_surface_temp': 61.71186440677966, 'date': '06/04/2018'}
# {'avg_surface_temp': None, 'date': '18/11/2018'}
# {'avg_surface_temp': None, 'date': '03/01/2018'}
# {'avg_surface_temp': None, 'date': '06/01/2018'}
# {'avg_surface_temp': 49.0, 'date': '14/05/2018'}
# {'avg_surface_temp': None, 'date': '17/01/2018'}
# {'avg_surface_temp': 59.57971014492754, 'date': '15/04/2018'}
# {'avg_surface_temp': None, 'date': '22/01/2018'}
# {'avg_surface_temp': None, 'date': '04/12/2018'}
# {'avg_surface_temp': 49.0, 'date': '09/06/2018'}
# {'avg_surface_temp': None, 'date': '14/02/2018'}
# {'avg_surface_temp': None, 'date': '30/09/2018'}
# {'avg_surface_temp': None, 'date': '19/01/2018'}
# {'avg_surface_temp': None, 'date': '27/11/2018'}
# {'avg_surface_temp': None, 'date': '01/09/2018'}
# {'avg_surface_temp': 50.921052631578945, 'date': '17/04/2018'}
# {'avg_surface_temp': None, 'date': '12/06/2018'}
# {'avg_surface_temp': None, 'date': '14/01/2018'}
# {'avg_surface_temp': None, 'date': '12/02/2018'}
# {'avg_surface_temp': None, 'date': '28/05/2018'}
# {'avg_surface_temp': None, 'date': '17/12/2018'}
# {'avg_surface_temp': None, 'date': '05/12/2018'}
# {'avg_surface_temp': None, 'date': '16/01/2018'}
# {'avg_surface_temp': None, 'date': '21/02/2018'}
# {'avg_surface_temp': None, 'date': '29/08/2018'}
# {'avg_surface_temp': None, 'date': '27/06/2018'}
# {'avg_surface_temp': None, 'date': '24/11/2018'}
# {'avg_surface_temp': None, 'date': '18/01/2018'}
# {'avg_surface_temp': None, 'date': '19/10/2018'}
# {'avg_surface_temp': 45.2, 'date': '02/04/2018'}
# {'avg_surface_temp': None, 'date': '11/02/2018'}
# {'avg_surface_temp': None, 'date': '13/01/2018'}
# {'avg_surface_temp': None, 'date': '25/02/2018'}
# {'avg_surface_temp': None, 'date': '12/01/2018'}
# {'avg_surface_temp': None, 'date': '02/01/2018'}
# {'avg_surface_temp': 51.0, 'date': '29/03/2018'}
# {'avg_surface_temp': None, 'date': '05/09/2018'}
# {'avg_surface_temp': 49.5, 'date': '26/05/2018'}
# {'avg_surface_temp': None, 'date': '14/10/2018'}
# {'avg_surface_temp': None, 'date': '27/07/2018'}
# {'avg_surface_temp': None, 'date': '03/03/2018'}
# {'avg_surface_temp': 54.5, 'date': '22/04/2018'}
# {'avg_surface_temp': None, 'date': '02/03/2018'}
# {'avg_surface_temp': None, 'date': '11/01/2018'}
# {'avg_surface_temp': None, 'date': '29/05/2018'}
# {'avg_surface_temp': None, 'date': '19/11/2018'}
# {'avg_surface_temp': None, 'date': '01/03/2018'}
# {'avg_surface_temp': None, 'date': '04/02/2018'}
# {'avg_surface_temp': None, 'date': '30/03/2018'}
# {'avg_surface_temp': None, 'date': '07/07/2018'}
# {'avg_surface_temp': 44.0, 'date': '06/10/2018'}
# {'avg_surface_temp': None, 'date': '09/02/2018'}
# {'avg_surface_temp': None, 'date': '25/01/2018'}
# {'avg_surface_temp': None, 'date': '04/01/2018'}
# {'avg_surface_temp': None, 'date': '17/08/2018'}
# {'avg_surface_temp': 46.714285714285715, 'date': '01/04/2018'}
# {'avg_surface_temp': None, 'date': '30/12/2018'}
# {'avg_surface_temp': None, 'date': '05/01/2018'}
# {'avg_surface_temp': 59.36842105263158, 'date': '11/05/2018'}
# {'avg_surface_temp': None, 'date': '08/01/2018'}
# {'avg_surface_temp': 38.5, 'date': '13/03/2018'}
# {'avg_surface_temp': None, 'date': '02/02/2018'}
# {'avg_surface_temp': 56.796875, 'date': '03/05/2018'}
# {'avg_surface_temp': None, 'date': '25/09/2018'}
# {'avg_surface_temp': None, 'date': '05/03/2018'}
# {'avg_surface_temp': 71.16666666666667, 'date': '20/06/2018'}
# {'avg_surface_temp': None, 'date': '22/02/2018'}
# {'avg_surface_temp': None, 'date': '15/02/2018'}
# {'avg_surface_temp': None, 'date': '26/01/2018'}
# {'avg_surface_temp': 62.57303370786517, 'date': '04/04/2018'}
# {'avg_surface_temp': 47.0, 'date': '13/11/2018'}
# {'avg_surface_temp': None, 'date': '19/07/2018'}
# {'avg_surface_temp': 56.88235294117647, 'date': '26/03/2018'}
# {'avg_surface_temp': None, 'date': '19/09/2018'}
# {'avg_surface_temp': None, 'date': '27/01/2018'}
# {'avg_surface_temp': 53.142857142857146, 'date': '05/04/2018'}
# {'avg_surface_temp': 40.8, 'date': '14/08/2018'}
# {'avg_surface_temp': None, 'date': '11/07/2018'}
# {'avg_surface_temp': 65.6, 'date': '14/03/2018'}
# {'avg_surface_temp': None, 'date': '28/01/2018'}
# {'avg_surface_temp': 53.36615384615384, 'date': '18/04/2018'}
# {'avg_surface_temp': None, 'date': '29/01/2018'}
# {'avg_surface_temp': None, 'date': '09/08/2018'}
# {'avg_surface_temp': None, 'date': '21/01/2018'}
# {'avg_surface_temp': 60.925925925925924, 'date': '28/03/2018'}
# {'avg_surface_temp': None, 'date': '23/01/2018'}
# {'avg_surface_temp': 60.5, 'date': '06/03/2018'}
# {'avg_surface_temp': None, 'date': '30/01/2018'}
# {'avg_surface_temp': None, 'date': '24/07/2018'}
# {'avg_surface_temp': None, 'date': '27/03/2018'}
# {'avg_surface_temp': None, 'date': '15/09/2018'}
# {'avg_surface_temp': None, 'date': '28/04/2018'}
# {'avg_surface_temp': None, 'date': '01/02/2018'}
# {'avg_surface_temp': 50.333333333333336, 'date': '07/05/2018'}
# {'avg_surface_temp': None, 'date': '10/01/2018'}
# {'avg_surface_temp': None, 'date': '07/01/2018'}
# {'avg_surface_temp': None, 'date': '23/02/2018'}
# {'avg_surface_temp': None, 'date': '07/02/2018'}
# {'avg_surface_temp': None, 'date': '04/11/2018'}
# {'avg_surface_temp': None, 'date': '08/02/2018'}
# {'avg_surface_temp': None, 'date': '10/02/2018'}
# {'avg_surface_temp': 50.69230769230769, 'date': '07/04/2018'}
# {'avg_surface_temp': 46.291666666666664, 'date': '11/04/2018'}
# {'avg_surface_temp': None, 'date': '09/04/2018'}
# {'avg_surface_temp': None, 'date': '20/03/2018'}
# {'avg_surface_temp': 34.0, 'date': '26/04/2018'}
# {'avg_surface_temp': None, 'date': '25/06/2018'}
# {'avg_surface_temp': 32.0, 'date': '24/12/2018'}
# {'avg_surface_temp': 52.69565217391305, 'date': '12/04/2018'}
# {'avg_surface_temp': None, 'date': '15/08/2018'}
# {'avg_surface_temp': 58.57983193277311, 'date': '13/04/2018'}
# {'avg_surface_temp': None, 'date': '10/07/2018'}
# {'avg_surface_temp': None, 'date': '26/02/2018'}
# {'avg_surface_temp': 61.94444444444444, 'date': '14/04/2018'}
# {'avg_surface_temp': None, 'date': '24/01/2018'}
# {'avg_surface_temp': 56.291666666666664, 'date': '08/05/2018'}
# {'avg_surface_temp': 48.72222222222222, 'date': '16/04/2018'}
# {'avg_surface_temp': None, 'date': '21/04/2018'}
# {'avg_surface_temp': 46.666666666666664, 'date': '09/03/2018'}
# {'avg_surface_temp': 44.142857142857146, 'date': '18/05/2018'}
# {'avg_surface_temp': 53.89473684210526, 'date': '23/04/2018'}
# {'avg_surface_temp': 61.3, 'date': '09/11/2018'}
# {'avg_surface_temp': 59.375, 'date': '24/04/2018'}
# {'avg_surface_temp': 48.666666666666664, 'date': '25/04/2018'}
# {'avg_surface_temp': 63.0, 'date': '29/04/2018'}
# {'avg_surface_temp': 68.4, 'date': '01/05/2018'}
# {'avg_surface_temp': 61.5, 'date': '22/11/2018'}
# {'avg_surface_temp': 55.6, 'date': '02/05/2018'}
# {'avg_surface_temp': None, 'date': '28/12/2018'}
# {'avg_surface_temp': None, 'date': '15/06/2018'}
# {'avg_surface_temp': None, 'date': '28/08/2018'}
# {'avg_surface_temp': 51.70967741935484, 'date': '05/05/2018'}
# {'avg_surface_temp': 57.529411764705884, 'date': '06/05/2018'}
# {'avg_surface_temp': None, 'date': '27/04/2018'}
# {'avg_surface_temp': 52.86842105263158, 'date': '10/05/2018'}
# {'avg_surface_temp': None, 'date': '19/02/2018'}
# {'avg_surface_temp': None, 'date': '13/07/2018'}
# {'avg_surface_temp': 51.5, 'date': '12/05/2018'}
# {'avg_surface_temp': None, 'date': '28/09/2018'}
# {'avg_surface_temp': None, 'date': '17/02/2018'}
# {'avg_surface_temp': 58.611111111111114, 'date': '13/05/2018'}
# {'avg_surface_temp': 53.950980392156865, 'date': '15/05/2018'}
# {'avg_surface_temp': None, 'date': '21/07/2018'}
# {'avg_surface_temp': None, 'date': '27/05/2018'}
# {'avg_surface_temp': None, 'date': '29/12/2018'}
# {'avg_surface_temp': 39.666666666666664, 'date': '16/05/2018'}
# {'avg_surface_temp': 42.46153846153846, 'date': '09/05/2018'}
# {'avg_surface_temp': 52.0, 'date': '17/05/2018'}
# {'avg_surface_temp': None, 'date': '25/10/2018'}
# {'avg_surface_temp': 63.5, 'date': '02/08/2018'}
# {'avg_surface_temp': None, 'date': '05/02/2018'}
# {'avg_surface_temp': None, 'date': '19/05/2018'}
# {'avg_surface_temp': None, 'date': '25/08/2018'}
# {'avg_surface_temp': None, 'date': '21/05/2018'}
# {'avg_surface_temp': None, 'date': '10/04/2018'}
# {'avg_surface_temp': None, 'date': '05/06/2018'}
# {'avg_surface_temp': 79.33333333333333, 'date': '18/03/2018'}
# {'avg_surface_temp': 54.484848484848484, 'date': '22/05/2018'}
# {'avg_surface_temp': 40.333333333333336, 'date': '24/05/2018'}
# {'avg_surface_temp': 41.5, 'date': '11/06/2018'}
# {'avg_surface_temp': None, 'date': '06/11/2018'}
# {'avg_surface_temp': 60.75, 'date': '08/04/2018'}
# {'avg_surface_temp': None, 'date': '25/05/2018'}
# {'avg_surface_temp': 70.0, 'date': '14/12/2018'}
# {'avg_surface_temp': None, 'date': '30/05/2018'}
# {'avg_surface_temp': None, 'date': '16/07/2018'}
# {'avg_surface_temp': None, 'date': '15/07/2018'}
# {'avg_surface_temp': None, 'date': '01/12/2018'}
# {'avg_surface_temp': None, 'date': '12/10/2018'}
# {'avg_surface_temp': None, 'date': '28/02/2018'}
# {'avg_surface_temp': 49.0, 'date': '24/03/2018'}
# {'avg_surface_temp': None, 'date': '31/05/2018'}
# {'avg_surface_temp': 54.0, 'date': '01/06/2018'}
# {'avg_surface_temp': 42.0, 'date': '18/06/2018'}
# {'avg_surface_temp': 47.72727272727273, 'date': '02/06/2018'}
# {'avg_surface_temp': None, 'date': '04/08/2018'}
# {'avg_surface_temp': 47.0, 'date': '03/06/2018'}
# {'avg_surface_temp': 52.22222222222222, 'date': '04/06/2018'}
# {'avg_surface_temp': None, 'date': '18/09/2018'}
# {'avg_surface_temp': 59.5, 'date': '17/03/2018'}
# {'avg_surface_temp': None, 'date': '06/06/2018'}
# {'avg_surface_temp': 41.5, 'date': '14/07/2018'}
# {'avg_surface_temp': None, 'date': '11/10/2018'}
# {'avg_surface_temp': None, 'date': '10/06/2018'}
# {'avg_surface_temp': 53.25, 'date': '14/06/2018'}
# {'avg_surface_temp': None, 'date': '17/06/2018'}
# {'avg_surface_temp': None, 'date': '21/03/2018'}
# {'avg_surface_temp': None, 'date': '16/03/2018'}
# {'avg_surface_temp': None, 'date': '19/06/2018'}
# {'avg_surface_temp': 43.5, 'date': '02/07/2018'}
# {'avg_surface_temp': 45.5, 'date': '08/11/2018'}
# {'avg_surface_temp': None, 'date': '21/06/2018'}
# {'avg_surface_temp': None, 'date': '20/02/2018'}
# {'avg_surface_temp': None, 'date': '03/07/2018'}
# {'avg_surface_temp': None, 'date': '20/05/2018'}
# {'avg_surface_temp': 46.0, 'date': '22/06/2018'}
# {'avg_surface_temp': 57.8, 'date': '16/12/2018'}
# {'avg_surface_temp': 51.2, 'date': '23/05/2018'}
# {'avg_surface_temp': 45.0, 'date': '05/07/2018'}
# {'avg_surface_temp': 46.0, 'date': '10/12/2018'}
# {'avg_surface_temp': 42.5, 'date': '16/06/2018'}
# {'avg_surface_temp': None, 'date': '17/07/2018'}
# {'avg_surface_temp': None, 'date': '31/12/2017'}
# {'avg_surface_temp': None, 'date': '23/06/2018'}
# {'avg_surface_temp': None, 'date': '24/06/2018'}
# {'avg_surface_temp': 40.0, 'date': '04/07/2018'}
# {'avg_surface_temp': None, 'date': '26/06/2018'}
# {'avg_surface_temp': None, 'date': '31/01/2018'}
# {'avg_surface_temp': None, 'date': '28/06/2018'}
# {'avg_surface_temp': None, 'date': '29/06/2018'}
# {'avg_surface_temp': 44.333333333333336, 'date': '30/06/2018'}
# {'avg_surface_temp': None, 'date': '03/11/2018'}
# {'avg_surface_temp': None, 'date': '03/08/2018'}
# {'avg_surface_temp': None, 'date': '09/01/2018'}
# {'avg_surface_temp': None, 'date': '09/07/2018'}
# {'avg_surface_temp': None, 'date': '10/11/2018'}
# {'avg_surface_temp': 30.5, 'date': '01/07/2018'}
# {'avg_surface_temp': None, 'date': '20/08/2018'}
# {'avg_surface_temp': 56.0, 'date': '06/07/2018'}
# {'avg_surface_temp': 58.0, 'date': '01/08/2018'}
# {'avg_surface_temp': None, 'date': '12/07/2018'}

# %% [markdown]
# **i. Find the top 10 records with the lowest GHI.**

# %%
results = climates.aggregate(
    [

        {
            "$lookup":{
                    "from": "fire_historic",
                    "localField": "fires",
                    "foreignField" : "_id",
                    "as": "fires"
            }
        },
        {
            "$sort": {"GHI_w/m2": 1}
        },
        {
            "$limit": 10
        }
    ]
)

for document in results:
    pprint(document)
# Out:
# {'GHI_w/m2': 47,
#  '_id': ObjectId('60af1c5e9343690fa945078e'),
#  'air_temperature_celcius': 5,
#  'date': '02/08/2018',
#  'fires': [{'_id': ObjectId('60af1c689343690fa9450949'),
#             'confidence': 94,
#             'date': '02/08/2018',
#             'datetime': '2018-08-02T03:45:40',
#             'latitude': -37.4796,
#             'longitude': 141.9403,
#             'surface_temperature_celcius': 87},
#            {'_id': ObjectId('60af1c689343690fa945094a'),
#             'confidence': 54,
#             'date': '02/08/2018',
#             'datetime': '2018-08-02T03:45:00',
#             'latitude': -37.491,
#             'longitude': 141.936,
#             'surface_temperature_celcius': 40}],
#  'max_wind_speed': 5.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 48,
#  '_id': ObjectId('60af1c5e9343690fa945076d'),
#  'air_temperature_celcius': 5,
#  'date': '30/06/2018',
#  'fires': [{'_id': ObjectId('60af1c689343690fa9450964'),
#             'confidence': 78,
#             'date': '30/06/2018',
#             'datetime': '2018-06-30T04:41:25',
#             'latitude': -36.834,
#             'longitude': 142.524,
#             'surface_temperature_celcius': 44},
#            {'_id': ObjectId('60af1c689343690fa9450965'),
#             'confidence': 78,
#             'date': '30/06/2018',
#             'datetime': '2018-06-30T04:41:25',
#             'latitude': -36.834,
#             'longitude': 142.524,
#             'surface_temperature_celcius': 44},
#            {'_id': ObjectId('60af1c689343690fa9450966'),
#             'confidence': 81,
#             'date': '30/06/2018',
#             'datetime': '2018-06-30T00:27:19',
#             'latitude': -37.858,
#             'longitude': 143.428,
#             'surface_temperature_celcius': 48},
#            {'_id': ObjectId('60af1c689343690fa9450967'),
#             'confidence': 75,
#             'date': '30/06/2018',
#             'datetime': '2018-06-30T00:27:19',
#             'latitude': -37.856,
#             'longitude': 143.416,
#             'surface_temperature_celcius': 41},
#            {'_id': ObjectId('60af1c689343690fa9450968'),
#             'confidence': 75,
#             'date': '30/06/2018',
#             'datetime': '2018-06-30T00:27:19',
#             'latitude': -37.856,
#             'longitude': 143.416,
#             'surface_temperature_celcius': 41},
#            {'_id': ObjectId('60af1c689343690fa9450969'),
#             'confidence': 81,
#             'date': '30/06/2018',
#             'datetime': '2018-06-30T00:27:19',
#             'latitude': -37.858,
#             'longitude': 143.428,
#             'surface_temperature_celcius': 48}],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00A',
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
# {'GHI_w/m2': 49,
#  '_id': ObjectId('60af1c5e9343690fa945076e'),
#  'air_temperature_celcius': 5,
#  'date': '01/07/2018',
#  'fires': [{'_id': ObjectId('60af1c689343690fa9450960'),
#             'confidence': 53,
#             'date': '01/07/2018',
#             'datetime': '2018-07-01T13:11:41',
#             'latitude': -37.062,
#             'longitude': 141.373,
#             'surface_temperature_celcius': 29},
#            {'_id': ObjectId('60af1c689343690fa9450961'),
#             'confidence': 53,
#             'date': '01/07/2018',
#             'datetime': '2018-07-01T13:11:41',
#             'latitude': -37.062,
#             'longitude': 141.373,
#             'surface_temperature_celcius': 29},
#            {'_id': ObjectId('60af1c689343690fa9450962'),
#             'confidence': 61,
#             'date': '01/07/2018',
#             'datetime': '2018-07-01T03:46:08',
#             'latitude': -36.779,
#             'longitude': 146.108,
#             'surface_temperature_celcius': 32},
#            {'_id': ObjectId('60af1c689343690fa9450963'),
#             'confidence': 61,
#             'date': '01/07/2018',
#             'datetime': '2018-07-01T03:46:08',
#             'latitude': -36.779,
#             'longitude': 146.108,
#             'surface_temperature_celcius': 32}],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 56,
#  '_id': ObjectId('60af1c5e9343690fa9450778'),
#  'air_temperature_celcius': 6,
#  'date': '11/07/2018',
#  'fires': [],
#  'max_wind_speed': 5.1,
#  'precipitation ': ' 0.01G',
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'GHI_w/m2': 57,
#  '_id': ObjectId('60af1c5e9343690fa945077c'),
#  'air_temperature_celcius': 6,
#  'date': '15/07/2018',
#  'fires': [],
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 37.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'GHI_w/m2': 60,
#  '_id': ObjectId('60af1c5e9343690fa945076f'),
#  'air_temperature_celcius': 6,
#  'date': '02/07/2018',
#  'fires': [{'_id': ObjectId('60af1c689343690fa9450958'),
#             'confidence': 84,
#             'date': '02/07/2018',
#             'datetime': '2018-07-02T04:29:18',
#             'latitude': -36.397,
#             'longitude': 142.254,
#             'surface_temperature_celcius': 52},
#            {'_id': ObjectId('60af1c689343690fa9450959'),
#             'confidence': 84,
#             'date': '02/07/2018',
#             'datetime': '2018-07-02T04:29:18',
#             'latitude': -36.397,
#             'longitude': 142.254,
#             'surface_temperature_celcius': 52},
#            {'_id': ObjectId('60af1c689343690fa945095a'),
#             'confidence': 69,
#             'date': '02/07/2018',
#             'datetime': '2018-07-02T04:29:10',
#             'latitude': -37.067,
#             'longitude': 141.379,
#             'surface_temperature_celcius': 36},
#            {'_id': ObjectId('60af1c689343690fa945095b'),
#             'confidence': 69,
#             'date': '02/07/2018',
#             'datetime': '2018-07-02T04:29:10',
#             'latitude': -37.067,
#             'longitude': 141.379,
#             'surface_temperature_celcius': 36},
#            {'_id': ObjectId('60af1c689343690fa945095c'),
#             'confidence': 88,
#             'date': '02/07/2018',
#             'datetime': '2018-07-02T04:29:00',
#             'latitude': -37.333,
#             'longitude': 143.534,
#             'surface_temperature_celcius': 58},
#            {'_id': ObjectId('60af1c689343690fa945095d'),
#             'confidence': 88,
#             'date': '02/07/2018',
#             'datetime': '2018-07-02T04:29:00',
#             'latitude': -37.333,
#             'longitude': 143.534,
#             'surface_temperature_celcius': 58},
#            {'_id': ObjectId('60af1c689343690fa945095e'),
#             'confidence': 50,
#             'date': '02/07/2018',
#             'datetime': '2018-07-02T04:28:42',
#             'latitude': -37.886,
#             'longitude': 147.207,
#             'surface_temperature_celcius': 28},
#            {'_id': ObjectId('60af1c689343690fa945095f'),
#             'confidence': 50,
#             'date': '02/07/2018',
#             'datetime': '2018-07-02T04:28:42',
#             'latitude': -37.886,
#             'longitude': 147.207,
#             'surface_temperature_celcius': 28}],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('60af1c5e9343690fa945078d'),
#  'air_temperature_celcius': 7,
#  'date': '01/08/2018',
#  'fires': [{'_id': ObjectId('60af1c689343690fa945094b'),
#             'confidence': 89,
#             'date': '01/08/2018',
#             'datetime': '2018-08-01T00:20:30',
#             'latitude': -38.3998,
#             'longitude': 147.064,
#             'surface_temperature_celcius': 65},
#            {'_id': ObjectId('60af1c689343690fa945094c'),
#             'confidence': 78,
#             'date': '01/08/2018',
#             'datetime': '2018-08-01T00:19:30',
#             'latitude': -38.3982,
#             'longitude': 147.0509,
#             'surface_temperature_celcius': 51}],
#  'max_wind_speed': 7.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('60af1c5e9343690fa9450781'),
#  'air_temperature_celcius': 7,
#  'date': '20/07/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.12G',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 65,
#  '_id': ObjectId('60af1c5e9343690fa945078c'),
#  'air_temperature_celcius': 7,
#  'date': '31/07/2018',
#  'fires': [{'_id': ObjectId('60af1c689343690fa945094d'),
#             'confidence': 100,
#             'date': '31/07/2018',
#             'datetime': '2018-07-31T13:21:00',
#             'latitude': -37.8641,
#             'longitude': 143.4276,
#             'surface_temperature_celcius': 51},
#            {'_id': ObjectId('60af1c689343690fa945094e'),
#             'confidence': 92,
#             'date': '31/07/2018',
#             'datetime': '2018-07-31T13:21:00',
#             'latitude': -37.8658,
#             'longitude': 143.4162,
#             'surface_temperature_celcius': 43}],
#  'max_wind_speed': 8.0,
#  'precipitation ': ' 0.00I',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 3.1}
# {'GHI_w/m2': 66,
#  '_id': ObjectId('60af1c5e9343690fa945079f'),
#  'air_temperature_celcius': 7,
#  'date': '19/08/2018',
#  'fires': [],
#  'max_wind_speed': 9.9,
#  'precipitation ': ' 0.04G',
#  'relative_humidity': 37.9,
#  'station': 948702,
#  'windspeed_knots': 5.7}

# %% [markdown]
# **j. Find the records with a 24-hour precipitation recorded between 0.20 to 0.35.**

# %%
results = climates.aggregate(
    [
        {
            "$match": {
                        "$or" : [ 
                                { "precipitation ": { "$regex": "^ 0\.[2][0-9]" }},
                                { "precipitation ": { "$regex": "^ 0\.[3][0-5]" }}
                        ],
                        "precipitation ": { "$regex": "G$" },
                        
            }
        },
        {
            "$lookup":{
                    "from": "fire_historic",
                    "localField": "fires",
                    "foreignField" : "_id",
                    "as": "fires"
            }
        }
    ]
)

for document in results:
    pprint(document)
# Out:
# {'GHI_w/m2': 157,
#  '_id': ObjectId('60af1c5e9343690fa94506c5'),
#  'air_temperature_celcius': 19,
#  'date': '13/01/2018',
#  'fires': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'GHI_w/m2': 146,
#  '_id': ObjectId('60af1c5e9343690fa9450710'),
#  'air_temperature_celcius': 17,
#  'date': '29/03/2018',
#  'fires': [{'_id': ObjectId('60af1c689343690fa94511f6'),
#             'confidence': 69,
#             'date': '29/03/2018',
#             'datetime': '2018-03-29T00:48:40',
#             'latitude': -34.2648,
#             'longitude': 141.6325,
#             'surface_temperature_celcius': 51}],
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 166,
#  '_id': ObjectId('60af1c5e9343690fa9450726'),
#  'air_temperature_celcius': 20,
#  'date': '20/04/2018',
#  'fires': [{'_id': ObjectId('60af1c689343690fa9450c6a'),
#             'confidence': 84,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:44:20',
#             'latitude': -36.8871,
#             'longitude': 145.1536,
#             'surface_temperature_celcius': 58},
#            {'_id': ObjectId('60af1c689343690fa9450c6b'),
#             'confidence': 59,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:36:00',
#             'latitude': -38.4685,
#             'longitude': 146.673,
#             'surface_temperature_celcius': 40},
#            {'_id': ObjectId('60af1c689343690fa9450c6c'),
#             'confidence': 60,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:34:10',
#             'latitude': -36.8922,
#             'longitude': 145.1252,
#             'surface_temperature_celcius': 40},
#            {'_id': ObjectId('60af1c689343690fa9450c6d'),
#             'confidence': 93,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:34:10',
#             'latitude': -37.769,
#             'longitude': 147.94,
#             'surface_temperature_celcius': 72},
#            {'_id': ObjectId('60af1c689343690fa9450c6e'),
#             'confidence': 77,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:33:40',
#             'latitude': -36.0799,
#             'longitude': 146.0784,
#             'surface_temperature_celcius': 50},
#            {'_id': ObjectId('60af1c689343690fa9450c6f'),
#             'confidence': 88,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:33:20',
#             'latitude': -36.0829,
#             'longitude': 146.0621,
#             'surface_temperature_celcius': 63},
#            {'_id': ObjectId('60af1c689343690fa9450c70'),
#             'confidence': 90,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:32:50',
#             'latitude': -36.1303,
#             'longitude': 146.3606,
#             'surface_temperature_celcius': 67},
#            {'_id': ObjectId('60af1c689343690fa9450c71'),
#             'confidence': 67,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:32:50',
#             'latitude': -37.7615,
#             'longitude': 147.9169,
#             'surface_temperature_celcius': 45},
#            {'_id': ObjectId('60af1c689343690fa9450c72'),
#             'confidence': 63,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:32:30',
#             'latitude': -36.8079,
#             'longitude': 145.1409,
#             'surface_temperature_celcius': 42},
#            {'_id': ObjectId('60af1c689343690fa9450c73'),
#             'confidence': 85,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:32:30',
#             'latitude': -37.7783,
#             'longitude': 147.9284,
#             'surface_temperature_celcius': 60},
#            {'_id': ObjectId('60af1c689343690fa9450c74'),
#             'confidence': 79,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:32:30',
#             'latitude': -36.8846,
#             'longitude': 145.1679,
#             'surface_temperature_celcius': 52},
#            {'_id': ObjectId('60af1c689343690fa9450c75'),
#             'confidence': 80,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:32:30',
#             'latitude': -37.2341,
#             'longitude': 149.1736,
#             'surface_temperature_celcius': 53},
#            {'_id': ObjectId('60af1c689343690fa9450c76'),
#             'confidence': 63,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:32:30',
#             'latitude': -36.9189,
#             'longitude': 147.5603,
#             'surface_temperature_celcius': 52},
#            {'_id': ObjectId('60af1c689343690fa9450c77'),
#             'confidence': 98,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:32:30',
#             'latitude': -36.1345,
#             'longitude': 146.351,
#             'surface_temperature_celcius': 84},
#            {'_id': ObjectId('60af1c689343690fa9450c78'),
#             'confidence': 87,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T04:32:30',
#             'latitude': -36.9246,
#             'longitude': 147.5559,
#             'surface_temperature_celcius': 62},
#            {'_id': ObjectId('60af1c689343690fa9450c79'),
#             'confidence': 64,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:19:00',
#             'latitude': -36.085,
#             'longitude': 145.9096,
#             'surface_temperature_celcius': 42},
#            {'_id': ObjectId('60af1c689343690fa9450c7a'),
#             'confidence': 88,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:18:40',
#             'latitude': -38.1301,
#             'longitude': 143.9398,
#             'surface_temperature_celcius': 63},
#            {'_id': ObjectId('60af1c689343690fa9450c7b'),
#             'confidence': 69,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:18:20',
#             'latitude': -37.7087,
#             'longitude': 145.5499,
#             'surface_temperature_celcius': 45},
#            {'_id': ObjectId('60af1c689343690fa9450c7c'),
#             'confidence': 100,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:18:20',
#             'latitude': -36.5865,
#             'longitude': 145.2081,
#             'surface_temperature_celcius': 111},
#            {'_id': ObjectId('60af1c689343690fa9450c7d'),
#             'confidence': 73,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:17:10',
#             'latitude': -36.8702,
#             'longitude': 144.0381,
#             'surface_temperature_celcius': 47},
#            {'_id': ObjectId('60af1c689343690fa9450c7e'),
#             'confidence': 99,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:17:10',
#             'latitude': -36.1586,
#             'longitude': 145.6666,
#             'surface_temperature_celcius': 85},
#            {'_id': ObjectId('60af1c689343690fa9450c7f'),
#             'confidence': 74,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:16:50',
#             'latitude': -37.8672,
#             'longitude': 143.8194,
#             'surface_temperature_celcius': 48},
#            {'_id': ObjectId('60af1c689343690fa9450c80'),
#             'confidence': 78,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:15:30',
#             'latitude': -36.5956,
#             'longitude': 145.206,
#             'surface_temperature_celcius': 51},
#            {'_id': ObjectId('60af1c689343690fa9450c81'),
#             'confidence': 77,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:14:20',
#             'latitude': -37.2197,
#             'longitude': 148.8134,
#             'surface_temperature_celcius': 50},
#            {'_id': ObjectId('60af1c689343690fa9450c82'),
#             'confidence': 96,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:14:10',
#             'latitude': -36.5847,
#             'longitude': 145.1968,
#             'surface_temperature_celcius': 78},
#            {'_id': ObjectId('60af1c689343690fa9450c83'),
#             'confidence': 89,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:13:40',
#             'latitude': -37.6997,
#             'longitude': 145.5519,
#             'surface_temperature_celcius': 64},
#            {'_id': ObjectId('60af1c689343690fa9450c84'),
#             'confidence': 61,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:13:30',
#             'latitude': -37.932,
#             'longitude': 146.1845,
#             'surface_temperature_celcius': 50},
#            {'_id': ObjectId('60af1c689343690fa9450c85'),
#             'confidence': 76,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:13:10',
#             'latitude': -36.6407,
#             'longitude': 144.2957,
#             'surface_temperature_celcius': 50},
#            {'_id': ObjectId('60af1c689343690fa9450c86'),
#             'confidence': 63,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:13:00',
#             'latitude': -36.1569,
#             'longitude': 145.6554,
#             'surface_temperature_celcius': 41},
#            {'_id': ObjectId('60af1c689343690fa9450c87'),
#             'confidence': 54,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:13:00',
#             'latitude': -36.6363,
#             'longitude': 144.3033,
#             'surface_temperature_celcius': 40},
#            {'_id': ObjectId('60af1c689343690fa9450c88'),
#             'confidence': 76,
#             'date': '20/04/2018',
#             'datetime': '2018-04-20T00:12:50',
#             'latitude': -37.2212,
#             'longitude': 148.8262,
#             'surface_temperature_celcius': 49}],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('60af1c5e9343690fa945072c'),
#  'air_temperature_celcius': 11,
#  'date': '26/04/2018',
#  'fires': [{'_id': ObjectId('60af1c689343690fa9450c49'),
#             'confidence': 56,
#             'date': '26/04/2018',
#             'datetime': '2018-04-26T13:26:10',
#             'latitude': -36.5511,
#             'longitude': 146.7819,
#             'surface_temperature_celcius': 34}],
#  'max_wind_speed': 20.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'GHI_w/m2': 122,
#  '_id': ObjectId('60af1c5e9343690fa945074b'),
#  'air_temperature_celcius': 14,
#  'date': '27/05/2018',
#  'fires': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.35G',
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'GHI_w/m2': 73,
#  '_id': ObjectId('60af1c5e9343690fa945074e'),
#  'air_temperature_celcius': 8,
#  'date': '30/05/2018',
#  'fires': [],
#  'max_wind_speed': 15.9,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'GHI_w/m2': 98,
#  '_id': ObjectId('60af1c5e9343690fa9450770'),
#  'air_temperature_celcius': 11,
#  'date': '03/07/2018',
#  'fires': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'GHI_w/m2': 99,
#  '_id': ObjectId('60af1c5e9343690fa9450788'),
#  'air_temperature_celcius': 11,
#  'date': '27/07/2018',
#  'fires': [],
#  'max_wind_speed': 21.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'GHI_w/m2': 83,
#  '_id': ObjectId('60af1c5e9343690fa9450792'),
#  'air_temperature_celcius': 9,
#  'date': '06/08/2018',
#  'fires': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'GHI_w/m2': 102,
#  '_id': ObjectId('60af1c5e9343690fa94507a6'),
#  'air_temperature_celcius': 11,
#  'date': '26/08/2018',
#  'fires': [],
#  'max_wind_speed': 19.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'GHI_w/m2': 75,
#  '_id': ObjectId('60af1c5e9343690fa94507b0'),
#  'air_temperature_celcius': 8,
#  'date': '05/09/2018',
#  'fires': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.31G',
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'GHI_w/m2': 90,
#  '_id': ObjectId('60af1c5e9343690fa94507b2'),
#  'air_temperature_celcius': 10,
#  'date': '07/09/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'GHI_w/m2': 97,
#  '_id': ObjectId('60af1c5e9343690fa94507ba'),
#  'air_temperature_celcius': 11,
#  'date': '15/09/2018',
#  'fires': [],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'GHI_w/m2': 105,
#  '_id': ObjectId('60af1c5e9343690fa94507ce'),
#  'air_temperature_celcius': 12,
#  'date': '05/10/2018',
#  'fires': [],
#  'max_wind_speed': 18.1,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'GHI_w/m2': 152,
#  '_id': ObjectId('60af1c5e9343690fa94507e6'),
#  'air_temperature_celcius': 17,
#  'date': '29/10/2018',
#  'fires': [],
#  'max_wind_speed': 27.0,
#  'precipitation ': ' 0.24G',
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'GHI_w/m2': 100,
#  '_id': ObjectId('60af1c5e9343690fa94507e7'),
#  'air_temperature_celcius': 11,
#  'date': '30/10/2018',
#  'fires': [],
#  'max_wind_speed': 14.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'GHI_w/m2': 140,
#  '_id': ObjectId('60af1c5e9343690fa94507f8'),
#  'air_temperature_celcius': 18,
#  'date': '16/11/2018',
#  'fires': [],
#  'max_wind_speed': 11.1,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 151,
#  '_id': ObjectId('60af1c5e9343690fa94507f9'),
#  'air_temperature_celcius': 19,
#  'date': '17/11/2018',
#  'fires': [],
#  'max_wind_speed': 12.0,
#  'precipitation ': ' 0.28G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'GHI_w/m2': 202,
#  '_id': ObjectId('60af1c5e9343690fa9450806'),
#  'air_temperature_celcius': 26,
#  'date': '30/11/2018',
#  'fires': [{'_id': ObjectId('60af1c679343690fa945084f'),
#             'confidence': 52,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T23:25:57',
#             'latitude': -37.635,
#             'longitude': 149.303,
#             'surface_temperature_celcius': 47},
#            {'_id': ObjectId('60af1c679343690fa9450850'),
#             'confidence': 100,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T15:38:36',
#             'latitude': -37.591,
#             'longitude': 149.33,
#             'surface_temperature_celcius': 53},
#            {'_id': ObjectId('60af1c679343690fa9450851'),
#             'confidence': 51,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T15:38:36',
#             'latitude': -37.59,
#             'longitude': 149.31,
#             'surface_temperature_celcius': 42},
#            {'_id': ObjectId('60af1c679343690fa9450852'),
#             'confidence': 64,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T15:38:36',
#             'latitude': -37.633,
#             'longitude': 149.264,
#             'surface_temperature_celcius': 42},
#            {'_id': ObjectId('60af1c679343690fa9450853'),
#             'confidence': 100,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T15:38:35',
#             'latitude': -37.585,
#             'longitude': 149.336,
#             'surface_temperature_celcius': 54},
#            {'_id': ObjectId('60af1c679343690fa9450854'),
#             'confidence': 69,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T15:38:35',
#             'latitude': -37.58,
#             'longitude': 149.331,
#             'surface_temperature_celcius': 35},
#            {'_id': ObjectId('60af1c679343690fa9450855'),
#             'confidence': 100,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T15:38:35',
#             'latitude': -37.583,
#             'longitude': 149.316,
#             'surface_temperature_celcius': 49},
#            {'_id': ObjectId('60af1c679343690fa9450856'),
#             'confidence': 61,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T15:38:32',
#             'latitude': -37.38,
#             'longitude': 149.334,
#             'surface_temperature_celcius': 31},
#            {'_id': ObjectId('60af1c679343690fa9450857'),
#             'confidence': 62,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T12:22:15',
#             'latitude': -37.602,
#             'longitude': 149.295,
#             'surface_temperature_celcius': 33},
#            {'_id': ObjectId('60af1c679343690fa9450858'),
#             'confidence': 64,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T12:22:15',
#             'latitude': -37.598,
#             'longitude': 149.29,
#             'surface_temperature_celcius': 32},
#            {'_id': ObjectId('60af1c679343690fa9450859'),
#             'confidence': 84,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T12:22:15',
#             'latitude': -37.596,
#             'longitude': 149.319,
#             'surface_temperature_celcius': 38},
#            {'_id': ObjectId('60af1c679343690fa945085a'),
#             'confidence': 81,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T12:22:15',
#             'latitude': -37.63,
#             'longitude': 149.232,
#             'surface_temperature_celcius': 42},
#            {'_id': ObjectId('60af1c679343690fa945085b'),
#             'confidence': 100,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T12:22:15',
#             'latitude': -37.644,
#             'longitude': 149.233,
#             'surface_temperature_celcius': 55},
#            {'_id': ObjectId('60af1c679343690fa945085c'),
#             'confidence': 100,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T12:22:15',
#             'latitude': -37.642,
#             'longitude': 149.263,
#             'surface_temperature_celcius': 65},
#            {'_id': ObjectId('60af1c679343690fa945085d'),
#             'confidence': 100,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T12:22:14',
#             'latitude': -37.634,
#             'longitude': 149.237,
#             'surface_temperature_celcius': 71},
#            {'_id': ObjectId('60af1c679343690fa945085e'),
#             'confidence': 84,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T04:35:00',
#             'latitude': -37.384,
#             'longitude': 149.336,
#             'surface_temperature_celcius': 59},
#            {'_id': ObjectId('60af1c679343690fa945085f'),
#             'confidence': 73,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T04:35:00',
#             'latitude': -37.389,
#             'longitude': 149.311,
#             'surface_temperature_celcius': 50},
#            {'_id': ObjectId('60af1c679343690fa9450860'),
#             'confidence': 98,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T04:34:57',
#             'latitude': -37.605,
#             'longitude': 149.302,
#             'surface_temperature_celcius': 83},
#            {'_id': ObjectId('60af1c679343690fa9450861'),
#             'confidence': 81,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T04:34:57',
#             'latitude': -37.627,
#             'longitude': 149.261,
#             'surface_temperature_celcius': 57},
#            {'_id': ObjectId('60af1c679343690fa9450862'),
#             'confidence': 84,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T04:34:57',
#             'latitude': -37.623,
#             'longitude': 149.284,
#             'surface_temperature_celcius': 61},
#            {'_id': ObjectId('60af1c679343690fa9450863'),
#             'confidence': 99,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T04:34:57',
#             'latitude': -37.6,
#             'longitude': 149.325,
#             'surface_temperature_celcius': 86},
#            {'_id': ObjectId('60af1c679343690fa9450864'),
#             'confidence': 69,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T04:34:57',
#             'latitude': -37.61,
#             'longitude': 149.279,
#             'surface_temperature_celcius': 48},
#            {'_id': ObjectId('60af1c679343690fa9450865'),
#             'confidence': 60,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T00:21:00',
#             'latitude': -37.637,
#             'longitude': 146.288,
#             'surface_temperature_celcius': 42},
#            {'_id': ObjectId('60af1c679343690fa9450866'),
#             'confidence': 83,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T00:20:53',
#             'latitude': -37.608,
#             'longitude': 149.282,
#             'surface_temperature_celcius': 58},
#            {'_id': ObjectId('60af1c679343690fa9450867'),
#             'confidence': 87,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T00:20:53',
#             'latitude': -37.62,
#             'longitude': 149.294,
#             'surface_temperature_celcius': 63},
#            {'_id': ObjectId('60af1c679343690fa9450868'),
#             'confidence': 95,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T00:20:53',
#             'latitude': -37.618,
#             'longitude': 149.281,
#             'surface_temperature_celcius': 76},
#            {'_id': ObjectId('60af1c679343690fa9450869'),
#             'confidence': 81,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T00:20:53',
#             'latitude': -37.61,
#             'longitude': 149.296,
#             'surface_temperature_celcius': 56},
#            {'_id': ObjectId('60af1c679343690fa945086a'),
#             'confidence': 73,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T00:20:53',
#             'latitude': -37.603,
#             'longitude': 149.324,
#             'surface_temperature_celcius': 51},
#            {'_id': ObjectId('60af1c679343690fa945086b'),
#             'confidence': 81,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T00:20:53',
#             'latitude': -37.602,
#             'longitude': 149.311,
#             'surface_temperature_celcius': 55},
#            {'_id': ObjectId('60af1c679343690fa945086c'),
#             'confidence': 69,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T00:20:53',
#             'latitude': -37.6,
#             'longitude': 149.297,
#             'surface_temperature_celcius': 50},
#            {'_id': ObjectId('60af1c679343690fa945086d'),
#             'confidence': 64,
#             'date': '30/11/2018',
#             'datetime': '2018-11-30T00:20:49',
#             'latitude': -37.382,
#             'longitude': 149.341,
#             'surface_temperature_celcius': 41}],
#  'max_wind_speed': 15.0,
#  'precipitation ': ' 0.20G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
